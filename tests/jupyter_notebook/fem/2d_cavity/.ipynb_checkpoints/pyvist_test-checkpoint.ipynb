# %%
import numpy as np
from numpy import pi, cos, sin, linspace, meshgrid
import pyvista as pv
from itkwidgets import view

# %%
def x_(u, v):
    x = -2 + 2*cos(v) - cos(u)
    x[v<3*pi] = -2 + (2 + cos(u[v<3*pi]))*cos(v[v<3*pi])
    x[v<2*pi] = cos(u[v<2*pi])*(2.5 - 1.5*cos(v[v<2*pi]))
    return x

def y_(u, v):
    y = sin(u)
    y[v<2*pi] = sin(u[v<2*pi])*(2.5 - 1.5*cos(v[v<2*pi]))
    return y

def z_(u, v):
    z = -3*v + 12*pi
    z[v<3*pi] = (2 + cos(u[v<3*pi]))*sin(v[v<3*pi]) + 3*pi
    z[v<2*pi] = 3*v[v<2*pi] - 3*pi
    z[v<pi] = -2.5*sin(v[v<pi])
    return -z

 
u = linspace(pi, 2*pi, 10)
v = linspace(0, 4*pi, 38)
u, v = meshgrid(u, v)

x = x_(u, v)
y = y_(u, v)
z = z_(u, v)

# %%
grid = pv.StructuredGrid(x, y, z)
grid["z"] = z.T.ravel()
view(geometries=grid, cmap="Plasma (matplotlib)")
# Out:
# Viewer(cmap='Plasma (matplotlib)', geometries=[{'vtkClass': 'vtkPolyData', 'points': {'vtkClass': 'vtkPoints',…

# %%
import gmsh
import gmsh_api
gmsh.initialize()
gmsh.model.add("square")
gmsh.model.geo.addPoint(0, 0, 0, 0.1, 1)
gmsh.model.geo.addPoint(1, 0, 0, 0.1, 2)
gmsh.model.geo.addPoint(1, 1, 0, 0.1, 3)
gmsh.model.geo.addPoint(0, 1, 0, 0.1, 4)
gmsh.model.geo.addLine(1, 2, 1)
gmsh.model.geo.addLine(2, 3, 2)
gmsh.model.geo.addLine(3, 4, 3)
# try automatic assignement of tag
line4 = gmsh.model.geo.addLine(4, 1)
gmsh.model.geo.addCurveLoop([1, 2, 3, line4], 1)
gmsh.model.geo.addPlaneSurface([1], 6)
gmsh.model.geo.synchronize()
gmsh.model.mesh.generate(2)
gmsh.write("square_testing_gmsh_python.msh")
# gmsh.finalize()

# %%
mesh = gmsh_api.Mesh.from_gmsh(gmsh)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/ctypeslib.py:523: RuntimeWarning: A builtin ctypes object gave a PEP3118 format string that does not match its itemsize, so a best-guess will be made of the data type. Newer versions of python may behave correctly.
#   return array(obj, copy=False)

# %%
ls
# Out:
# mesh_simple_square.geo          test_cavity.edp
# mesh_simple_square.msh          test_cavity.py
# pyvist_test.ipynb               test_cavity_new.py
# square_testing_gmsh_python.msh  test_cavity_new.vtk

# %%
mesh=gmsh_api.Mesh.from_gmsh("mesh_simple_square.msh")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-73a3e12ccd7c> in <module>
# ----> 1 mesh=gmsh_api.Mesh.from_gmsh("mesh_simple_square.msh")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gmsh_api/__init__.py in from_gmsh(cls, gmsh)
#      22
#      23         elements = pd.DataFrame(columns=['pid', 'elid', 'type', 'n_nodes', 'nodes'])
# ---> 24         etypes, elids, enids = gmsh.model.mesh.getElements()
#      25         typedict = dict(zip(etypes, range(len(etypes))))
#      26         logging.debug(typedict)
#
# AttributeError: 'str' object has no attribute 'model'

# %%
import meshio

# %%
meshio.read("")

# %%
gmsh.model
# Out:
# gmsh.model

# %%
mesh.elements['nodes'].to_numpy()
# Out:
# array([list([2, 14, 92]), list([1, 5, 93]), list([3, 23, 90]),
#        list([4, 32, 91]), list([13, 2, 92]), list([40, 1, 93]),
#        list([22, 3, 90]), list([31, 4, 91]), list([106, 63, 108]),
#        list([66, 63, 106]), list([64, 107, 109]), list([64, 67, 107]),
#        list([65, 69, 109]), list([65, 109, 142]), list([55, 83, 103]),
#        list([54, 82, 102]), list([60, 85, 105]), list([58, 84, 104]),
#        list([83, 43, 103]), list([82, 42, 102]), list([85, 45, 105]),
#        list([84, 44, 104]), list([66, 46, 86]), list([67, 48, 87]),
#        list([68, 47, 88]), list([69, 49, 89]), list([87, 57, 98]),
#        list([86, 56, 99]), list([89, 61, 100]), list([88, 59, 101]),
#        list([68, 65, 142]), list([27, 28, 70]), list([36, 37, 71]),
#        list([18, 19, 72]), list([9, 10, 73]), list([72, 19, 118]),
#        list([73, 10, 119]), list([70, 28, 120]), list([71, 37, 121]),
#        list([46, 66, 130]), list([47, 68, 131]), list([67, 64, 132]),
#        list([48, 67, 132]), list([69, 65, 133]), list([49, 69, 133]),
#        list([42, 87, 98]), list([43, 86, 99]), list([44, 89, 100]),
#        list([45, 88, 101]), list([63, 66, 111]), list([65, 68, 113]),
#        list([108, 68, 142]), list([41, 106, 108]), list([107, 41, 109]),
#        list([57, 72, 118]), list([61, 73, 119]), list([56, 70, 120]),
#        list([59, 71, 121]), list([24, 25, 74]), list([33, 34, 75]),
#        list([15, 16, 76]), list([6, 7, 77]), list([20, 21, 78]),
#        list([11, 12, 80]), list([29, 30, 79]), list([38, 39, 81]),
#        list([27, 70, 94]), list([36, 71, 95]), list([18, 72, 96]),
#        list([9, 73, 97]), list([57, 78, 98]), list([56, 79, 99]),
#        list([61, 80, 100]), list([59, 81, 101]), list([70, 46, 134]),
#        list([71, 47, 135]), list([72, 48, 136]), list([73, 49, 137]),
#        list([82, 62, 110]), list([83, 63, 111]), list([84, 64, 112]),
#        list([85, 65, 113]), list([50, 74, 102]), list([51, 75, 103]),
#        list([52, 76, 104]), list([53, 77, 105]), list([42, 82, 110]),
#        list([43, 83, 111]), list([44, 84, 112]), list([45, 85, 113]),
#        list([62, 107, 110]), list([107, 67, 110]), list([64, 109, 112]),
#        list([109, 69, 112]), list([26, 27, 94]), list([35, 36, 95]),
#        list([17, 18, 96]), list([8, 9, 97]), list([86, 46, 138]),
#        list([87, 48, 140]), list([88, 47, 139]), list([89, 49, 141]),
#        list([24, 74, 122]), list([33, 75, 123]), list([15, 76, 124]),
#        list([6, 77, 125]), list([78, 21, 126]), list([80, 12, 127]),
#        list([79, 30, 128]), list([81, 39, 129]), list([75, 55, 103]),
#        list([74, 54, 102]), list([77, 60, 105]), list([76, 58, 104]),
#        list([78, 50, 98]), list([79, 51, 99]), list([80, 52, 100]),
#        list([81, 53, 101]), list([14, 15, 124]), list([23, 24, 122]),
#        list([5, 6, 125]), list([32, 33, 123]), list([21, 22, 126]),
#        list([12, 13, 127]), list([30, 31, 128]), list([39, 40, 129]),
#        list([94, 70, 134]), list([95, 71, 135]), list([96, 72, 136]),
#        list([97, 73, 137]), list([92, 14, 124]), list([93, 5, 125]),
#        list([90, 23, 122]), list([91, 32, 123]), list([22, 90, 126]),
#        list([13, 92, 127]), list([31, 91, 128]), list([40, 93, 129]),
#        list([98, 50, 102]), list([99, 51, 103]), list([100, 52, 104]),
#        list([101, 53, 105]), list([62, 82, 130]), list([63, 83, 131]),
#        list([64, 84, 132]), list([65, 85, 133]), list([46, 70, 138]),
#        list([47, 71, 139]), list([70, 56, 138]), list([71, 59, 139]),
#        list([48, 72, 140]), list([49, 73, 141]), list([72, 57, 140]),
#        list([73, 61, 141]), list([74, 25, 114]), list([75, 34, 115]),
#        list([79, 56, 120]), list([54, 74, 114]), list([55, 75, 115]),
#        list([78, 57, 118]), list([81, 59, 121]), list([80, 61, 119]),
#        list([29, 79, 120]), list([20, 78, 118]), list([38, 81, 121]),
#        list([11, 80, 119]), list([76, 16, 116]), list([77, 7, 117]),
#        list([58, 76, 116]), list([60, 77, 117]), list([82, 46, 130]),
#        list([83, 47, 131]), list([84, 48, 132]), list([85, 49, 133]),
#        list([106, 62, 130]), list([66, 106, 130]), list([108, 63, 131]),
#        list([68, 108, 131]), list([74, 50, 122]), list([75, 51, 123]),
#        list([50, 78, 126]), list([76, 52, 124]), list([51, 79, 128]),
#        list([77, 53, 125]), list([52, 80, 127]), list([53, 81, 129]),
#        list([82, 54, 134]), list([46, 82, 134]), list([83, 55, 135]),
#        list([47, 83, 135]), list([48, 84, 136]), list([84, 58, 136]),
#        list([85, 60, 137]), list([49, 85, 137]), list([66, 86, 111]),
#        list([86, 43, 111]), list([67, 87, 110]), list([87, 42, 110]),
#        list([68, 88, 113]), list([69, 89, 112]), list([88, 45, 113]),
#        list([89, 44, 112]), list([42, 98, 102]), list([43, 99, 103]),
#        list([44, 100, 104]), list([45, 101, 105]), list([50, 90, 122]),
#        list([51, 91, 123]), list([90, 50, 126]), list([91, 51, 128]),
#        list([52, 92, 124]), list([92, 52, 127]), list([53, 93, 125]),
#        list([93, 53, 129]), list([106, 41, 107]), list([62, 106, 107]),
#        list([26, 94, 114]), list([35, 95, 115]), list([94, 54, 114]),
#        list([95, 55, 115]), list([17, 96, 116]), list([8, 97, 117]),
#        list([96, 58, 116]), list([97, 60, 117]), list([25, 26, 114]),
#        list([34, 35, 115]), list([16, 17, 116]), list([7, 8, 117]),
#        list([19, 20, 118]), list([10, 11, 119]), list([28, 29, 120]),
#        list([37, 38, 121]), list([56, 86, 138]), list([57, 87, 140]),
#        list([59, 88, 139]), list([61, 89, 141]), list([54, 94, 134]),
#        list([55, 95, 135]), list([58, 96, 136]), list([60, 97, 137]),
#        list([109, 41, 142]), list([41, 108, 142])], dtype=object)

# %%
type(mesh.elements.values)
# Out:
# numpy.ndarray

# %%
type(mesh.nodes["x"])
# Out:
# pandas.core.series.Series

# %%
import pyvista as pv

mesh = pv.read("square_testing_gmsh_python.msh")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-02b58a1b32e4> in <module>
#       1 import pyvista as pv
#       2
# ----> 3 mesh = pv.read("square_testing_gmsh_python.msh")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyvista/utilities/fileio.py in read(filename, attrs)
#     183         except KeyError:
#     184             pass
# --> 185     raise IOError("This file was not able to be automatically read by pyvista.")
#     186
#     187
#
# OSError: This file was not able to be automatically read by pyvista.

# %%
view(geometries=mesh)
# Out:
# Viewer(geometries=[{'vtkClass': 'vtkPolyData', 'points': {'vtkClass': 'vtkPoints', 'name': '_points', 'numberO…

# %%
p = pv.Plotter()
p.add_mesh(mesh)
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13D4486A0>
