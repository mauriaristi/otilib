# %%
import scipy.sparse as spr
import sys
path2oti = '../../../build/'
sys.path.append(path2oti) # Add path to OTI library.

import pyoti.sparse as oti 
import pyoti.core   as coti 
import pyoti.fem    as fem 

# %matplotlib notebook
import matplotlib.pyplot as plt

e  = oti.e
np = oti.np

# %%
# Testing triangle:

fem.tri3.allocate(3)
fem.tri3.allocate_spatial(2,compute_Jinv = True)

# %%
fem.tri3.compute_jacobian()

# %%
fem.tri3
# Out:
# < elbaseso object:
#  - Object status: ---------------- Started
#  - Geometric type: --------------- elTriangle
#  - Kind of evaluation: ----------- elkindIso
#  - Number of derivatives: -------- 10
#  - Number of dimensions: --------- 2
#  - Number of basis: -------------- 3
#  - Integration Order: ------------ 3
#  - Object allocation: ------------ Allocated
#  - Number of Integration points: - 4
#  - Integration points:
#  ----   xi:
# sotife< nip: 4,
# (0) 0.333333
# (1) 0.2
# (2) 0.6
# (3) 0.2
# > ----  eta:
# sotife< nip: 4,
# (0) 0.333333
# (1) 0.2
# (2) 0.2
# (3) 0.6
# > ---- zeta:
# sotife< nip: 4,
# (0) 0
# (1) 0
# (2) 0
# (3) 0
# >
#  - Integration weights:
# sotife< nip: 4,
# (0) -0.28125
# (1) 0.260417
# (2) 0.260417
# (3) 0.260417
# >
#  - Evaluated basis functions:
#
#  ==== derN
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.333333
#  - Column 1
# (0,1) 0.333333
#  - Column 2
# (0,2) 0.333333
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.6
#  - Column 1
# (0,1) 0.2
#  - Column 2
# (0,2) 0.2
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.2
#  - Column 1
# (0,1) 0.6
#  - Column 2
# (0,2) 0.2
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.2
#  - Column 1
# (0,1) 0.2
#  - Column 2
# (0,2) 0.6
# >
# -------------------------
# >
#
#  ==== derNa
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# >
#
#  ==== derNb
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# >
#
#  ==== derNc
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# >
#
#  ==== derN
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.333333
#  - Column 1
# (0,1) 0.333333
#  - Column 2
# (0,2) 0.333333
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.6
#  - Column 1
# (0,1) 0.2
#  - Column 2
# (0,2) 0.2
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.2
#  - Column 1
# (0,1) 0.6
#  - Column 2
# (0,2) 0.2
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.2
#  - Column 1
# (0,1) 0.2
#  - Column 2
# (0,2) 0.6
# >
# -------------------------
# >
#
#  ==== derNa
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# >
#
#  ==== derNb
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# >
#
#  ==== derNc
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# >
#
#  ==== derN
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.333333
#  - Column 1
# (0,1) 0.333333
#  - Column 2
# (0,2) 0.333333
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.6
#  - Column 1
# (0,1) 0.2
#  - Column 2
# (0,2) 0.2
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.2
#  - Column 1
# (0,1) 0.6
#  - Column 2
# (0,2) 0.2
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0.2
#  - Column 1
# (0,1) 0.2
#  - Column 2
# (0,2) 0.6
# >
# -------------------------
# >
#
#  ==== derNa
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 1
#  - Column 2
# (0,2) 0
# >
# -------------------------
# >
#
#  ==== derNb
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) -1
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 1
# >
# -------------------------
# >
#
#  ==== derNc
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (1, 3),
#  - Column 0
# (0,0) 0
#  - Column 1
# (0,1) 0
#  - Column 2
# (0,2) 0
# >
# -------------------------
# >
# end elbaseso object >

# %%
x = oti.array([[ 6+oti.e(1,order=10)],
               [10],
               [10]
              ])

y = oti.array([[ 5],
               [ 1],
               [ 8]
              ])

z = oti.array([[ 0],
               [ 0],
               [ 0]
              ])

els = np.array([0,1,2])

# %%
fem.tri3.set_coordinates(x,y,z,els)

# %%
fem.tri3.compute_jacobian()

# %%
oti.transpose(fem.tri3.Nx)
# Out:
# matsofe< nip: 4,
# (Integration point - 0)
# -------------------------
# matso< shape: (3, 1),
#  - Column 0
# (0,0) -0.25 - 0.0625 * e([1]) - 0.015625 * e([[1,2]]) - 0.00390625 * e([[1,3]]) - 0.000976562 * e([[1,4]]) - 0.000244141 * e([[1,5]]) - 6.10352e-05 * e([[1,6]]) - 1.52588e-05 * e([[1,7]]) - 3.8147e-06 * e([[1,8]]) - 9.53674e-07 * e([[1,9]]) - 2.38419e-07 * e([[1,10]])
# (1,0) 0.107143 + 0.0267857 * e([1]) + 0.00669643 * e([[1,2]]) + 0.00167411 * e([[1,3]]) + 0.000418527 * e([[1,4]]) + 0.000104632 * e([[1,5]]) + 2.61579e-05 * e([[1,6]]) + 6.53948e-06 * e([[1,7]]) + 1.63487e-06 * e([[1,8]]) + 4.08718e-07 * e([[1,9]]) + 1.02179e-07 * e([[1,10]])
# (2,0) 0.142857 + 0.0357143 * e([1]) + 0.00892857 * e([[1,2]]) + 0.00223214 * e([[1,3]]) + 0.000558036 * e([[1,4]]) + 0.000139509 * e([[1,5]]) + 3.48772e-05 * e([[1,6]]) + 8.71931e-06 * e([[1,7]]) + 2.17983e-06 * e([[1,8]]) + 5.44957e-07 * e([[1,9]]) + 1.36239e-07 * e([[1,10]])
# >
# -------------------------
# (Integration point - 1)
# -------------------------
# matso< shape: (3, 1),
#  - Column 0
# (0,0) -0.25 - 0.0625 * e([1]) - 0.015625 * e([[1,2]]) - 0.00390625 * e([[1,3]]) - 0.000976562 * e([[1,4]]) - 0.000244141 * e([[1,5]]) - 6.10352e-05 * e([[1,6]]) - 1.52588e-05 * e([[1,7]]) - 3.8147e-06 * e([[1,8]]) - 9.53674e-07 * e([[1,9]]) - 2.38419e-07 * e([[1,10]])
# (1,0) 0.107143 + 0.0267857 * e([1]) + 0.00669643 * e([[1,2]]) + 0.00167411 * e([[1,3]]) + 0.000418527 * e([[1,4]]) + 0.000104632 * e([[1,5]]) + 2.61579e-05 * e([[1,6]]) + 6.53948e-06 * e([[1,7]]) + 1.63487e-06 * e([[1,8]]) + 4.08718e-07 * e([[1,9]]) + 1.02179e-07 * e([[1,10]])
# (2,0) 0.142857 + 0.0357143 * e([1]) + 0.00892857 * e([[1,2]]) + 0.00223214 * e([[1,3]]) + 0.000558036 * e([[1,4]]) + 0.000139509 * e([[1,5]]) + 3.48772e-05 * e([[1,6]]) + 8.71931e-06 * e([[1,7]]) + 2.17983e-06 * e([[1,8]]) + 5.44957e-07 * e([[1,9]]) + 1.36239e-07 * e([[1,10]])
# >
# -------------------------
# (Integration point - 2)
# -------------------------
# matso< shape: (3, 1),
#  - Column 0
# (0,0) -0.25 - 0.0625 * e([1]) - 0.015625 * e([[1,2]]) - 0.00390625 * e([[1,3]]) - 0.000976562 * e([[1,4]]) - 0.000244141 * e([[1,5]]) - 6.10352e-05 * e([[1,6]]) - 1.52588e-05 * e([[1,7]]) - 3.8147e-06 * e([[1,8]]) - 9.53674e-07 * e([[1,9]]) - 2.38419e-07 * e([[1,10]])
# (1,0) 0.107143 + 0.0267857 * e([1]) + 0.00669643 * e([[1,2]]) + 0.00167411 * e([[1,3]]) + 0.000418527 * e([[1,4]]) + 0.000104632 * e([[1,5]]) + 2.61579e-05 * e([[1,6]]) + 6.53948e-06 * e([[1,7]]) + 1.63487e-06 * e([[1,8]]) + 4.08718e-07 * e([[1,9]]) + 1.02179e-07 * e([[1,10]])
# (2,0) 0.142857 + 0.0357143 * e([1]) + 0.00892857 * e([[1,2]]) + 0.00223214 * e([[1,3]]) + 0.000558036 * e([[1,4]]) + 0.000139509 * e([[1,5]]) + 3.48772e-05 * e([[1,6]]) + 8.71931e-06 * e([[1,7]]) + 2.17983e-06 * e([[1,8]]) + 5.44957e-07 * e([[1,9]]) + 1.36239e-07 * e([[1,10]])
# >
# -------------------------
# (Integration point - 3)
# -------------------------
# matso< shape: (3, 1),
#  - Column 0
# (0,0) -0.25 - 0.0625 * e([1]) - 0.015625 * e([[1,2]]) - 0.00390625 * e([[1,3]]) - 0.000976562 * e([[1,4]]) - 0.000244141 * e([[1,5]]) - 6.10352e-05 * e([[1,6]]) - 1.52588e-05 * e([[1,7]]) - 3.8147e-06 * e([[1,8]]) - 9.53674e-07 * e([[1,9]]) - 2.38419e-07 * e([[1,10]])
# (1,0) 0.107143 + 0.0267857 * e([1]) + 0.00669643 * e([[1,2]]) + 0.00167411 * e([[1,3]]) + 0.000418527 * e([[1,4]]) + 0.000104632 * e([[1,5]]) + 2.61579e-05 * e([[1,6]]) + 6.53948e-06 * e([[1,7]]) + 1.63487e-06 * e([[1,8]]) + 4.08718e-07 * e([[1,9]]) + 1.02179e-07 * e([[1,10]])
# (2,0) 0.142857 + 0.0357143 * e([1]) + 0.00892857 * e([[1,2]]) + 0.00223214 * e([[1,3]]) + 0.000558036 * e([[1,4]]) + 0.000139509 * e([[1,5]]) + 3.48772e-05 * e([[1,6]]) + 8.71931e-06 * e([[1,7]]) + 2.17983e-06 * e([[1,8]]) + 5.44957e-07 * e([[1,9]]) + 1.36239e-07 * e([[1,10]])
# >
# -------------------------
# >

# %%
val = oti.gauss_integrate(oti.one(nip=fem.tri3.nip),fem.tri3.w_dJ)
val
# Out:
# 14.0000 - 3.5000 * e([1])

# %%
val.taylor_integrate(bases=[1],deltas=[1])
# Out:
# 10.5000

# %%
fem.tri3.w_dJ,fem.tri3.w
# Out:
# (sotife< nip: 4,
#  (0) -9.84375
#  (1) 9.11458
#  (2) 9.11458
#  (3) 9.11458
#  >, sotife< nip: 4,
#  (0) -0.28125
#  (1) 0.260417
#  (2) 0.260417
#  (3) 0.260417
#  >)

# %%
35/2
# Out:
# 17.5

# %%
fem.tri3.xi.real
# Out:
# array([0.33333333, 0.2       , 0.6       , 0.2       ])

# %%
plt.figure()

plt.plot( [0,1,0,0], [0,0,1,0],'-k' )
plt.plot(fem.tri3.xi.real, fem.tri3.eta.real,'xr' )

plt.axis('equal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()

plt.fill( fem.tri3.x.real, fem.tri3.y.real,'-C0' )
plt.plot( fem.tri3.x.real, fem.tri3.y.real,'oC1' )

xval = oti.dot(fem.tri3.N,fem.tri3.x)[0,0]
yval = oti.dot(fem.tri3.N,fem.tri3.y)[0,0]

plt.plot( xval.real, yval.real,'xC3' )
plt.axis('equal')
plt.grid(which='major')
plt.grid(which='minor')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %timeit oti.gauss_integrate(xval**3,fem.tri3.w_dJ)
# Out:
# 885 ns ± 3.04 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
