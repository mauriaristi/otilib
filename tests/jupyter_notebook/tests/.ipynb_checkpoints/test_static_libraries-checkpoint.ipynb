# %%
import sys
import timeit
path2oti = '../../../build/'
sys.path.append(path2oti) # Add path to OTI library.

import pyoti.core      as coti

import pyoti.real      as r
import pyoti.sparse    as oti

# Static libraries:
# Dual
import pyoti.onumm1n1  as dual

# Multiduals
import pyoti.mdnum2    as md2
import pyoti.mdnum3    as md3
import pyoti.mdnum4    as md4
import pyoti.mdnum5    as md5

# OTI.
import pyoti.onumm1n2  as om1n2 
import pyoti.onumm1n3  as om1n3 
import pyoti.onumm1n5  as om1n5 
import pyoti.onumm2n2  as om2n2 
import pyoti.onumm3n3  as om3n3 
import pyoti.onumm1n10 as om1n10
import pyoti.onumm10n1 as om10n1
import pyoti.onumm2n5  as om2n5 

np = oti.np


modules = [r, dual, md2, md3, md4, md5, om1n2, om1n3, om1n5, om2n2, om3n3, om1n10, om10n1, om2n5]

# %%
len('scalar gauss_integrate(xg,xg)')
# Out:
# 29

# %%
report_length = 40 
def report_times():
    for i in range(len(modules)):
        mname = modules[i].__name__
        print(mname+" ::::")
        for key1, items1 in times[i].items():
            for key2, items2 in items1.items():
                str_out = key1+" "+key2 + ' '
                str_out += '-'*(int(report_length-len(str_out))) 
                print(str_out+" {0:15.4f} ns".format((items2)) )
        print()
        print()
        print()
        
def report_times_comp_real():
    mreal = modules[0]
    treal = times[0]
    for i in range(1,len(modules)):
        mname = modules[i].__name__
        print(mname+" ::::")
        for key1, items1 in times[i].items():
            for key2, items2 in items1.items():
                item_real = treal[key1][key2]
                str_out = key1+" "+key2 + ' '
                str_out += '-'*(int(report_length-len(str_out))) 
                print(str_out+" {0:15.2f}X".format((items2/item_real)) )
        print()
        print()
        print()

# %%
times = []
niter = int(1e5)
for module in modules:
    
    print("Analyzing "+module.__name__)
    times.append({})
    times[-1]['scalar']={}
    times[-1]['gauss_scalar']={}
    times[-1]['array']={}
    times[-1]['gauss_array']={}

    niter = int(1e5)
    
    x  = module.number(0.5)
    xout = x.copy()
    X  = module.zeros((3,3))
    Xout = X.copy()
    xg = module.number(0.5,  nip=27)
    xgout = xg.copy()
    Xg = module.zeros((3,3), nip=27)
    Xgout = Xg.copy()

    expr = 'x+x'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'x*x'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sin(x)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.pow(x,100.)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'X+X'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'X*X'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.dot(X,X)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sin(X)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sum(x,x,out=xout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.mul(x,x,out=xout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sin(x, out=xout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.pow(x,100., out=xout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sum(X,X,out=Xout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.mul(X,X,out=Xout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.dot(X,X,out=Xout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sin(X,out=Xout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    
    
    
    
    niter = int(1e4)
    expr = 'xg+xg'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'xg*xg'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sin(xg)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.gauss_integrate(xg,xg)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    
    
    expr = 'Xg+Xg'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'Xg*Xg'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.dot(Xg,Xg)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sin(Xg)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.gauss_integrate(Xg,xg)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    
    
    
    expr = 'module.sum(xg,xg,out=xgout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.mul(xg,xg,out=xgout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sin(xg,out=xgout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.gauss_integrate(xg,xg, out=xgout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['scalar'][expr.replace('module.','')]=time/float(niter)*1e9
    
    
    
    expr = 'module.sum(Xg,Xg,out=Xgout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.mul(Xg,Xg,out=Xgout)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.dot(Xg,Xg)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.sin(Xg)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    
    expr = 'module.gauss_integrate(Xg,xg)'
    time = timeit.timeit (expr,globals=globals(), number =niter)
    times[-1]['gauss_array'][expr.replace('module.','')]=time/float(niter)*1e9
    

# end for 
print("Finished")
# Out:
# Analyzing pyoti.real
# Analyzing pyoti.onumm1n1
# Analyzing pyoti.mdnum2
# Analyzing pyoti.mdnum3
# Analyzing pyoti.mdnum4
# Analyzing pyoti.mdnum5
# Analyzing pyoti.onumm1n2
# Analyzing pyoti.onumm1n3
# Analyzing pyoti.onumm1n5
# Analyzing pyoti.onumm2n2
# Analyzing pyoti.onumm3n3
# Analyzing pyoti.onumm1n10
# Analyzing pyoti.onumm10n1
# Analyzing pyoti.onumm2n5
# Finished

# %%
report_times()
# Out:
# pyoti.real ::::
# scalar x+x -----------------------------         46.9002 ns
# scalar x*x -----------------------------         47.9003 ns
# scalar sin(x) --------------------------      34981.6216 ns
# scalar pow(x,100.) ---------------------      35109.6456 ns
# scalar xg+xg ---------------------------        214.1845 ns
# scalar xg*xg ---------------------------        200.8744 ns
# scalar sin(xg) -------------------------        412.4792 ns
# scalar gauss_integrate(xg,xg) ----------        158.3919 ns
# array X+X ------------------------------        215.4491 ns
# array X*X ------------------------------        221.6272 ns
# array dot(X,X) -------------------------        343.9888 ns
# array sin(X) ---------------------------        295.4683 ns
# gauss_array Xg+Xg ----------------------       8046.4698 ns
# gauss_array Xg*Xg ----------------------       7544.1003 ns
# gauss_array dot(Xg,Xg) -----------------       8764.8825 ns
# gauss_array sin(Xg) --------------------       8106.0519 ns
# gauss_array gauss_integrate(Xg,xg) -----        564.1710 ns
#
#
#
# pyoti.onumm1n1 ::::
# scalar x+x -----------------------------         73.7019 ns
# scalar x*x -----------------------------         79.4084 ns
# scalar sin(x) --------------------------        172.7038 ns
# scalar pow(x,100.) ---------------------        184.2390 ns
# scalar xg+xg ---------------------------        323.6428 ns
# scalar xg*xg ---------------------------        471.1224 ns
# scalar sin(xg) -------------------------       1135.4554 ns
# scalar gauss_integrate(xg,xg) ----------        234.2823 ns
# array X+X ------------------------------        402.8966 ns
# array X*X ------------------------------        336.9424 ns
# array dot(X,X) -------------------------        489.2858 ns
# array sin(X) ---------------------------        602.4420 ns
# gauss_array Xg+Xg ----------------------       6448.7481 ns
# gauss_array Xg*Xg ----------------------       5672.0200 ns
# gauss_array dot(Xg,Xg) -----------------       6186.8605 ns
# gauss_array sin(Xg) --------------------       8174.3830 ns
# gauss_array gauss_integrate(Xg,xg) -----       1131.9001 ns
#
#
#
# pyoti.mdnum2 ::::
# scalar x+x -----------------------------         82.4196 ns
# scalar x*x -----------------------------         82.7445 ns
# scalar sin(x) --------------------------        188.3463 ns
# scalar pow(x,100.) ---------------------        209.8888 ns
# scalar xg+xg ---------------------------        345.7944 ns
# scalar xg*xg ---------------------------        324.7951 ns
# scalar sin(xg) -------------------------       1014.7273 ns
# scalar gauss_integrate(xg,xg) ----------        283.5345 ns
# array X+X ------------------------------        281.1325 ns
# array X*X ------------------------------        294.9971 ns
# array dot(X,X) -------------------------        512.8672 ns
# array sin(X) ---------------------------        600.4873 ns
# gauss_array Xg+Xg ----------------------       7916.3807 ns
# gauss_array Xg*Xg ----------------------       8184.1181 ns
# gauss_array dot(Xg,Xg) -----------------       9620.9954 ns
# gauss_array sin(Xg) --------------------      11494.7831 ns
# gauss_array gauss_integrate(Xg,xg) -----       1436.5190 ns
#
#
#
# pyoti.mdnum3 ::::
# scalar x+x -----------------------------         82.5598 ns
# scalar x*x -----------------------------         90.9082 ns
# scalar sin(x) --------------------------        210.8399 ns
# scalar pow(x,100.) ---------------------        231.8698 ns
# scalar xg+xg ---------------------------        245.5369 ns
# scalar xg*xg ---------------------------        409.0615 ns
# scalar sin(xg) -------------------------       1446.8919 ns
# scalar gauss_integrate(xg,xg) ----------        418.8958 ns
# array X+X ------------------------------        294.4647 ns
# array X*X ------------------------------        340.5231 ns
# array dot(X,X) -------------------------        880.5454 ns
# array sin(X) ---------------------------       1044.1128 ns
# gauss_array Xg+Xg ----------------------      13599.9909 ns
# gauss_array Xg*Xg ----------------------      16303.4196 ns
# gauss_array dot(Xg,Xg) -----------------      20630.5885 ns
# gauss_array sin(Xg) --------------------      22788.1943 ns
# gauss_array gauss_integrate(Xg,xg) -----       3074.4476 ns
#
#
#
# pyoti.mdnum4 ::::
# scalar x+x -----------------------------        105.2237 ns
# scalar x*x -----------------------------        121.8762 ns
# scalar sin(x) --------------------------        336.7601 ns
# scalar pow(x,100.) ---------------------        374.1149 ns
# scalar xg+xg ---------------------------        270.8127 ns
# scalar xg*xg ---------------------------        729.6413 ns
# scalar sin(xg) -------------------------       4295.6632 ns
# scalar gauss_integrate(xg,xg) ----------        876.8332 ns
# array X+X ------------------------------       1204.4176 ns
# array X*X ------------------------------       1373.3995 ns
# array dot(X,X) -------------------------       2074.1143 ns
# array sin(X) ---------------------------       2560.5663 ns
# gauss_array Xg+Xg ----------------------      28694.3950 ns
# gauss_array Xg*Xg ----------------------      35261.3964 ns
# gauss_array dot(Xg,Xg) -----------------      53795.4698 ns
# gauss_array sin(Xg) --------------------      66759.0646 ns
# gauss_array gauss_integrate(Xg,xg) -----       7374.8102 ns
#
#
#
# pyoti.mdnum5 ::::
# scalar x+x -----------------------------        102.0336 ns
# scalar x*x -----------------------------        230.2857 ns
# scalar sin(x) --------------------------        631.8186 ns
# scalar pow(x,100.) ---------------------        700.9883 ns
# scalar xg+xg ---------------------------        399.5095 ns
# scalar xg*xg ---------------------------       2317.5723 ns
# scalar sin(xg) -------------------------      13313.5801 ns
# scalar gauss_integrate(xg,xg) ----------       2346.1695 ns
# array X+X ------------------------------        813.9572 ns
# array X*X ------------------------------       2487.7230 ns
# array dot(X,X) -------------------------       4546.7269 ns
# array sin(X) ---------------------------       6729.9494 ns
# gauss_array Xg+Xg ----------------------      47748.4000 ns
# gauss_array Xg*Xg ----------------------      65143.7283 ns
# gauss_array dot(Xg,Xg) -----------------     110120.3122 ns
# gauss_array sin(Xg) --------------------     166252.9045 ns
# gauss_array gauss_integrate(Xg,xg) -----      23746.1480 ns
#
#
#
# pyoti.onumm1n2 ::::
# scalar x+x -----------------------------         78.6940 ns
# scalar x*x -----------------------------         79.5302 ns
# scalar sin(x) --------------------------        189.2369 ns
# scalar pow(x,100.) ---------------------        204.1399 ns
# scalar xg+xg ---------------------------        293.9326 ns
# scalar xg*xg ---------------------------        344.8497 ns
# scalar sin(xg) -------------------------        913.5623 ns
# scalar gauss_integrate(xg,xg) ----------        225.3855 ns
# array X+X ------------------------------        360.8027 ns
# array X*X ------------------------------        348.0692 ns
# array dot(X,X) -------------------------        482.5787 ns
# array sin(X) ---------------------------        524.6036 ns
# gauss_array Xg+Xg ----------------------       6369.4317 ns
# gauss_array Xg*Xg ----------------------       6992.7873 ns
# gauss_array dot(Xg,Xg) -----------------       8388.2007 ns
# gauss_array sin(Xg) --------------------       9792.9395 ns
# gauss_array gauss_integrate(Xg,xg) -----       1229.7181 ns
#
#
#
# pyoti.onumm1n3 ::::
# scalar x+x -----------------------------         80.7215 ns
# scalar x*x -----------------------------         85.8758 ns
# scalar sin(x) --------------------------        199.8564 ns
# scalar pow(x,100.) ---------------------        234.9651 ns
# scalar xg+xg ---------------------------        323.8552 ns
# scalar xg*xg ---------------------------        370.7344 ns
# scalar sin(xg) -------------------------       1268.8909 ns
# scalar gauss_integrate(xg,xg) ----------        283.4596 ns
# array X+X ------------------------------        438.0022 ns
# array X*X ------------------------------        317.7326 ns
# array dot(X,X) -------------------------        654.9198 ns
# array sin(X) ---------------------------        702.1387 ns
# gauss_array Xg+Xg ----------------------       7691.4502 ns
# gauss_array Xg*Xg ----------------------       8008.9083 ns
# gauss_array dot(Xg,Xg) -----------------      10626.0665 ns
# gauss_array sin(Xg) --------------------      12085.0546 ns
# gauss_array gauss_integrate(Xg,xg) -----       1428.9179 ns
#
#
#
# pyoti.onumm1n5 ::::
# scalar x+x -----------------------------         85.4241 ns
# scalar x*x -----------------------------         88.3307 ns
# scalar sin(x) --------------------------        217.4203 ns
# scalar pow(x,100.) ---------------------        259.6914 ns
# scalar xg+xg ---------------------------        213.2399 ns
# scalar xg*xg ---------------------------        416.7648 ns
# scalar sin(xg) -------------------------       1786.8172 ns
# scalar gauss_integrate(xg,xg) ----------        348.2941 ns
# array X+X ------------------------------        274.5808 ns
# array X*X ------------------------------        319.9383 ns
# array dot(X,X) -------------------------        744.3529 ns
# array sin(X) ---------------------------        975.2520 ns
# gauss_array Xg+Xg ----------------------       9888.1934 ns
# gauss_array Xg*Xg ----------------------      11957.0127 ns
# gauss_array dot(Xg,Xg) -----------------      16120.9831 ns
# gauss_array sin(Xg) --------------------      22019.5861 ns
# gauss_array gauss_integrate(Xg,xg) -----       2393.3872 ns
#
#
#
# pyoti.onumm2n2 ::::
# scalar x+x -----------------------------         80.1778 ns
# scalar x*x -----------------------------         83.5019 ns
# scalar sin(x) --------------------------        197.4904 ns
# scalar pow(x,100.) ---------------------        207.6127 ns
# scalar xg+xg ---------------------------        252.9744 ns
# scalar xg*xg ---------------------------        317.7679 ns
# scalar sin(xg) -------------------------       1124.2098 ns
# scalar gauss_integrate(xg,xg) ----------        332.3149 ns
# array X+X ------------------------------        266.5970 ns
# array X*X ------------------------------        322.2854 ns
# array dot(X,X) -------------------------        759.0849 ns
# array sin(X) ---------------------------        796.1187 ns
# gauss_array Xg+Xg ----------------------       9976.0374 ns
# gauss_array Xg*Xg ----------------------      10334.9746 ns
# gauss_array dot(Xg,Xg) -----------------      14920.6295 ns
# gauss_array sin(Xg) --------------------      14626.9609 ns
# gauss_array gauss_integrate(Xg,xg) -----       1674.8434 ns
#
#
#
# pyoti.onumm3n3 ::::
# scalar x+x -----------------------------         95.6142 ns
# scalar x*x -----------------------------        112.9430 ns
# scalar sin(x) --------------------------        273.6846 ns
# scalar pow(x,100.) ---------------------        309.9484 ns
# scalar xg+xg ---------------------------        351.3053 ns
# scalar xg*xg ---------------------------        941.1365 ns
# scalar sin(xg) -------------------------       3308.2570 ns
# scalar gauss_integrate(xg,xg) ----------        819.3468 ns
# array X+X ------------------------------       1163.0549 ns
# array X*X ------------------------------       1434.3598 ns
# array dot(X,X) -------------------------       2098.5553 ns
# array sin(X) ---------------------------       2227.2135 ns
# gauss_array Xg+Xg ----------------------      28912.4713 ns
# gauss_array Xg*Xg ----------------------      33962.1432 ns
# gauss_array dot(Xg,Xg) -----------------      49862.7080 ns
# gauss_array sin(Xg) --------------------      62018.0342 ns
# gauss_array gauss_integrate(Xg,xg) -----       7933.7752 ns
#
#
#
# pyoti.onumm1n10 ::::
# scalar x+x -----------------------------         95.8553 ns
# scalar x*x -----------------------------        116.9254 ns
# scalar sin(x) --------------------------        566.6650 ns
# scalar pow(x,100.) ---------------------        663.9188 ns
# scalar xg+xg ---------------------------        241.5849 ns
# scalar xg*xg ---------------------------        730.0625 ns
# scalar sin(xg) -------------------------       9118.4543 ns
# scalar gauss_integrate(xg,xg) ----------        762.0403 ns
# array X+X ------------------------------        324.5607 ns
# array X*X ------------------------------        881.8308 ns
# array dot(X,X) -------------------------       1529.7318 ns
# array sin(X) ---------------------------       3589.5743 ns
# gauss_array Xg+Xg ----------------------      15979.0440 ns
# gauss_array Xg*Xg ----------------------      21357.5365 ns
# gauss_array dot(Xg,Xg) -----------------      36493.5003 ns
# gauss_array sin(Xg) --------------------     104028.8228 ns
# gauss_array gauss_integrate(Xg,xg) -----       7272.8166 ns
#
#
#
# pyoti.onumm10n1 ::::
# scalar x+x -----------------------------        103.7869 ns
# scalar x*x -----------------------------        111.7888 ns
# scalar sin(x) --------------------------        224.7467 ns
# scalar pow(x,100.) ---------------------        244.3190 ns
# scalar xg+xg ---------------------------        606.1737 ns
# scalar xg*xg ---------------------------        463.4587 ns
# scalar sin(xg) -------------------------       1597.5319 ns
# scalar gauss_integrate(xg,xg) ----------        553.3593 ns
# array X+X ------------------------------        331.6488 ns
# array X*X ------------------------------        489.6820 ns
# array dot(X,X) -------------------------       1977.6924 ns
# array sin(X) ---------------------------       1752.2450 ns
# gauss_array Xg+Xg ----------------------      23477.0869 ns
# gauss_array Xg*Xg ----------------------      21286.5017 ns
# gauss_array dot(Xg,Xg) -----------------      22180.7192 ns
# gauss_array sin(Xg) --------------------      19928.1987 ns
# gauss_array gauss_integrate(Xg,xg) -----       2995.4374 ns
#
#
#
# pyoti.onumm2n5 ::::
# scalar x+x -----------------------------        109.1938 ns
# scalar x*x -----------------------------        153.2100 ns
# scalar sin(x) --------------------------        469.3558 ns
# scalar pow(x,100.) ---------------------        528.7737 ns
# scalar xg+xg ---------------------------        659.3692 ns
# scalar xg*xg ---------------------------       1620.4129 ns
# scalar sin(xg) -------------------------       9266.0577 ns
# scalar gauss_integrate(xg,xg) ----------       1525.3607 ns
# array X+X ------------------------------       1010.1163 ns
# array X*X ------------------------------       1597.8048 ns
# array dot(X,X) -------------------------       2809.8445 ns
# array sin(X) ---------------------------       4406.2748 ns
# gauss_array Xg+Xg ----------------------      35610.9522 ns
# gauss_array Xg*Xg ----------------------      44869.1239 ns
# gauss_array dot(Xg,Xg) -----------------      68263.4149 ns
# gauss_array sin(Xg) --------------------     106049.7775 ns
# gauss_array gauss_integrate(Xg,xg) -----      12650.4283 ns

# %%
report_times_comp_real()
# Out:
# pyoti.onumm1n1 ::::
# scalar x+x -----------------------------            1.57X
# scalar x*x -----------------------------            1.66X
# scalar sin(x) --------------------------            0.00X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.51X
# scalar xg*xg ---------------------------            2.35X
# scalar sin(xg) -------------------------            2.75X
# scalar gauss_integrate(xg,xg) ----------            1.48X
# array X+X ------------------------------            1.87X
# array X*X ------------------------------            1.52X
# array dot(X,X) -------------------------            1.42X
# array sin(X) ---------------------------            2.04X
# gauss_array Xg+Xg ----------------------            0.80X
# gauss_array Xg*Xg ----------------------            0.75X
# gauss_array dot(Xg,Xg) -----------------            0.71X
# gauss_array sin(Xg) --------------------            1.01X
# gauss_array gauss_integrate(Xg,xg) -----            2.01X
#
#
#
# pyoti.mdnum2 ::::
# scalar x+x -----------------------------            1.76X
# scalar x*x -----------------------------            1.73X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.61X
# scalar xg*xg ---------------------------            1.62X
# scalar sin(xg) -------------------------            2.46X
# scalar gauss_integrate(xg,xg) ----------            1.79X
# array X+X ------------------------------            1.30X
# array X*X ------------------------------            1.33X
# array dot(X,X) -------------------------            1.49X
# array sin(X) ---------------------------            2.03X
# gauss_array Xg+Xg ----------------------            0.98X
# gauss_array Xg*Xg ----------------------            1.08X
# gauss_array dot(Xg,Xg) -----------------            1.10X
# gauss_array sin(Xg) --------------------            1.42X
# gauss_array gauss_integrate(Xg,xg) -----            2.55X
#
#
#
# pyoti.mdnum3 ::::
# scalar x+x -----------------------------            1.76X
# scalar x*x -----------------------------            1.90X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.15X
# scalar xg*xg ---------------------------            2.04X
# scalar sin(xg) -------------------------            3.51X
# scalar gauss_integrate(xg,xg) ----------            2.64X
# array X+X ------------------------------            1.37X
# array X*X ------------------------------            1.54X
# array dot(X,X) -------------------------            2.56X
# array sin(X) ---------------------------            3.53X
# gauss_array Xg+Xg ----------------------            1.69X
# gauss_array Xg*Xg ----------------------            2.16X
# gauss_array dot(Xg,Xg) -----------------            2.35X
# gauss_array sin(Xg) --------------------            2.81X
# gauss_array gauss_integrate(Xg,xg) -----            5.45X
#
#
#
# pyoti.mdnum4 ::::
# scalar x+x -----------------------------            2.24X
# scalar x*x -----------------------------            2.54X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.26X
# scalar xg*xg ---------------------------            3.63X
# scalar sin(xg) -------------------------           10.41X
# scalar gauss_integrate(xg,xg) ----------            5.54X
# array X+X ------------------------------            5.59X
# array X*X ------------------------------            6.20X
# array dot(X,X) -------------------------            6.03X
# array sin(X) ---------------------------            8.67X
# gauss_array Xg+Xg ----------------------            3.57X
# gauss_array Xg*Xg ----------------------            4.67X
# gauss_array dot(Xg,Xg) -----------------            6.14X
# gauss_array sin(Xg) --------------------            8.24X
# gauss_array gauss_integrate(Xg,xg) -----           13.07X
#
#
#
# pyoti.mdnum5 ::::
# scalar x+x -----------------------------            2.18X
# scalar x*x -----------------------------            4.81X
# scalar sin(x) --------------------------            0.02X
# scalar pow(x,100.) ---------------------            0.02X
# scalar xg+xg ---------------------------            1.87X
# scalar xg*xg ---------------------------           11.54X
# scalar sin(xg) -------------------------           32.28X
# scalar gauss_integrate(xg,xg) ----------           14.81X
# array X+X ------------------------------            3.78X
# array X*X ------------------------------           11.22X
# array dot(X,X) -------------------------           13.22X
# array sin(X) ---------------------------           22.78X
# gauss_array Xg+Xg ----------------------            5.93X
# gauss_array Xg*Xg ----------------------            8.64X
# gauss_array dot(Xg,Xg) -----------------           12.56X
# gauss_array sin(Xg) --------------------           20.51X
# gauss_array gauss_integrate(Xg,xg) -----           42.09X
#
#
#
# pyoti.onumm1n2 ::::
# scalar x+x -----------------------------            1.68X
# scalar x*x -----------------------------            1.66X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.37X
# scalar xg*xg ---------------------------            1.72X
# scalar sin(xg) -------------------------            2.21X
# scalar gauss_integrate(xg,xg) ----------            1.42X
# array X+X ------------------------------            1.67X
# array X*X ------------------------------            1.57X
# array dot(X,X) -------------------------            1.40X
# array sin(X) ---------------------------            1.78X
# gauss_array Xg+Xg ----------------------            0.79X
# gauss_array Xg*Xg ----------------------            0.93X
# gauss_array dot(Xg,Xg) -----------------            0.96X
# gauss_array sin(Xg) --------------------            1.21X
# gauss_array gauss_integrate(Xg,xg) -----            2.18X
#
#
#
# pyoti.onumm1n3 ::::
# scalar x+x -----------------------------            1.72X
# scalar x*x -----------------------------            1.79X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.51X
# scalar xg*xg ---------------------------            1.85X
# scalar sin(xg) -------------------------            3.08X
# scalar gauss_integrate(xg,xg) ----------            1.79X
# array X+X ------------------------------            2.03X
# array X*X ------------------------------            1.43X
# array dot(X,X) -------------------------            1.90X
# array sin(X) ---------------------------            2.38X
# gauss_array Xg+Xg ----------------------            0.96X
# gauss_array Xg*Xg ----------------------            1.06X
# gauss_array dot(Xg,Xg) -----------------            1.21X
# gauss_array sin(Xg) --------------------            1.49X
# gauss_array gauss_integrate(Xg,xg) -----            2.53X
#
#
#
# pyoti.onumm1n5 ::::
# scalar x+x -----------------------------            1.82X
# scalar x*x -----------------------------            1.84X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.00X
# scalar xg*xg ---------------------------            2.07X
# scalar sin(xg) -------------------------            4.33X
# scalar gauss_integrate(xg,xg) ----------            2.20X
# array X+X ------------------------------            1.27X
# array X*X ------------------------------            1.44X
# array dot(X,X) -------------------------            2.16X
# array sin(X) ---------------------------            3.30X
# gauss_array Xg+Xg ----------------------            1.23X
# gauss_array Xg*Xg ----------------------            1.58X
# gauss_array dot(Xg,Xg) -----------------            1.84X
# gauss_array sin(Xg) --------------------            2.72X
# gauss_array gauss_integrate(Xg,xg) -----            4.24X
#
#
#
# pyoti.onumm2n2 ::::
# scalar x+x -----------------------------            1.71X
# scalar x*x -----------------------------            1.74X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.18X
# scalar xg*xg ---------------------------            1.58X
# scalar sin(xg) -------------------------            2.73X
# scalar gauss_integrate(xg,xg) ----------            2.10X
# array X+X ------------------------------            1.24X
# array X*X ------------------------------            1.45X
# array dot(X,X) -------------------------            2.21X
# array sin(X) ---------------------------            2.69X
# gauss_array Xg+Xg ----------------------            1.24X
# gauss_array Xg*Xg ----------------------            1.37X
# gauss_array dot(Xg,Xg) -----------------            1.70X
# gauss_array sin(Xg) --------------------            1.80X
# gauss_array gauss_integrate(Xg,xg) -----            2.97X
#
#
#
# pyoti.onumm3n3 ::::
# scalar x+x -----------------------------            2.04X
# scalar x*x -----------------------------            2.36X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            1.64X
# scalar xg*xg ---------------------------            4.69X
# scalar sin(xg) -------------------------            8.02X
# scalar gauss_integrate(xg,xg) ----------            5.17X
# array X+X ------------------------------            5.40X
# array X*X ------------------------------            6.47X
# array dot(X,X) -------------------------            6.10X
# array sin(X) ---------------------------            7.54X
# gauss_array Xg+Xg ----------------------            3.59X
# gauss_array Xg*Xg ----------------------            4.50X
# gauss_array dot(Xg,Xg) -----------------            5.69X
# gauss_array sin(Xg) --------------------            7.65X
# gauss_array gauss_integrate(Xg,xg) -----           14.06X
#
#
#
# pyoti.onumm1n10 ::::
# scalar x+x -----------------------------            2.04X
# scalar x*x -----------------------------            2.44X
# scalar sin(x) --------------------------            0.02X
# scalar pow(x,100.) ---------------------            0.02X
# scalar xg+xg ---------------------------            1.13X
# scalar xg*xg ---------------------------            3.63X
# scalar sin(xg) -------------------------           22.11X
# scalar gauss_integrate(xg,xg) ----------            4.81X
# array X+X ------------------------------            1.51X
# array X*X ------------------------------            3.98X
# array dot(X,X) -------------------------            4.45X
# array sin(X) ---------------------------           12.15X
# gauss_array Xg+Xg ----------------------            1.99X
# gauss_array Xg*Xg ----------------------            2.83X
# gauss_array dot(Xg,Xg) -----------------            4.16X
# gauss_array sin(Xg) --------------------           12.83X
# gauss_array gauss_integrate(Xg,xg) -----           12.89X
#
#
#
# pyoti.onumm10n1 ::::
# scalar x+x -----------------------------            2.21X
# scalar x*x -----------------------------            2.33X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.01X
# scalar xg+xg ---------------------------            2.83X
# scalar xg*xg ---------------------------            2.31X
# scalar sin(xg) -------------------------            3.87X
# scalar gauss_integrate(xg,xg) ----------            3.49X
# array X+X ------------------------------            1.54X
# array X*X ------------------------------            2.21X
# array dot(X,X) -------------------------            5.75X
# array sin(X) ---------------------------            5.93X
# gauss_array Xg+Xg ----------------------            2.92X
# gauss_array Xg*Xg ----------------------            2.82X
# gauss_array dot(Xg,Xg) -----------------            2.53X
# gauss_array sin(Xg) --------------------            2.46X
# gauss_array gauss_integrate(Xg,xg) -----            5.31X
#
#
#
# pyoti.onumm2n5 ::::
# scalar x+x -----------------------------            2.33X
# scalar x*x -----------------------------            3.20X
# scalar sin(x) --------------------------            0.01X
# scalar pow(x,100.) ---------------------            0.02X
# scalar xg+xg ---------------------------            3.08X
# scalar xg*xg ---------------------------            8.07X
# scalar sin(xg) -------------------------           22.46X
# scalar gauss_integrate(xg,xg) ----------            9.63X
# array X+X ------------------------------            4.69X
# array X*X ------------------------------            7.21X
# array dot(X,X) -------------------------            8.17X
# array sin(X) ---------------------------           14.91X
# gauss_array Xg+Xg ----------------------            4.43X
# gauss_array Xg*Xg ----------------------            5.95X
# gauss_array dot(Xg,Xg) -----------------            7.79X
# gauss_array sin(Xg) --------------------           13.08X
# gauss_array gauss_integrate(Xg,xg) -----           22.42X

# %%
# Test Scalar

module = md2

x = 0.5+module.e(1)+module.e(2)
print(module.__name__+" - Scalar")
print("(Scalar) Addition")
# %timeit x+x
print("\n(Scalar) Multiplication")
# %timeit x*x
print("\n(Scalar) Function - sine")
# %timeit module.sin(x)
print("\n(Scalar) Function - x**100")
# %timeit module.pow(x,100.)
# Out:
# pyoti.mdnum2 - Scalar
# (Scalar) Addition
# 81.2 ns ± 1.66 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
#
# (Scalar) Multiplication
# 87.3 ns ± 5.94 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
#
# (Scalar) Function - sine
# 254 ns ± 67.3 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Scalar) Function - x**100
# 227 ns ± 10 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# Test Array
X = module.zeros((3,3)) + x
print(module.__name__+" - Array "+str(X.shape))
print("(Array) Addition")
# %timeit X+X
print("\n(Array) Multiplication (elementwise)")
# %timeit X*X
print("\n(Array) Multiplication (elementwise)")
# %timeit module.dot(X,X)
print("\n(Array) Function - sine")
# %timeit module.sin(X)
print("\n(Array) Function - x**100")
# %timeit module.pow(X,100.)
# Out:
# pyoti.mdnum2 - Array (3, 3)
# (Array) Addition
# 271 ns ± 7.09 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Array) Multiplication (elementwise)
# 324 ns ± 54.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Array) Multiplication (elementwise)
# 624 ns ± 32.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Array) Function - sine
# 722 ns ± 28.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Array) Function - x**100
# 952 ns ± 83.1 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# Test Gauss scalar
x = module.number(0.5,nip=27)+module.e(1)+module.e(2)
print(module.__name__+" - Gauss Scalar with "+str(x.nip)+" integration points")
print("(Gauss Scalar) Addition")
# %timeit x+x
print("\n(Gauss Scalar) Multiplication")
# %timeit x*x
print("\n(Gauss Scalar) Function - sine")
# %timeit module.sin(x)
print("\n(Gauss Scalar) Function - x**100")
# %timeit module.pow(x,100.)
print("\n(Gauss Scalar) Gauss integration")
# %timeit module.gauss_integrate(x,x)
# Out:
# pyoti.mdnum2 - Gauss Scalar with 27 integration points
# (Gauss Scalar) Addition
# 302 ns ± 30.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Gauss Scalar) Multiplication
# 344 ns ± 5.66 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Gauss Scalar) Function - sine
# 1.01 µs ± 26.1 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Gauss Scalar) Function - x**100
# 1.54 µs ± 21.9 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
#
# (Gauss Scalar) Gauss integration
# 288 ns ± 5.18 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# Test Gauss Array
X = module.zeros((3,3), nip=27) + 0.5 + module.e(1)
print(module.__name__+" - Gauss Array "+str(X.shape))
print("(Gauss Array) Addition")
# %timeit X+X
print("\n(Gauss Array) Multiplication (elementwise)")
# %timeit X*X
print("\n(Gauss Array) Multiplication (elementwise)")
# %timeit module.dot(X,X)
print("\n(Gauss Array) Function - sine")
# %timeit module.sin(X)
print("\n(Gauss Array) Function - x**100")
# %timeit module.pow(X,100.)
print("\n(Gauss Array) Gauss integration")
# %timeit module.gauss_integrate(X,x)
# Out:
# pyoti.mdnum2 - Gauss Array (3, 3)
# (Gauss Array) Addition
# 8.61 µs ± 563 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
#
# (Gauss Array) Multiplication (elementwise)
# 8.76 µs ± 153 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
#
# (Gauss Array) Multiplication (elementwise)
# 12.8 µs ± 1.94 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)
#
# (Gauss Array) Function - sine
# 15.6 µs ± 1.14 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)
#
# (Gauss Array) Function - x**100
# 20.1 µs ± 966 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
#
# (Gauss Array) Gauss integration
# 1.51 µs ± 69.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
globals()['md3']
# Out:
# <module 'pyoti.mdnum3' from '../../../build/pyoti/mdnum3.cpython-37m-darwin.so'>

# %%
f = oti.sin(x)

# %%
f.get_deriv([1,2,3])
# Out:
# -5.2654953713422366

# %%
X_so  = oti.zeros((3,3)) +1+ oti.e(1)+ oti.e(2)+ oti.e(3)+ oti.e(4)+ oti.e(5)+ oti.e(6)+ oti.e(7)+ oti.e(8)+ oti.e(9)+ oti.e(10)
# %timeit oti.dot(X_so,X_so)
# Out:
# 8.13 µs ± 259 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
X_om10n1 = om10n1.zeros((3,3))
# %timeit om10n1.dot(X_om10n1,X_om10n1)
# Out:
# 1.08 µs ± 12.9 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
X_om2n5 = om2n5.zeros((3,3))
out = X_om2n5.copy()
# %timeit om2n5.dot(X_om2n5,X_om2n5,out=out)
# Out:
# 3.88 µs ± 466 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
X_so  = oti.zeros((3,3)) +(1 + oti.e(1,order=5)+ oti.e(2,order=5))**5
out = X_so.copy()
# %timeit oti.dot(X_so,X_so,out=out)
# Out:
# 53 µs ± 1.28 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
X_om2n5 = om2n5.zeros((3,3))

X_om2n5
# Out:
# omatm2n5< shape: (3, 3),
#  - Column 0
# (0,0) 0.0000 + 0.0000 * e([1]) + 0.0000 * e([2]) + 0.0000 * e([[1,2]]) + 0.0000 * e([1,2]) + 0.0000 * e([[2,2]]) + nan * e([[1,3]]) + 0.0000 * e([[1,2],2]) + .0000 * e([1,[2,2]]) + 0.0000 * e([[2,3]]) + 0.0000 * e([[1,4]]) + 0.0000 * e([[1,3],2]) + 0.0000 * e([[1,2],[2,2]]) + nan * e([1,[2,3]]) + 0.0000 * e([[2,4]]) + nan * e([[1,5]]) + 0.0000 * e([[1,4],2]) + 11711902778936637226412060440200741170897204695545250784611653264892894013472031834471901470953311875452542224830134818818813432582736715921688651224358315997421109248.0000 * e([[1,3],[2,2]]) + 0.0000 * e([[1,2],[2,3]]) + 0.0000 * e([1,[2,4]]) + 0.0000 * e([[2,5]])
# (1,0) 0.0000 + 0.0000 * e([1]) + 0.0000 * e([2]) + 0.0000 * e([[1,2]]) + 0.0000 * e([1,2]) + 0.0000 * e([[2,2]]) + 0.0000 * e([[1,3]]) + 0.0000 * e([[1,2],2]) + 0.0000 * e([1,[2,2]]) + 0.0000 * e([[2,3]]) + 0.0000 * e([[1,4]]) + 0.0000 * e([[1,3],2]) + 0.0000 * e([[1,2],[2,2]]) + 0.0000 * e([1,[2,3]]) + 0.0000 * e([[2,4]]) + 0.0000 * e([[1,5]]) + 0.0000 * e([[1,4],2]) + 0.0000 * e([[1,3],[2,2]]) + 0.0000 * e([[1,2],[2,3]]) + 0.0000 * e([1,[2,4]]) + 0.0000 * e([[2,5]])
# (2,0) 0.0000 + 14172419874314737573684082792431729803279817680446104223340320974191938452796938927399467859867538845230143046086012022153988137133675120489354745589220466004245781820883414769080387663560704.0000 * e([1]) + 11756736847946630905015248478468413947968360365533421884557101014321512851515584199892030322735715756281293893846889637595964276072755451765564459211696114293200380832478360230598703747872657528848085504737910194176.0000 * e([2]) + .0000 * e([[1,2]]) + 322955779081363024950769718384958024688298439798522603121604864544567481169213138936205053095416912776899239659893460675033420217642287961113112569615439211953238696021628963352446232239658567101679996283912192.0000 * e([1,2]) + 1746764841161534417862323870346403489306049663640966353421006841925448090143325554075318764908620504234173996182376507462394637054257373095248858518908269468741636249640092928033860494849201008565886711015690241555451213864045952145964601966592.0000 * e([[2,2]]) + 8763913419115043780872578572181009302808693390702789242106974279400913627869181995410949839394877716288410632816755566028470774899170841536501190078623714273300164413659527812948817791607797270528095907142970209316126475550358762151662192307356787802112.0000 * e([[1,3]]) + 9800584406755568367217096255020905049726471469457310762319015254016653473192295665035508598953608883255743787580198189526568140847307108094189446939427232554427252747390619350541222479481404729576772318489125302065825035920884837185428797140577504198656.0000 * e([[1,2],2]) + 8763912900501879733867967978545246933619202269294462251906273082752404108685961476779728380444766658103552563794716053593467893769963058947017056396070781815864549186724811229469619244788962486779481780560921348697477577970123972357012439462365540384768.0000 * e([1,[2,2]]) + 66713685692944013309862247550976313212987850392125615006105473792354041476332453485813576764063048396998514823246414509014391415935213644472168388493312.0000 * e([[2,3]]) + .0000 * e([[1,4]]) + 0.0000 * e([[1,3],2]) + 93035059886111498676185058151315994493072078913109823294830668742485483708706938335204920079615099101631243637806992913392005226413745306108397265488118755997924664010108699566335501348263799744888832.0000 * e([[1,2],[2,2]]) + 0.0000 * e([1,[2,3]]) + 632299173616036491489166147112641099102742199048661639079952559295385021247775126309545365125753085202535067885135887487815417870130726413753531434281104832907589419231781240294177795320060694850982884131941883223548630291496831025152.0000 * e([[2,4]]) + 4824108596111890382324735812303569775951503812601507794667651960347319987942568930954193960967452774938509639499053849510592344652293281786878552226979597955787577898949212143553960558474483700949634624080529627586052821639757824.0000 * e([[1,5]]) + 4272430298433113434863220185894656014222169605756263469416754453189236276096035465083815004892371845473007178783037382750330379758983256054486512161756613723261415244191651701194752.0000 * e([[1,4],2]) + 1465570258488018620328706403116805562356687949626603369885717143932094749345822688825184638785454806484996565945898041234162203768566001956486224705247255840316405588164608.0000 * e([[1,3],[2,2]]) + 5607750933644258075059225055596061807922097139213400399749639900813703858948148479551530082950167007037590951683033105538537673099579423195136.0000 * e([[1,2],[2,3]]) + 314542551175581834732644226390862692348531118736235129731807724097508934551119867096944897602731915513009171 ...
#  - Column 1
# (0,1) 0.0000 + 0.0000 * e([1]) + 0.0000 * e([2]) + nan * e([[1,2]]) + 0.0000 * e([1,2]) + 149176248894601854976.0000 * e([[2,2]]) + 0.0000 * e([[1,3]]) + 0.0000 * e([[1,2],2]) + 0.0000 * e([1,[2,2]]) + 0.0000 * e([[2,3]]) + 0.0000 * e([[1,4]]) + 0.0000 * e([[1,3],2]) + nan * e([[1,2],[2,2]]) + 0.0000 * e([1,[2,3]]) + .0000 * e([[2,4]]) + 0.0000 * e([[1,5]]) + 0.0000 * e([[1,4],2]) + 0.0000 * e([[1,3],[2,2]]) + 0.0000 * e([[1,2],[2,3]]) + 0.0000 * e([1,[2,4]]) + 0.0000 * e([[2,5]])
# (1,1) 0.0000 + 0.0000 * e([1]) + 0.0000 * e([2]) + 0.0000 * e([[1,2]]) + 0.0000 * e([1,2]) + 0.0000 * e([[2,2]]) + 0.0000 * e([[1,3]]) + 0.0000 * e([[1,2],2]) + 0.0000 * e([1,[2,2]]) + 0.0000 * e([[2,3]]) + 0.0000 * e([[1,4]]) + nan * e([[1,3],2]) + 0.0000 * e([[1,2],[2,2]]) + nan * e([1,[2,3]]) + 0.0000 * e([[2,4]]) + 0.0000 * e([[1,5]]) + 0.0000 * e([[1,4],2]) + 0.0000 * e([[1,3],[2,2]]) + 0.0000 * e([[1,2],[2,3]]) + 0.0000 * e([1,[2,4]]) + 88289357871179578707496294441485856395047237793369451268233840921116573493525058304210792393081314786078103672850260096803795561865792744945397453000070212303184428160508729182797193735469171516375040.0000 * e([[2,5]])
# (2,1) 0.0000 + 7513037969051479468547725228372402133599600010996198663055388101408330217614361802816933888764418589669879340739412289099203659939396849937576088775668533511373114409356871341370893858666091080930840967476559912379499521229416184474809246113084374777856.0000 * e([1]) + 60906730181041356834666720714671520641119890278304251257355305452593083681216094770697826400346387700947587262854757962945397877095527893500937564937798435353533947720950230716386776051540240021073966412761462322617823468156178174706491039439388672.0000 * e([2]) + 9853306219501758596548884255594152158716293515155821340105920941287107545620766170342928008242407882426564926710965745749494062981857299734478886775549703695340929024.0000 * e([[1,2]]) + 7