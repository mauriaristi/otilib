# %%
import sys
import os
path2oti = '../../../build/'
sys.path.append(path2oti) # Add path to OTI library.

import pyoti.core   as coti
from pyoti.cmod_writer import writer

# %%
h = coti.get_dHelp()

# %%
2**5
# Out:
# 32

# %%
h.get_ndir_total(10,3)
# Out:
# 286

# %%
w = writer(order = 10, nbases=2, mdual=False)
# w = writer(order = 3, nbases=3, mdual=False)
# w.process_static_include_files(base_dir='../../../')
# w.process_headers_static(tab='  ', base_dir = '../../../' )

# %%
print(w.truncaddition_like_function_oo(level = "    ", f_name = "", lhs_name= "LHS", lhs_ptr=True,
    rhs_name= "RHS", rhs_ptr=True, res_name = "RES", separator = " - ", f_open = "", f_close = "", tab = "    ",
    addition = " + ", to=True ))
# Out:
#     // Addition like function 'LHS - RHS'
#     switch(order){
#         case(0):
#             //  Real
#             RES->r = LHS->r - RHS->r;
#             break;
#         case(1):        // Order 1
#             RES->e1 = LHS->e1 - RHS->e1;
#             RES->e2 = LHS->e2 - RHS->e2;
#             RES->e3 = LHS->e3 - RHS->e3;
#             RES->e4 = LHS->e4 - RHS->e4;
#             break;
#         case(2):        // Order 2
#             RES->e11 = LHS->e11 - RHS->e11;
#             RES->e12 = LHS->e12 - RHS->e12;
#             RES->e22 = LHS->e22 - RHS->e22;
#             RES->e13 = LHS->e13 - RHS->e13;
#             RES->e23 = LHS->e23 - RHS->e23;
#             RES->e33 = LHS->e33 - RHS->e33;
#             RES->e14 = LHS->e14 - RHS->e14;
#             RES->e24 = LHS->e24 - RHS->e24;
#             RES->e34 = LHS->e34 - RHS->e34;
#             RES->e44 = LHS->e44 - RHS->e44;
#             break;
#     }

# %%
print(w.write_truncscalar_function(function_name = "sub", is_elemental = True, level = 0, 
      tab = "    ", f_name = "", lhs_type= "o", rhs_type= "o", separator = " - ", f_open = "", 
      lhs_ptr=True, rhs_ptr= True, to=True,header = 'algebra',
      f_close = "", generator = w.truncaddition_like_function_oo, overload = "-" ))
# Out:
# void onumm2n10_sub_oo_to(ord_t order, onumm2n10_t* lhs,onumm2n10_t* rhs, onumm2n10_t* res){
#     // Addition like function 'lhs - rhs'
#     switch(order){
#         case(0):
#             //  Real
#             res->r = lhs->r - rhs->r;
#             break;
#         case(1):        // Order 1
#             res->e1 = lhs->e1 - rhs->e1;
#             res->e2 = lhs->e2 - rhs->e2;
#             break;
#         case(2):        // Order 2
#             res->e11 = lhs->e11 - rhs->e11;
#             res->e12 = lhs->e12 - rhs->e12;
#             res->e22 = lhs->e22 - rhs->e22;
#             break;
#         case(3):        // Order 3
#             res->e111 = lhs->e111 - rhs->e111;
#             res->e112 = lhs->e112 - rhs->e112;
#             res->e122 = lhs->e122 - rhs->e122;
#             res->e222 = lhs->e222 - rhs->e222;
#             break;
#         case(4):        // Order 4
#             res->e1111 = lhs->e1111 - rhs->e1111;
#             res->e1112 = lhs->e1112 - rhs->e1112;
#             res->e1122 = lhs->e1122 - rhs->e1122;
#             res->e1222 = lhs->e1222 - rhs->e1222;
#             res->e2222 = lhs->e2222 - rhs->e2222;
#             break;
#         case(5):        // Order 5
#             res->e11111 = lhs->e11111 - rhs->e11111;
#             res->e11112 = lhs->e11112 - rhs->e11112;
#             res->e11122 = lhs->e11122 - rhs->e11122;
#             res->e11222 = lhs->e11222 - rhs->e11222;
#             res->e12222 = lhs->e12222 - rhs->e12222;
#             res->e22222 = lhs->e22222 - rhs->e22222;
#             break;
#         case(6):        // Order 6
#             res->e111111 = lhs->e111111 - rhs->e111111;
#             res->e111112 = lhs->e111112 - rhs->e111112;
#             res->e111122 = lhs->e111122 - rhs->e111122;
#             res->e111222 = lhs->e111222 - rhs->e111222;
#             res->e112222 = lhs->e112222 - rhs->e112222;
#             res->e122222 = lhs->e122222 - rhs->e122222;
#             res->e222222 = lhs->e222222 - rhs->e222222;
#             break;
#         case(7):        // Order 7
#             res->e1111111 = lhs->e1111111 - rhs->e1111111;
#             res->e1111112 = lhs->e1111112 - rhs->e1111112;
#             res->e1111122 = lhs->e1111122 - rhs->e1111122;
#             res->e1111222 = lhs->e1111222 - rhs->e1111222;
#             res->e1112222 = lhs->e1112222 - rhs->e1112222;
#             res->e1122222 = lhs->e1122222 - rhs->e1122222;
#             res->e1222222 = lhs->e1222222 - rhs->e1222222;
#             res->e2222222 = lhs->e2222222 - rhs->e2222222;
#             break;
#         case(8):        // Order 8
#             res->e11111111 = lhs->e11111111 - rhs->e11111111;
#             res->e11111112 = lhs->e11111112 - rhs->e11111112;
#             res->e11111122 = lhs->e11111122 - rhs->e11111122;
#             res->e11111222 = lhs->e11111222 - rhs->e11111222;
#             res->e11112222 = lhs->e11112222 - rhs->e11112222;
#             res->e11122222 = lhs->e11122222 - rhs->e11122222;
#             res->e11222222 = lhs->e11222222 - rhs->e11222222;
#             res->e12222222 = lhs->e12222222 - rhs->e12222222;
#             res->e22222222 = lhs->e22222222 - rhs->e22222222;
#             break;
#         case(9):        // Order 9
#             res->e111111111 = lhs->e111111111 - rhs->e111111111;
#             res->e111111112 = lhs->e111111112 - rhs->e111111112;
#             res->e111111122 = lhs->e111111122 - rhs->e111111122;
#             res->e111111222 = lhs->e111111222 - rhs->e111111222;
#             res->e111112222 = lhs->e111112222 - rhs->e111112222;
#             res->e111122222 = lhs->e111122222 - rhs->e111122222;
#             res->e111222222 = lhs->e111222222 - rhs->e111222222;
#             res->e112222222 = lhs->e112222222 - rhs->e112222222;
#             res->e122222222 = lhs->e122222222 - rhs->e122222222;
#             res->e222222222 = lhs->e222222222 - rhs->e222222222;
#             break;
#         case(10):        // Order 10
#             res->e1111111111 = lhs->e1111111111 - rhs->e1111111111;
#             res->e1111111112 = lhs->e1111111112 - rhs->e1111111112;
#             res->e1111111122 = lhs->e1111111122 - rhs->e1111111122;
#             res->e1111111222 = lhs->e1111111222 - rhs->e1111111222;
#             res->e1111112222 = lhs->e1111112222 - rhs->e1111112222;
#             res->e1111122222 = lhs->e1111122222 - rhs->e1111122222;
#             res->e1111222222 = lhs->e1111222222 - rhs->e1111222222;
#             res->e1112222222 = lhs->e1112222222 - rhs->e1112222222;
#             res->e1122222222 = lhs->e1122222222 - rhs->e1122222222;
#             res->e1222222222 = lhs->e1222222222 - rhs->e1222222222;
#             res->e2222222222 = lhs->e2222222222 - rhs->e2222222222;
#             break;
#     }
# }

# %%
export_dir = '../../../'

w = writer(order = 0, nbases=0, mdual=False)
w.clean_output_folder_files( base_dir = export_dir)
w.write_files(base_dir=export_dir)

# Write MultiDuals.
nbases_max = 5# Generate all one variable until order 10.
order_max  = 5# Generate all one variable until order 10.
for order in range(order_max + 1,11):
    for nbases in range( 1, 2 + 1 ):
        w = writer(order = order, nbases=nbases, mdual=False)
        w.write_files(base_dir=export_dir)
    # end for
# end for # Generate all one variable until order 10.
for order in range(order_max + 1,11):
    for nbases in range( 1, 2 + 1 ):
        w = writer(order = order, nbases=nbases, mdual=False)
        w.write_files(base_dir=export_dir)
    # end for
# end for 
order_max  = 5
for order in range( 1, order_max + 1 ):
    w = writer(order = order, nbases=order, mdual=True)
    w.write_files(base_dir=export_dir)
# end for




# OTI
# Generate all from order  1 - 5
# Generate all from nbases 1 - 5
for order in range( 1, order_max + 1):
    for nbases in range( 1, nbases_max + 1):
        w = writer(order = order, nbases=nbases, mdual=False)
        w.write_files(base_dir=export_dir)
    # end for
# end for 


# Generate all one and two variables until order 10.
for order in range(order_max + 1,11):
    for nbases in range( 1, 2 + 1 ):
        w = writer(order = order, nbases=nbases, mdual=False)
        w.write_files(base_dir=export_dir)
    # end for
# end for 

# Generate all one and first order for 6 - 10 variables.
for order in range(1,2+1):
    for nbases in range( nbases_max+1, 10 + 1 ):
        w = writer(order = order, nbases=nbases, mdual=False)
        w.write_files(base_dir=export_dir)
    # end for
# end for
# Out:
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# ...
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c

# %%
nbases_max = 5
order_max  = 5
for order in range( 1, order_max + 1 ):
    w = writer(order = order, nbases=order, mdual=True)
    w.write_files(base_dir='output_test/')
# end for

w = writer(order = 0, nbases=0, mdual=False)
w.write_files(base_dir='output_test/')
# Out:
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c

# %%
src_path = coti.whereotilib.getpath()+"../../src/python/pyoti/python/source/"

folders={}
folders['include']=[]
folders['src']=[]


supp_ext = ['h','pxd','pxi','c','pyx']

# r=>root, d=>directories, f=>files
for key, files_in_dir in folders.items():
    location = src_path+ key
    for r, d, f in os.walk(location):
        for item in f:
            ext = item.split('.')[-1]
            if ext in supp_ext:
                files_in_dir.append(os.path.join(r.replace(location,""), item))
            #
        #
    #
#
    
for i in range(len(folders['include'])):
    print(folders['include'][i])
    print()
# Out:
# /pyoti/static/number.pxd
#
# /pyoti/static/number/array.pxd
#
# /pyoti/static/number/math.pxd
#
# /pyoti/static/number/algebra.pxd
#
# /pyoti/static/number/scalar.pxd
#
# /pyoti/static/number/gauss.pxd
#
# /pyoti/static/number/sparse_array.pxd
#
# /pyoti/static/number/dependencies.pxd
#
# /pyoti/static/number/utils.pxd
#
# /pyoti/static/number/fem.pxd
#
# /pyoti/static/number/gauss/array.pxd
#
# /pyoti/static/number/gauss/scalar.pxd
#
# /oti/static/number.h
#
# /oti/static/number/scalar/functions.h
#
# /oti/static/number/scalar/structures.h
#
# /oti/static/number/scalar/base.h
#
# /oti/static/number/scalar/utils.h
#
# /oti/static/number/scalar/algebra.h
#
# /oti/static/number/scalar/gauss.h
#
# /oti/static/number/scalar/gauss/functions.h
#
# /oti/static/number/scalar/gauss/structures.h
#
# /oti/static/number/scalar/gauss/base.h
#
# /oti/static/number/scalar/gauss/utils.h
#
# /oti/static/number/scalar/gauss/algebra.h
#
# /oti/static/number/array/functions.h
#
# /oti/static/number/array/structures.h
#
# /oti/static/number/array/algebra_elementwise.h
#
# /oti/static/number/array/base.h
#
# /oti/static/number/array/utils.h
#
# /oti/static/number/array/algebra_matops.h
#
# /oti/static/number/array/gauss.h
#
# /oti/static/number/array/gauss/functions.h
#
# /oti/static/number/array/gauss/structures.h
#
# /oti/static/number/array/gauss/base.h
#
# /oti/static/number/array/gauss/utils.h
#
# /oti/static/number/array/gauss/algebra.h

# %%
# Generate all one variable until order 10.
# for order in range(order_max + 1,11):
#     for nbases in range( 1, 2 + 1 ):
#         w = writer(order = order, nbases=nbases, mdual=False)
#         w.write_files(base_dir=export_dir)
#     # end for
# # end for # f = open(coti.whereotilib.getpath()+"/source/src/cython/number/algebra_utils/div.pxi",'r')

src_path = coti.whereotilib.getpath()+"../../src/python/pyoti/python/source/"

# file_path = "/src/cython/number/algebra_utils/div.pxi"

# file_path = "/include/pyoti/number/algebra.pxd"
file_path = "/src"+"/c/number/scalar/functions.c"


dest_path = src_path+"../source_conv/"

for key, files_in_dir in folders.items():
    for file_path in files_in_dir:
        dest_path = src_path+"../source_conv/"+key
        
        f = open(src_path +key+ file_path,'r')
        f_str = f.read()
        f.close()

        f_str = f_str.replace("{","{{")
        f_str = f_str.replace("}","}}")
        
        f_str = f_str.replace("<<<","{")
        f_str = f_str.replace(">>>","}")

        f_str = f_str.replace("global dhl","")
        
        for i in range(30):
            string = " "*i
            f_str = f_str.replace(","+string+"dhl","")
            f_str = f_str.replace(",\n"+string+"dhl","")
            f_str = f_str.replace(", \n"+string+"dhl","")
            f_str = f_str.replace(",  \n"+string+"dhl","")
            f_str = f_str.replace(","+string+"dhelpl_t dhl","")
            f_str = f_str.replace(",\n"+string+"dhelpl_t dhl","")
            f_str = f_str.replace(", \n"+string+"dhelpl_t dhl","")
            f_str = f_str.replace(",  \n"+string+"dhelpl_t dhl","")
        #end for 
        
        
        f_str = f_str.replace("sotinum_t","{num_type}")
        f_str = f_str.replace("fesoti_t","{fenum_type}")
        f_str = f_str.replace("fearrso_t","{fearr_type}")
        f_str = f_str.replace("arrso_t","{arr_type}")
        
        f_str = f_str.replace("_SPARSE_","_{module_name_upper}_")
        f_str = f_str.replace(", bases_t nbases, ord_t order","")
        f_str = f_str.replace(", nbases, order","")
        
        f_str = f_str.replace("type}an","func}_tan")
        f_str = f_str.replace("type}aylor","func}_taylor")
        f_str = f_str.replace("type}runc","func}_trunc")

        f_str = f_str.replace("sotinum","{num_pytype}")
        f_str = f_str.replace("sotife","{fenum_pytype}")
        f_str = f_str.replace("matsofe","{fearr_pytype}")
        f_str = f_str.replace("matso","{arr_pytype}")


        f_str = f_str.replace("fesoti","{fenum_func}")
        f_str = f_str.replace("fearrso","{fearr_func}")
        f_str = f_str.replace("arrso","{arr_func}")
        f_str = f_str.replace("soti","{num_func}")
        
        f_str = f_str.replace("active_bases","active_base")
        f_str = f_str.replace("_bases","")
        f_str = f_str.replace("active_base","active_bases")
        f_str = f_str.replace("_predef","")
        f_str = f_str.replace(", 0, 0","")
        
        for i in range(10):
            f_str = f_str.replace("\n\n\n","\n\n")
        #end for 

        conv_file = dest_path+file_path
        os.makedirs(os.path.dirname(conv_file), exist_ok=True)

        f = open(conv_file,'w')
        f.write(f_str)
        f.close()

# %%
print( w.write_util_function_getidx() )

# %%
# Write static OTI.
w = writer(order = 1, nbases=20, mdual=False)
w.write_files(base_dir='export_tests/')

# %%
import re

# %%
s = """
#ifndef OTI_ONUMM1N2_SCALAR_STRUCTURES_H
#define OTI_ONUMM1N2_SCALAR_STRUCTURES_H

// ----------------------------------------------------------------------------------------------------
// --------------------------------------      STRUCTURES        --------------------------------------
// ----------------------------------------------------------------------------------------------------

// Scalar
typedef struct {
  // Real
  coeff_t r;
  // Order 1
  coeff_t e1;
  // Order 2
  coeff_t e11;
} onumm1n2_t;




// ----------------------------------------------------------------------------------------------------
// -------------------------------------    END STRUCTURES      ---------------------------------------
// ----------------------------------------------------------------------------------------------------

#endif
"""
pattern = "}(.*?);"

substring = re.search(pattern, s).group(1)

# %%
substring
# Out:
# ' onumm1n2_t'
