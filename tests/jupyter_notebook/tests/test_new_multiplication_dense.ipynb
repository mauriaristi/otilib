# %%
# 1. SET GLOBAL PATH 
import sys
path2oti = '../../../build/'
sys.path.append(path2oti) # Add path to OTI library.


from pyoti.dense import e, set_trunc_order, get_trunc_order
from pyoti.dense import add, add_to, mul, mul_to, mulr_to

# %%
nbases= 5
order = 5

# %%
set_trunc_order(10)

# %%
get_trunc_order()
# Out:
# 10

# %%
x1 = 0.5 + e(1,nbases=nbases,order=order) 
x2 = 0.8 + e(2,nbases=nbases,order=order)
xr = 0.7 * e(0)

# %%
x1.short_repr()
# Out:
# 'otinum(0.5, ndir: 251, order: 5)'

# %%
x2
# Out:
# 0.8 + 0 * e([1]) + 1 * e([2]) + 0 * e([3]) + 0 * e([4]) + 0 * e([5]) + 0 * e([[1,2]]) + 0 * e([1,2]) + 0 * e([[2,2]]) + 0 * e([1,3]) + 0 * e([2,3]) + 0 * e([[3,2]]) + 0 * e([1,4]) + 0 * e([2,4]) + 0 * e([3,4]) + 0 * e([[4,2]]) + 0 * e([1,5]) + 0 * e([2,5]) + 0 * e([3,5]) + 0 * e([4,5]) + 0 * e([[5,2]]) + 0 * e([[1,3]]) + 0 * e([[1,2],2]) + 0 * e([1,[2,2]]) + 0 * e([[2,3]]) + 0 * e([[1,2],3]) + 0 * e([1,2,3]) + 0 * e([[2,2],3]) + 0 * e([1,[3,2]]) + 0 * e([2,[3,2]]) + 0 * e([[3,3]]) + 0 * e([[1,2],4]) + 0 * e([1,2,4]) + 0 * e([[2,2],4]) + 0 * e([1,3,4]) + 0 * e([2,3,4]) + 0 * e([[3,2],4]) + 0 * e([1,[4,2]]) + 0 * e([2,[4,2]]) + 0 * e([3,[4,2]]) + 0 * e([[4,3]]) + 0 * e([[1,2],5]) + 0 * e([1,2,5]) + 0 * e([[2,2],5]) + 0 * e([1,3,5]) + 0 * e([2,3,5]) + 0 * e([[3,2],5]) + 0 * e([1,4,5]) + 0 * e([2,4,5]) + 0 * e([3,4,5]) + 0 * e([[4,2],5]) + 0 * e([1,[5,2]]) + 0 * e([2,[5,2]]) + 0 * e([3,[5,2]]) + 0 * e([4,[5,2]]) + 0 * e([[5,3]]) + 0 * e([[1,4]]) + 0 * e([[1,3],2]) + 0 * e([[1,2],[2,2]]) + 0 * e([1,[2,3]]) + 0 * e([[2,4]]) + 0 * e([[1,3],3]) + 0 * e([[1,2],2,3]) + 0 * e([1,[2,2],3]) + 0 * e([[2,3],3]) + 0 * e([[1,2],[3,2]]) + 0 * e([1,2,[3,2]]) + 0 * e([[2,2],[3,2]]) + 0 * e([1,[3,3]]) + 0 * e([2,[3,3]]) + 0 * e([[3,4]]) + 0 * e([[1,3],4]) + 0 * e([[1,2],2,4]) + 0 * e([1,[2,2],4]) + 0 * e([[2,3],4]) + 0 * e([[1,2],3,4]) + 0 * e([1,2,3,4]) + 0 * e([[2,2],3,4]) + 0 * e([1,[3,2],4]) + 0 * e([2,[3,2],4]) + 0 * e([[3,3],4]) + 0 * e([[1,2],[4,2]]) + 0 * e([1,2,[4,2]]) + 0 * e([[2,2],[4,2]]) + 0 * e([1,3,[4,2]]) + 0 * e([2,3,[4,2]]) + 0 * e([[3,2],[4,2]]) + 0 * e([1,[4,3]]) + 0 * e([2,[4,3]]) + 0 * e([3,[4,3]]) + 0 * e([[4,4]]) + 0 * e([[1,3],5]) + 0 * e([[1,2],2,5]) + 0 * e([1,[2,2],5]) + 0 * e([[2,3],5]) + 0 * e([[1,2],3,5]) + 0 * e([1,2,3,5]) + 0 * e([[2,2],3,5]) + 0 * e([1,[3,2],5]) + 0 * e([2,[3,2],5]) + 0 * e([[3,3],5]) + 0 * e([[1,2],4,5]) + 0 * e([1,2,4,5]) + 0 * e([[2,2],4,5]) + 0 * e([1,3,4,5]) + 0 * e([2,3,4,5]) + 0 * e([[3,2],4,5]) + 0 * e([1,[4,2],5]) + 0 * e([2,[4,2],5]) + 0 * e([3,[4,2],5]) + 0 * e([[4,3],5]) + 0 * e([[1,2],[5,2]]) + 0 * e([1,2,[5,2]]) + 0 * e([[2,2],[5,2]]) + 0 * e([1,3,[5,2]]) + 0 * e([2,3,[5,2]]) + 0 * e([[3,2],[5,2]]) + 0 * e([1,4,[5,2]]) + 0 * e([2,4,[5,2]]) + 0 * e([3,4,[5,2]]) + 0 * e([[4,2],[5,2]]) + 0 * e([1,[5,3]]) + 0 * e([2,[5,3]]) + 0 * e([3,[5,3]]) + 0 * e([4,[5,3]]) + 0 * e([[5,4]]) + 0 * e([[1,5]]) + 0 * e([[1,4],2]) + 0 * e([[1,3],[2,2]]) + 0 * e([[1,2],[2,3]]) + 0 * e([1,[2,4]]) + 0 * e([[2,5]]) + 0 * e([[1,4],3]) + 0 * e([[1,3],2,3]) + 0 * e([[1,2],[2,2],3]) + 0 * e([1,[2,3],3]) + 0 * e([[2,4],3]) + 0 * e([[1,3],[3,2]]) + 0 * e([[1,2],2,[3,2]]) + 0 * e([1,[2,2],[3,2]]) + 0 * e([[2,3],[3,2]]) + 0 * e([[1,2],[3,3]]) + 0 * e([1,2,[3,3]]) + 0 * e([[2,2],[3,3]]) + 0 * e([1,[3,4]]) + 0 * e([2,[3,4]]) + 0 * e([[3,5]]) + 0 * e([[1,4],4]) + 0 * e([[1,3],2,4]) + 0 * e([[1,2],[2,2],4]) + 0 * e([1,[2,3],4]) + 0 * e([[2,4],4]) + 0 * e([[1,3],3,4]) + 0 * e([[1,2],2,3,4]) + 0 * e([1,[2,2],3,4]) + 0 * e([[2,3],3,4]) + 0 * e([[1,2],[3,2],4]) + 0 * e([1,2,[3,2],4]) + 0 * e([[2,2],[3,2],4]) + 0 * e([1,[3,3],4]) + 0 * e([2,[3,3],4]) + 0 * e([[3,4],4]) + 0 * e([[1,3],[4,2]]) + 0 * e([[1,2],2,[4,2]]) + 0 * e([1,[2,2],[4,2]]) + 0 * e([[2,3],[4,2]]) + 0 * e([[1,2],3,[4,2]]) + 0 * e([1,2,3,[4,2]]) + 0 * e([[2,2],3,[4,2]]) + 0 * e([1,[3,2],[4,2]]) + 0 * e([2,[3,2],[4,2]]) + 0 * e([[3,3],[4,2]]) + 0 * e([[1,2],[4,3]]) + 0 * e([1,2,[4,3]]) + 0 * e([[2,2],[4,3]]) + 0 * e([1,3,[4,3]]) + 0 * e([2,3,[4,3]]) + 0 * e([[3,2],[4,3]]) + 0 * e([1,[4,4]]) + 0 * e([2,[4,4]]) + 0 * e([3,[4,4]]) + 0 * e([[4,5]]) + 0 * e([[1,4],5]) + 0 * e([[1,3],2,5]) + 0 * e([[1,2],[2,2],5]) + 0 * e([1,[2,3],5]) + 0 * e([[2,4],5]) + 0 * e([[1,3],3,5]) + 0 * e([[1,2],2,3,5]) + 0 * e([1,[2,2],3,5]) + 0 * e([[2,3],3,5]) + 0 * e([[1,2],[3,2],5]) + 0 * e([1,2,[3,2],5]) + 0 * e([[2,2],[3,2],5]) + 0 * e([1,[3,3],5]) + 0 * e([2,[3,3],5]) + 0 * e([[3,4],5]) + 0 * e([[1,3],4,5]) + 0 * e([[1,2],2,4,5]) + 0 * e([1,[2,2],4,5]) + 0 * e([[2,3],4,5]) + 0 * e([[ ...

# %%
xr
# Out:
# 0.7

# %%
xr.short_repr()
# Out:
# 'otinum(0.7, ndir: 0, order: 0)'

# %%
x3 = x1*x2

# %%
x3.short_repr()
# Out:
# 'otinum(0.4, ndir: 3002, order: 10)'

# %%
x1*xr
# Out:
# 0.35 + 0.7 * e([1]) + 0 * e([2]) + 0 * e([3]) + 0 * e([4]) + 0 * e([5]) + 0 * e([[1,2]]) + 0 * e([1,2]) + 0 * e([[2,2]]) + 0 * e([1,3]) + 0 * e([2,3]) + 0 * e([[3,2]]) + 0 * e([1,4]) + 0 * e([2,4]) + 0 * e([3,4]) + 0 * e([[4,2]]) + 0 * e([1,5]) + 0 * e([2,5]) + 0 * e([3,5]) + 0 * e([4,5]) + 0 * e([[5,2]]) + 0 * e([[1,3]]) + 0 * e([[1,2],2]) + 0 * e([1,[2,2]]) + 0 * e([[2,3]]) + 0 * e([[1,2],3]) + 0 * e([1,2,3]) + 0 * e([[2,2],3]) + 0 * e([1,[3,2]]) + 0 * e([2,[3,2]]) + 0 * e([[3,3]]) + 0 * e([[1,2],4]) + 0 * e([1,2,4]) + 0 * e([[2,2],4]) + 0 * e([1,3,4]) + 0 * e([2,3,4]) + 0 * e([[3,2],4]) + 0 * e([1,[4,2]]) + 0 * e([2,[4,2]]) + 0 * e([3,[4,2]]) + 0 * e([[4,3]]) + 0 * e([[1,2],5]) + 0 * e([1,2,5]) + 0 * e([[2,2],5]) + 0 * e([1,3,5]) + 0 * e([2,3,5]) + 0 * e([[3,2],5]) + 0 * e([1,4,5]) + 0 * e([2,4,5]) + 0 * e([3,4,5]) + 0 * e([[4,2],5]) + 0 * e([1,[5,2]]) + 0 * e([2,[5,2]]) + 0 * e([3,[5,2]]) + 0 * e([4,[5,2]]) + 0 * e([[5,3]]) + 0 * e([[1,4]]) + 0 * e([[1,3],2]) + 0 * e([[1,2],[2,2]]) + 0 * e([1,[2,3]]) + 0 * e([[2,4]]) + 0 * e([[1,3],3]) + 0 * e([[1,2],2,3]) + 0 * e([1,[2,2],3]) + 0 * e([[2,3],3]) + 0 * e([[1,2],[3,2]]) + 0 * e([1,2,[3,2]]) + 0 * e([[2,2],[3,2]]) + 0 * e([1,[3,3]]) + 0 * e([2,[3,3]]) + 0 * e([[3,4]]) + 0 * e([[1,3],4]) + 0 * e([[1,2],2,4]) + 0 * e([1,[2,2],4]) + 0 * e([[2,3],4]) + 0 * e([[1,2],3,4]) + 0 * e([1,2,3,4]) + 0 * e([[2,2],3,4]) + 0 * e([1,[3,2],4]) + 0 * e([2,[3,2],4]) + 0 * e([[3,3],4]) + 0 * e([[1,2],[4,2]]) + 0 * e([1,2,[4,2]]) + 0 * e([[2,2],[4,2]]) + 0 * e([1,3,[4,2]]) + 0 * e([2,3,[4,2]]) + 0 * e([[3,2],[4,2]]) + 0 * e([1,[4,3]]) + 0 * e([2,[4,3]]) + 0 * e([3,[4,3]]) + 0 * e([[4,4]]) + 0 * e([[1,3],5]) + 0 * e([[1,2],2,5]) + 0 * e([1,[2,2],5]) + 0 * e([[2,3],5]) + 0 * e([[1,2],3,5]) + 0 * e([1,2,3,5]) + 0 * e([[2,2],3,5]) + 0 * e([1,[3,2],5]) + 0 * e([2,[3,2],5]) + 0 * e([[3,3],5]) + 0 * e([[1,2],4,5]) + 0 * e([1,2,4,5]) + 0 * e([[2,2],4,5]) + 0 * e([1,3,4,5]) + 0 * e([2,3,4,5]) + 0 * e([[3,2],4,5]) + 0 * e([1,[4,2],5]) + 0 * e([2,[4,2],5]) + 0 * e([3,[4,2],5]) + 0 * e([[4,3],5]) + 0 * e([[1,2],[5,2]]) + 0 * e([1,2,[5,2]]) + 0 * e([[2,2],[5,2]]) + 0 * e([1,3,[5,2]]) + 0 * e([2,3,[5,2]]) + 0 * e([[3,2],[5,2]]) + 0 * e([1,4,[5,2]]) + 0 * e([2,4,[5,2]]) + 0 * e([3,4,[5,2]]) + 0 * e([[4,2],[5,2]]) + 0 * e([1,[5,3]]) + 0 * e([2,[5,3]]) + 0 * e([3,[5,3]]) + 0 * e([4,[5,3]]) + 0 * e([[5,4]]) + 0 * e([[1,5]]) + 0 * e([[1,4],2]) + 0 * e([[1,3],[2,2]]) + 0 * e([[1,2],[2,3]]) + 0 * e([1,[2,4]]) + 0 * e([[2,5]]) + 0 * e([[1,4],3]) + 0 * e([[1,3],2,3]) + 0 * e([[1,2],[2,2],3]) + 0 * e([1,[2,3],3]) + 0 * e([[2,4],3]) + 0 * e([[1,3],[3,2]]) + 0 * e([[1,2],2,[3,2]]) + 0 * e([1,[2,2],[3,2]]) + 0 * e([[2,3],[3,2]]) + 0 * e([[1,2],[3,3]]) + 0 * e([1,2,[3,3]]) + 0 * e([[2,2],[3,3]]) + 0 * e([1,[3,4]]) + 0 * e([2,[3,4]]) + 0 * e([[3,5]]) + 0 * e([[1,4],4]) + 0 * e([[1,3],2,4]) + 0 * e([[1,2],[2,2],4]) + 0 * e([1,[2,3],4]) + 0 * e([[2,4],4]) + 0 * e([[1,3],3,4]) + 0 * e([[1,2],2,3,4]) + 0 * e([1,[2,2],3,4]) + 0 * e([[2,3],3,4]) + 0 * e([[1,2],[3,2],4]) + 0 * e([1,2,[3,2],4]) + 0 * e([[2,2],[3,2],4]) + 0 * e([1,[3,3],4]) + 0 * e([2,[3,3],4]) + 0 * e([[3,4],4]) + 0 * e([[1,3],[4,2]]) + 0 * e([[1,2],2,[4,2]]) + 0 * e([1,[2,2],[4,2]]) + 0 * e([[2,3],[4,2]]) + 0 * e([[1,2],3,[4,2]]) + 0 * e([1,2,3,[4,2]]) + 0 * e([[2,2],3,[4,2]]) + 0 * e([1,[3,2],[4,2]]) + 0 * e([2,[3,2],[4,2]]) + 0 * e([[3,3],[4,2]]) + 0 * e([[1,2],[4,3]]) + 0 * e([1,2,[4,3]]) + 0 * e([[2,2],[4,3]]) + 0 * e([1,3,[4,3]]) + 0 * e([2,3,[4,3]]) + 0 * e([[3,2],[4,3]]) + 0 * e([1,[4,4]]) + 0 * e([2,[4,4]]) + 0 * e([3,[4,4]]) + 0 * e([[4,5]]) + 0 * e([[1,4],5]) + 0 * e([[1,3],2,5]) + 0 * e([[1,2],[2,2],5]) + 0 * e([1,[2,3],5]) + 0 * e([[2,4],5]) + 0 * e([[1,3],3,5]) + 0 * e([[1,2],2,3,5]) + 0 * e([1,[2,2],3,5]) + 0 * e([[2,3],3,5]) + 0 * e([[1,2],[3,2],5]) + 0 * e([1,2,[3,2],5]) + 0 * e([[2,2],[3,2],5]) + 0 * e([1,[3,3],5]) + 0 * e([2,[3,3],5]) + 0 * e([[3,4],5]) + 0 * e([[1,3],4,5]) + 0 * e([[1,2],2,4,5]) + 0 * e([1,[2,2],4,5]) + 0 * e([[2,3],4,5]) + 0 * e ...

# %%
x3.short_repr()
# Out:
# 'otinum(0.4, ndir: 3002, order: 10)'

# %%
x3sum = x1+x2

# %%
x3sum
# Out:
# 1.3 + 1 * e([1]) + 1 * e([2]) + 0 * e([3]) + 0 * e([4]) + 0 * e([5]) + 0 * e([[1,2]]) + 0 * e([1,2]) + 0 * e([[2,2]]) + 0 * e([1,3]) + 0 * e([2,3]) + 0 * e([[3,2]]) + 0 * e([1,4]) + 0 * e([2,4]) + 0 * e([3,4]) + 0 * e([[4,2]]) + 0 * e([1,5]) + 0 * e([2,5]) + 0 * e([3,5]) + 0 * e([4,5]) + 0 * e([[5,2]]) + 0 * e([[1,3]]) + 0 * e([[1,2],2]) + 0 * e([1,[2,2]]) + 0 * e([[2,3]]) + 0 * e([[1,2],3]) + 0 * e([1,2,3]) + 0 * e([[2,2],3]) + 0 * e([1,[3,2]]) + 0 * e([2,[3,2]]) + 0 * e([[3,3]]) + 0 * e([[1,2],4]) + 0 * e([1,2,4]) + 0 * e([[2,2],4]) + 0 * e([1,3,4]) + 0 * e([2,3,4]) + 0 * e([[3,2],4]) + 0 * e([1,[4,2]]) + 0 * e([2,[4,2]]) + 0 * e([3,[4,2]]) + 0 * e([[4,3]]) + 0 * e([[1,2],5]) + 0 * e([1,2,5]) + 0 * e([[2,2],5]) + 0 * e([1,3,5]) + 0 * e([2,3,5]) + 0 * e([[3,2],5]) + 0 * e([1,4,5]) + 0 * e([2,4,5]) + 0 * e([3,4,5]) + 0 * e([[4,2],5]) + 0 * e([1,[5,2]]) + 0 * e([2,[5,2]]) + 0 * e([3,[5,2]]) + 0 * e([4,[5,2]]) + 0 * e([[5,3]]) + 0 * e([[1,4]]) + 0 * e([[1,3],2]) + 0 * e([[1,2],[2,2]]) + 0 * e([1,[2,3]]) + 0 * e([[2,4]]) + 0 * e([[1,3],3]) + 0 * e([[1,2],2,3]) + 0 * e([1,[2,2],3]) + 0 * e([[2,3],3]) + 0 * e([[1,2],[3,2]]) + 0 * e([1,2,[3,2]]) + 0 * e([[2,2],[3,2]]) + 0 * e([1,[3,3]]) + 0 * e([2,[3,3]]) + 0 * e([[3,4]]) + 0 * e([[1,3],4]) + 0 * e([[1,2],2,4]) + 0 * e([1,[2,2],4]) + 0 * e([[2,3],4]) + 0 * e([[1,2],3,4]) + 0 * e([1,2,3,4]) + 0 * e([[2,2],3,4]) + 0 * e([1,[3,2],4]) + 0 * e([2,[3,2],4]) + 0 * e([[3,3],4]) + 0 * e([[1,2],[4,2]]) + 0 * e([1,2,[4,2]]) + 0 * e([[2,2],[4,2]]) + 0 * e([1,3,[4,2]]) + 0 * e([2,3,[4,2]]) + 0 * e([[3,2],[4,2]]) + 0 * e([1,[4,3]]) + 0 * e([2,[4,3]]) + 0 * e([3,[4,3]]) + 0 * e([[4,4]]) + 0 * e([[1,3],5]) + 0 * e([[1,2],2,5]) + 0 * e([1,[2,2],5]) + 0 * e([[2,3],5]) + 0 * e([[1,2],3,5]) + 0 * e([1,2,3,5]) + 0 * e([[2,2],3,5]) + 0 * e([1,[3,2],5]) + 0 * e([2,[3,2],5]) + 0 * e([[3,3],5]) + 0 * e([[1,2],4,5]) + 0 * e([1,2,4,5]) + 0 * e([[2,2],4,5]) + 0 * e([1,3,4,5]) + 0 * e([2,3,4,5]) + 0 * e([[3,2],4,5]) + 0 * e([1,[4,2],5]) + 0 * e([2,[4,2],5]) + 0 * e([3,[4,2],5]) + 0 * e([[4,3],5]) + 0 * e([[1,2],[5,2]]) + 0 * e([1,2,[5,2]]) + 0 * e([[2,2],[5,2]]) + 0 * e([1,3,[5,2]]) + 0 * e([2,3,[5,2]]) + 0 * e([[3,2],[5,2]]) + 0 * e([1,4,[5,2]]) + 0 * e([2,4,[5,2]]) + 0 * e([3,4,[5,2]]) + 0 * e([[4,2],[5,2]]) + 0 * e([1,[5,3]]) + 0 * e([2,[5,3]]) + 0 * e([3,[5,3]]) + 0 * e([4,[5,3]]) + 0 * e([[5,4]]) + 0 * e([[1,5]]) + 0 * e([[1,4],2]) + 0 * e([[1,3],[2,2]]) + 0 * e([[1,2],[2,3]]) + 0 * e([1,[2,4]]) + 0 * e([[2,5]]) + 0 * e([[1,4],3]) + 0 * e([[1,3],2,3]) + 0 * e([[1,2],[2,2],3]) + 0 * e([1,[2,3],3]) + 0 * e([[2,4],3]) + 0 * e([[1,3],[3,2]]) + 0 * e([[1,2],2,[3,2]]) + 0 * e([1,[2,2],[3,2]]) + 0 * e([[2,3],[3,2]]) + 0 * e([[1,2],[3,3]]) + 0 * e([1,2,[3,3]]) + 0 * e([[2,2],[3,3]]) + 0 * e([1,[3,4]]) + 0 * e([2,[3,4]]) + 0 * e([[3,5]]) + 0 * e([[1,4],4]) + 0 * e([[1,3],2,4]) + 0 * e([[1,2],[2,2],4]) + 0 * e([1,[2,3],4]) + 0 * e([[2,4],4]) + 0 * e([[1,3],3,4]) + 0 * e([[1,2],2,3,4]) + 0 * e([1,[2,2],3,4]) + 0 * e([[2,3],3,4]) + 0 * e([[1,2],[3,2],4]) + 0 * e([1,2,[3,2],4]) + 0 * e([[2,2],[3,2],4]) + 0 * e([1,[3,3],4]) + 0 * e([2,[3,3],4]) + 0 * e([[3,4],4]) + 0 * e([[1,3],[4,2]]) + 0 * e([[1,2],2,[4,2]]) + 0 * e([1,[2,2],[4,2]]) + 0 * e([[2,3],[4,2]]) + 0 * e([[1,2],3,[4,2]]) + 0 * e([1,2,3,[4,2]]) + 0 * e([[2,2],3,[4,2]]) + 0 * e([1,[3,2],[4,2]]) + 0 * e([2,[3,2],[4,2]]) + 0 * e([[3,3],[4,2]]) + 0 * e([[1,2],[4,3]]) + 0 * e([1,2,[4,3]]) + 0 * e([[2,2],[4,3]]) + 0 * e([1,3,[4,3]]) + 0 * e([2,3,[4,3]]) + 0 * e([[3,2],[4,3]]) + 0 * e([1,[4,4]]) + 0 * e([2,[4,4]]) + 0 * e([3,[4,4]]) + 0 * e([[4,5]]) + 0 * e([[1,4],5]) + 0 * e([[1,3],2,5]) + 0 * e([[1,2],[2,2],5]) + 0 * e([1,[2,3],5]) + 0 * e([[2,4],5]) + 0 * e([[1,3],3,5]) + 0 * e([[1,2],2,3,5]) + 0 * e([1,[2,2],3,5]) + 0 * e([[2,3],3,5]) + 0 * e([[1,2],[3,2],5]) + 0 * e([1,2,[3,2],5]) + 0 * e([[2,2],[3,2],5]) + 0 * e([1,[3,3],5]) + 0 * e([2,[3,3],5]) + 0 * e([[3,4],5]) + 0 * e([[1,3],4,5]) + 0 * e([[1,2],2,4,5]) + 0 * e([1,[2,2],4,5]) + 0 * e([[2,3],4,5]) + 0 * e([[ ...

# %%
# %timeit x1*x2
# Out:
# 66.4 µs ± 697 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit x1*3.7
# Out:
# 323 ns ± 1.38 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit x1*xr
# Out:
# 399 ns ± 10.1 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit mulr_to(x1,3.7,x3)
# Out:
# 269 ns ± 2.84 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit x1*x2

# %%
# %timeit 3.5*8.8
# Out:
# 8.9 ns ± 0.0666 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
a = 3
b = 8
# %timeit 3*8
# Out:
# 8.89 ns ± 0.104 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
x3

# %%
# %timeit mul(x1,xr)
# Out:
# 521 ns ± 6.9 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit mul(x1,x2)

# %%
# %timeit mul_to(x1,x2,x3)

# %%
x1*x2

# %%
x2

# %%
N1 = 1/2(1-xi)
N2 = 1/2(1+xi)
