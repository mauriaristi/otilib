# %%
# %reset -f
import sys
sys.path.append("/home/jose/Documents/Maestria/Codigo/OTI/build/")
import Calc_Cable as cab
import pyoti.sparse as oti
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator

# %%
#Reacciones en 0
def Rx_Ry(l,h,L0,A0,E,w,F,s,cargas,order,nbases):
    cargas[0][0] = F
    cargas[0][1] = s
    #convertir adimensionales
    gamma,delta,beta,Psi,Sigmas = cab.param_adim(l,h,L0,A0,E,w,cargas)

    #calcular las incognitas gi fi
    gi_0, fi_0 = 0.3, 0.4 #valores iniciales para iterar en newton
    gi_fi = cab.calc_gi_fi(order,nbases,gamma,delta,beta,Psi,Sigmas,gi_0,fi_0)
    Rx_Ry = gi_fi*w*L0
    return(Rx_Ry)

# %%
# punto x,y de la carga
def x_y(l,h,L0,A0,E,w,F,s,cargas,order,nbases):
    cargas[0][0] = F
    cargas[0][1] = s
    
    #convertir adimensionales
    gamma,delta,beta,Psi,Sigmas = cab.param_adim(l,h,L0,A0,E,w,cargas)

    #calcular las incognitas gi fi
    gi_0, fi_0 = 0.3, 0.4 #valores iniciales para iterar en newton
    gi_fi = cab.calc_gi_fi(order,nbases,gamma,delta,beta,Psi,Sigmas,gi_0,fi_0)
    xi_eta_tau = cab.solu(gi_fi[0],gi_fi[1],beta,Psi,Sigmas,Sigmas[1],1)
    x_y = oti.zeros((2,1),nbases=nbases,order=order)
    x_y[0,0] = xi_eta_tau[0]*L0
    x_y[1,0] = xi_eta_tau[1]*L0
    return(x_y)

# %%
def plot(x,y,order, xlabel,legend,figsize=(6,6)):
    fig1 = plt.figure(1,figsize=(6,6))
    mpl.rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 13}) 
    mpl.rc('text', usetex=True)
    plt.plot(x,y, label= "Orden " + str(order))
#     plt.yscale('log')
    plt.legend(loc=legend)
    plt.ylabel('Error relativo', fontsize='22')
    plt.xlabel(xlabel, fontsize='22')
    plt.grid(True)

# %%
def f(func,param_f):
    if func == "Rx":
        X = Rx_Ry(*param_f)[0]
    elif func == "x_y":
        X = x_y(*param_f)
    return(X)

# %%
def error_graph(param,func,porc_max=0,paso=0,zoom=False,zoom_exp=0,zoom_0_x=0,legend="lower left", 
                xmult=None,figsize=(6,6)):

    #Configuracion de los parámetros
    xlabel = r'$\frac{{\Delta {{{0}}}}}{{{0}}} \, [\%]$'.format(param)
    l,h,L0,A0,E,w,cargas = cab.leer_entradas("Irvine_1")
    cargas = cargas.astype(object)
    F = cargas[0][0]
    s = cargas[0][1]

    var = [l,h,L0,A0,E,w,F,s]
    var_str =["l","h","L_0","A_0","E","w","f_v","s"]
    var_index = var_str.index(param)

    # arreglo del delta como porcentaje
    if zoom==False:
        a= np.arange(1,porc_max,paso)/100
    else:
        a=10.**(np.arange(zoom_exp,0))
        param = param + "_zoom"
    b=-np.flip(a)
    porc = np.concatenate((b,[0],a))
    Delta_h = porc*var[var_index]

    # Perturbación
    nbases = 1
    order = 10
    e1 = oti.e(nbases, order=order)
    var[var_index] = var[var_index] + e1
    param_f = [var[0],var[1],var[2],var[3],var[4],var[5],var[6],var[7],cargas,order,nbases]
    
    X = f(func,param_f)
       
    #Calculo del error
    error_rel = np.zeros(len(Delta_h))
    for o in [1, 2, 3, 4, 5, 7, 10]:
        X_t = X.truncate([[1, o + 1]])
        j = 0
        for ht in Delta_h:
            param_f_ht = param_f.copy()
            param_f_ht[var_index] = param_f_ht[var_index] + ht
            param_f_ht[9] = o
            X_deltah_oti = f(func,param_f_ht)
            X_taylor = X_t.taylor_integrate([1],[ht])
            error_rel[j] = abs((oti.norm(X_deltah_oti).real - oti.norm(X_taylor).real))/oti.norm(X_deltah_oti).real
            j+=1
        plot(porc*100,error_rel,o,xlabel,legend,figsize=figsize)
    
    plt.ylim(-10e-17,10e-1)
    if zoom==True:
        plt.xscale('symlog',linthreshx=zoom_0_x)
    plt.yscale('symlog',linthreshy=1e-16, linscaley=1)
    if func is "Rx":
        plt.ylabel(r'Error relativo de $R_x$', fontsize='22')
    else:
        plt.ylabel(r'Error relativo de $\mathbf{p}(s_f)$', fontsize='22')
        
    if xmult is not None:
        
        ax = plt.gca()
        plt.minorticks_on()
        
        ax.xaxis.set_major_locator(MultipleLocator(xmult[0]))
        ax.xaxis.set_minor_locator(MultipleLocator(xmult[1]))

        plt.grid(which='major',color='#CCCCCC', linewidth=0.5)
        
        plt.grid(which='minor',color='#EEEEEE')
    plt.tight_layout()

# %%
#ERROR Rx vs % Delta_L0 entre -15% y 15%

#Escoger parámetro "l","h","L_0","A_0","E","w","F","s"
p="L_0"
#Escoger funcion "Rx", "x_y"
func="Rx"

error_graph(p,func,porc_max=25,paso=2,xmult=[10,5])
# plt.axis([-106,106,None, None])
plt.savefig("Error_taylor"+p+".pdf")
# Out:
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.

# %%
#ERROR Rx vs % Delta_L0  en ZOOM entre -1% y 1$

#Escoger parámetro "l","h","L_0","A_0","E","w","F","s"
p="L_0"
#Escoger funcion "Rx", "x_y"
func="Rx"

fig1 = plt.figure(1,figsize=(12,6))
error_graph(p,func,zoom=True,zoom_exp=-16,zoom_0_x=1e-7,legend="upper center")

plt.savefig("Error_taylor"+p+"_zoom.pdf")

# %%
#ERROR Rx vs % Delta_E entre -100% y 100%

#Escoger parámetro "l","h","L_0","A_0","E","w","F","s"
p="E"
#Escoger funcion "Rx", "x_y"
func="Rx"

error_graph(p,func,porc_max=106,paso=5,xmult=[20,5])
plt.savefig("Error_taylor"+p+".pdf")

# %%
#ERROR Rx vs % Delta_A0 entre -100% y 100%

#Escoger parámetro "l","h","L_0","A_0","E","w","F","s"
p="A_0"
#Escoger funcion "Rx", "x_y"
func="Rx"
error_graph(p,func,porc_max=106,paso=5,xmult=[20,5])
plt.savefig("Error_taylor"+p+".pdf")

# %%
#ERROR Rx vs % Delta_l entre -20% y 20%

#Escoger parámetro "l","h","L_0","A_0","E","w","F","s"
p="l"
#Escoger funcion "Rx", "x_y"
func="Rx"
error_graph(p,func,porc_max=25,paso=2,xmult=[10,5])
plt.savefig("Error_taylor"+p+".pdf")
# Out:
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.
# No converge. 50 it.

# %%
#ERROR Rx vs % Delta_F entre -100% y 100%

#Escoger parámetro "l","h","L_0","A_0","E","w","F","s"
p="f_v"
#Escoger funcion "Rx", "x_y"
func="Rx"
error_graph(p,func,porc_max=106,paso=5,xmult=[20,5])
plt.savefig("Error_taylor"+p+".pdf")

# %%
#ERROR x_y vs % Delta_F entre -100% y 100%

#Escoger parámetro "l","h","L_0","A_0","E","w","F","s"
p="f_v"
#Escoger funcion "Rx", "x_y"
func="x_y"
error_graph(p,func,porc_max=106,paso=5, xmult=[20,5])
plt.savefig("Error_taylor"+p+"_x_y.pdf")

# %%
#Lectura de datos de entrada
nbases = 1
order = 2
l,h,L0,A0,E,w,cargas = cab.leer_entradas("Irvine_0")
cargas = cargas.astype(object)
F = cargas[0][0]
s = cargas[0][1]

#Pertubar parametros 
e1 = oti.e(1,nbases=nbases, order=order)
F = F + e1
cargas[0][0] = F

xy = x_y(l,h,L0,A0,E,w,F,s,cargas,order,nbases)
x = (xy[0,0]*L0).get_deriv(0)
y = (xy[1,0]*L0).get_deriv(0)
print(x)
print(y)
# Out:
# niter:  7
# 0.2916023863208233
# 0.2644254467547399

# %%
print(A)
# Out:
# matso< shape: (101, 3),
#  - Column 0
# (0,0) 0 + 0 * e([1]) + 0 * e([[1,2]])
# (1,0) 0.00626342 - 3.82064e-05 * e([1]) + 9.86862e-07 * e([[1,2]])
# (2,0) 0.0126062 - 7.89217e-05 * e([1]) + 2.04277e-06 * e([[1,2]])
# (3,0) 0.0190297 - 0.00012221 * e([1]) + 3.16944e-06 * e([[1,2]])
# (4,0) 0.0255353 - 0.000168133 * e([1]) + 4.36837e-06 * e([[1,2]])
# (5,0) 0.0321243 - 0.000216751 * e([1]) + 5.64081e-06 * e([[1,2]])
# (6,0) 0.0387982 - 0.000268121 * e([1]) + 6.98771e-06 * e([[1,2]])
# (7,0) 0.0455581 - 0.000322296 * e([1]) + 8.40968e-06 * e([[1,2]])
# (8,0) 0.0524056 - 0.000379327 * e([1]) + 9.9069e-06 * e([[1,2]])
# (9,0) 0.0593418 - 0.000439258 * e([1]) + 1.1479e-05 * e([[1,2]])
# (10,0) 0.0663681 - 0.000502127 * e([1]) + 1.31252e-05 * e([[1,2]])
# (11,0) 0.0734856 - 0.000567966 * e([1]) + 1.48439e-05 * e([[1,2]])
# (12,0) 0.0806957 - 0.000636799 * e([1]) + 1.66329e-05 * e([[1,2]])
# (13,0) 0.0879994 - 0.000708642 * e([1]) + 1.84889e-05 * e([[1,2]])
# (14,0) 0.0953979 - 0.000783498 * e([1]) + 2.0408e-05 * e([[1,2]])
# (15,0) 0.102892 - 0.00086136 * e([1]) + 2.2385e-05 * e([[1,2]])
# (16,0) 0.110483 - 0.000942209 * e([1]) + 2.44136e-05 * e([[1,2]])
# (17,0) 0.118172 - 0.00102601 * e([1]) + 2.64862e-05 * e([[1,2]])
# (18,0) 0.125959 - 0.00111271 * e([1]) + 2.85937e-05 * e([[1,2]])
# (19,0) 0.133845 - 0.00120224 * e([1]) + 3.07256e-05 * e([[1,2]])
# (20,0) 0.14183 - 0.00129451 * e([1]) + 3.28696e-05 * e([[1,2]])
# (21,0) 0.149916 - 0.00138941 * e([1]) + 3.50117e-05 * e([[1,2]])
# (22,0) 0.158102 - 0.00148681 * e([1]) + 3.71358e-05 * e([[1,2]])
# (23,0) 0.166389 - 0.00158654 * e([1]) + 3.9224e-05 * e([[1,2]])
# (24,0) 0.174775 - 0.00168843 * e([1]) + 4.12563e-05 * e([[1,2]])
# (25,0) 0.183262 - 0.00179225 * e([1]) + 4.32104e-05 * e([[1,2]])
# (26,0) 0.191849 - 0.00189776 * e([1]) + 4.50621e-05 * e([[1,2]])
# (27,0) 0.200534 - 0.00200468 * e([1]) + 4.67847e-05 * e([[1,2]])
# (28,0) 0.202502 - 0.0020289 * e([1]) + 4.71516e-05 * e([[1,2]])
# (29,0) 0.209317 - 0.00196339 * e([1]) + 4.51315e-05 * e([[1,2]])
# (30,0) 0.218197 - 0.00188187 * e([1]) + 4.25275e-05 * e([[1,2]])
# (31,0) 0.227173 - 0.00180389 * e([1]) + 3.99353e-05 * e([[1,2]])
# (32,0) 0.236242 - 0.0017296 * e([1]) + 3.7365e-05 * e([[1,2]])
# (33,0) 0.245402 - 0.00165915 * e([1]) + 3.48273e-05 * e([[1,2]])
# (34,0) 0.254652 - 0.00159268 * e([1]) + 3.23332e-05 * e([[1,2]])
# (35,0) 0.263989 - 0.00153031 * e([1]) + 2.9894e-05 * e([[1,2]])
# (36,0) 0.273408 - 0.00147214 * e([1]) + 2.75212e-05 * e([[1,2]])
# (37,0) 0.282909 - 0.00141826 * e([1]) + 2.52263e-05 * e([[1,2]])
# (38,0) 0.292485 - 0.00136873 * e([1]) + 2.30205e-05 * e([[1,2]])
# (39,0) 0.302134 - 0.00132358 * e([1]) + 2.09148e-05 * e([[1,2]])
# (40,0) 0.311852 - 0.00128284 * e([1]) + 1.89195e-05 * e([[1,2]])
# (41,0) 0.321633 - 0.00124647 * e([1]) + 1.70441e-05 * e([[1,2]])
# (42,0) 0.331473 - 0.00121444 * e([1]) + 1.52972e-05 * e([[1,2]])
# (43,0) 0.341366 - 0.00118666 * e([1]) + 1.36862e-05 * e([[1,2]])
# (44,0) 0.351307 - 0.00116304 * e([1]) + 1.22171e-05 * e([[1,2]])
# (45,0) 0.361289 - 0.00114342 * e([1]) + 1.08945e-05 * e([[1,2]])
# (46,0) 0.371308 - 0.00112765 * e([1]) + 9.7213e-06 * e([[1,2]])
# (47,0) 0.381357 - 0.00111553 * e([1]) + 8.69855e-06 * e([[1,2]])
# (48,0) 0.391429 - 0.00110683 * e([1]) + 7.82565e-06 * e([[1,2]])
# (49,0) 0.401517 - 0.00110129 * e([1]) + 7.10018e-06 * e([[1,2]])
# (50,0) 0.411616 - 0.00109865 * e([1]) + 6.51795e-06 * e([[1,2]])
# (51,0) 0.421718 - 0.00109861 * e([1]) + 6.0731e-06 * e([[1,2]])
# (52,0) 0.431816 - 0.00110085 * e([1]) + 5.7582e-06 * e([[1,2]])
# (53,0) 0.441905 - 0.00110507 * e([1]) + 5.56445e-06 * e([[1,2]])
# (54,0) 0.451977 - 0.00111092 * e([1]) + 5.48184e-06 * e([[1,2]])
# (55,0) 0.462025 - 0.00111806 * e([1]) + 5.49938e-06 * e([[1,2]])
# (56,0) 0.472044 - 0.00112616 * e([1]) + 5.60536e-06 * e([[1,2]])
# (57,0) 0.482027 - 0.00113489 * e([1]) + 5.78756e-06 * e([[1,2]])
# (58,0) 0.491968 - 0.00114392 * e([1]) + 6.03351e-06 * e([[1,2]])
# (59,0) 0.501861 - 0.00115292 * e([1]) + 6.33074e-06 * e([[1,2]])
# (60,0) 0.5117 - 0.0011616 * e([1]) + 6.66698e-06 * e([[1,2]])
# (61,0) 0.521481 - 0.00116966 * e([1]) + 7.0304e-06 * e([[1,2]])
# (62,0) 0.531199 - 0.00117684 * e([1]) + 7.40975e-06 * e([[1,2]])
# (63,0) 0.540848 - 0.00118288 * e([1]) + 7.79452e-06 * e([[1,2]])
# (64,0) 0.550425 - 0.00118756 * e([1]) + 8.17507e-06 * e([[1,2]])
# (65,0) 0.559925 - 0.00119068 * e([1]) + 8.54269e-06 * e([[1,2]])
# (66,0) 0.569345 - 0.00119204 * e([1]) + 8.88969e-06 * e([[1,2]])
# (67,0) 0.578681 - 0.0011915 * e([1]) + 9.2094e-06 * e([[1,2]])
# (68,0) 0.587931 - 0.0011889 * e([1]) + 9.49617e-06 * e([[1,2]])
# (69,0) 0.597092 - 0.00118415 * e([1]) + 9.74538e-06 * e([[1,2]])
# (70,0) 0.606161 - 0.00117715 * e([1]) + 9.95337e-06 * e([[1,2]])
# (71,0) 0.615136 - 0.00116783 * e([1]) + 1.01174e-05 * e([[1,2]])
# (72,0) 0.624016 - 0.00115613 * e([1]) + 1.02355e-05 * e([[1,2]])
# (73,0) 0.632799 - 0.00114202 * e([1]) + 1.03067e-05 * e([[1,2]])
# (74,0) 0.641485 - 0.00112549 * e([1]) + 1.03305e-05 * e([[1,2]])
# (75,0) 0.650071 - 0.00110653 * e([1]) + 1.03071e-05 * e([[1,2]])
# (76,0) 0.658558 - 0.00108516 * e([1]) + 1.02372e-05 * e([[1,2]])
# (77,0) 0.666945 - 0.00106139 * e([1]) + 1.0122e-05 * e([[1,2]])
# (78,0) 0.675231 - 0.00103527 * e([1]) + 9.96313e-06 * e([[1,2]])
# (79,0) 0.683417 - 0.00100684 * e([1]) + 9.76236e-06 * e([[1,2]])
# (80,0) 0.691503 - 0.000976152 * e([1]) + 9.52185e-06 * e([[1,2]])
# (81,0) 0.699489 - 0.000943264 * e([1]) + 9.24389e-06 * e([[1,2]])
# (82,0) 0.707375 - 0.000908244 * e([1]) + 8.93091e-06 * e([[1,2]])
# (83,0) 0.715162 - 0.00087116 * e([1]) + 8.58541e-06 * e([[1,2]])
# (84,0) 0.72285 - 0.000832086 * e([1]) + 8.20995e-06 * e([[1,2]])
# (85,0) 0.730441 - 0.000791099 * e([1]) + 7.80708e-06 * e([[1,2]])
# (86,0) 0.737935 - 0.000748278 * e([1]) + 7.37933e-06 * e([[1,2]])
# (87,0) 0.745334 - 0.000703702 * e([1]) + 6.92918e-06 * e([[1,2]])
# (88,0) 0.752638 - 0.000657451 * e([1]) + 6.45906e-06 * e([[1,2]])
# (89,0) 0.759848 - 0.000609606 * e([1]) + 5.97129e-06 * e([[1,2]])
# (90,0) 0.766965 - 0.000560246 * e([1]) + 5.4681e-06 * e([[1,2]])
# (91,0) 0.773992 - 0.000509452 * e([1]) + 4.95164e-06 * e([[1,2]])
# (92,0) 0.780928 - 0.0004573 * e([1]) + 4.4239e-06 * e([[1,2]])
# (93,0) 0.787775 - 0.000403867 * e([1]) + 3.88681e-06 * e([[1,2]])
# (94,0) 0.794535 - 0.000349228 * e([1]) + 3.34212e-06 * e([[1,2]])
# (95,0) 0.801209 - 0.000293456 * e([1]) + 2.79153e-06 * e([[1,2]])
# (96,0) 0.807798 - 0.000236622 * e([1]) + 2.23656e-06 * e([[1,2]])
# (97,0) 0.814304 - 0.000178795 * e([1]) + 1.67865e-06 * e([[1,2]])
# (98,0) 0.820727 - 0.000120039 * e([1]) + 1.11913e-06 * e([[1,2]])
# (99,0) 0.82707 - 6.04206e-05 * e([1]) + 5.5921e-07 * e([[1,2]])
# (100,0) 0.833333 + 3.46945e-18 * e([1]) + 8.67362e-19 * e([[1,2]])
#  - Column 1
# (0,1) 0 + 0 * e([1]) + 0 * e([[1,2]])
# (1,1) 0.00792716 + 3.02664e-05 * e([1]) - 9.29596e-07 * e([[1,2]])
# (2,1) 0.0157909 + 6.31861e-05 * e([1]) - 1.9556e-06 * e([[1,2]])
# (3,1) 0.0235889 + 9.89248e-05 * e([1]) - 3.08576e-06 * e([[1,2]])
# (4,1) 0.0313184 + 0.000137657 * e([1]) - 4.32835e-06 * e([[1,2]])
# (5,1) 0.0389769 + 0.000179568 * e([1]) - 5.69216e-06 * e([[1,2]])
# (6,1) 0.0465616 + 0.000224852 * e([1]) - 7.18654e-06 * e([[1,2]])
# (7,1) 0.0540696 + 0.000273714 * e([1]) - 8.8214e-06 * e([[1,2]])
# (8,1) 0.0614978 + 0.000326371 * e([1]) - 1.06072e-05 * e([[1,2]])
# (9,1) 0.0688432 + 0.00038305 * e([1]) - 1.25551e-05 * e([[1,2]])
# (10,1) 0.0761025 + 0.000443988 * e([1]) - 1.46766e-05 * e([[1,2]])
# (11,1) 0.0832722 + 0.000509438 * e([1]) - 1.6984e-05 * e([[1,2]])
# (12,1) 0.0903489 + 0.000579659 * e([1]) - 1.94901e-05 * e([[1,2]])
# (13,1) 0.0973289 + 0.000654925 * e([1]) - 2.2208e-05 * e([[1,2]])
# (14,1) 0.104208 + 0.000735523 * e([1]) - 2.51515e-05 * e([[1,2]])
# (15,1) 0.110983 + 0.000821748 * e([1]) - 2.83349e-05 * e([[1,2]])
# (16,1) 0.117649 + 0.000913908 * e([1]) - 3.17725e-05 * e([[1,2]])
# (17,1) 0.124203 + 0.00101232 * e([1]) - 3.54793e-05 * e([[1,2]])
# (18,1) 0.130639 + 0.00111732 * e([1]) - 3.947e-05 * e([[1,2]])
# (19,1) 0.136953 + 0.00122924 * e([1]) - 4.37596e-05 * e([[1,2]])
# (20,1) 0.143141 + 0.00134842 * e([1]) - 4.83629e-05 * e([[1,2]])
# (21,1) 0.149198 + 0.00147523 * e([1]) - 5.32942e-05 * e([[1,2]])
# (22,1) 0.155118 + 0.00161002 * e([1]) - 5.85675e-05 * e([[1,2]])
# (23,1) 0.160896 + 0.00175315 * e([1]) - 6.41957e-05 * e([[1,2]])
# (24,1) 0.166529 + 0.00190498 * e([1]) - 7.01909e-05 * e([[1,2]])
# (25,1) 0.172009 + 0.00206589 * e([1]) - 7.65636e-05 * e([[1,2]])
# (26,1) 0.177331 + 0.00223622 * e([1]) - 8.33226e-05 * e([[1,2]])
# (27,1) 0.182491 + 0.00241633 * e([1]) - 9.04747e-05 * e([[1,2]])
# (28,1) 0.183629 + 0.00245824 * e([1]) - 9.21386e-05 * e([[1,2]])
# (29,1) 0.187482 + 0.0023424 * e([1]) - 9.08625e-05 * e([[1,2]])
# (30,1) 0.192298 + 0.00219215 * e([1]) - 8.9094e-05 * e([[1,2]])
# (31,1) 0.196935 + 0.00204123 * e([1]) - 8.71871e-05 * e([[1,2]])
# (32,1) 0.201385 + 0.0018899 * e([1]) - 8.51416e-05 * e([[1,2]])
# (33,1) 0.205644 + 0.00173843 * e([1]) - 8.29586e-05 * e([[1,2]])
# (34,1) 0.209706 + 0.0015871 * e([1]) - 8.06403e-05 * e([[1,2]])
# (35,1) 0.213564 + 0.00143625 * e([1]) - 7.81902e-05 * e([[1,2]])
# (36,1) 0.217214 + 0.00128619 * e([1]) - 7.56134e-05 * e([[1,2]])
# (37,1) 0.220649 + 0.00113727 * e([1]) - 7.29163e-05 * e([[1,2]])
# (38,1) 0.223864 + 0.000989844 * e([1]) - 7.01069e-05 * e([[1,2]])
# (39,1) 0.226855 + 0.000844292 * e([1]) - 6.71947e-05 * e([[1,2]])
# (40,1) 0.229616 + 0.000700988 * e([1]) - 6.41906e-05 * e([[1,2]])
# (41,1) 0.232142 + 0.000560317 * e([1]) - 6.11071e-05 * e([[1,2]])
# (42,1) 0.234429 + 0.000422665 * e([1]) - 5.79579e-05 * e([[1,2]])
# (43,1) 0.236474 + 0.000288416 * e([1]) - 5.47578e-05 * e([[1,2]])
# (44,1) 0.238271 + 0.000157947 * e([1]) - 5.15229e-05 * e([[1,2]])
# (45,1) 0.239818 + 3.16278e-05 * e([1]) - 4.82699e-05 * e([[1,2]])
# (46,1) 0.241112 - 9.0189e-05 * e([1]) - 4.50159e-05 * e([[1,2]])
# (47,1) 0.24215 - 0.000207168 * e([1]) - 4.17786e-05 * e([[1,2]])
# (48,1) 0.24293 - 0.000318996 * e([1]) - 3.85756e-05 * e([[1,2]])
# (49,1) 0.243452 - 0.000425387 * e([1]) - 3.54241e-05 * e([[1,2]])
# (50,1) 0.243712 - 0.000526083 * e([1]) - 3.23409e-05 * e([[1,2]])
# (51,1) 0.243712 - 0.00062086 * e([1]) - 2.93418e-05 * e([[1,2]])
# (52,1) 0.243452 - 0.000709528 * e([1]) - 2.64415e-05 * e([[1,2]])
# (53,1) 0.24293 - 0.000791936 * e([1]) - 2.36535e-05 * e([[1,2]])
# (54,1) 0.24215 - 0.000867968 * e([1]) - 2.09895e-05 * e([[1,2]])
# (55,1) 0.241112 - 0.00093755 * e([1]) - 1.84596e-05 * e([[1,2]])
# (56,1) 0.239818 - 0.00100064 * e([1]) - 1.60721e-05 * e([[1,2]])
# (57,1) 0.238271 - 0.00105725 * e([1]) - 1.38335e-05 * e([[1,2]])
# (58,1) 0.236474 - 0.00110741 * e([1]) - 1.17482e-05 * e([[1,2]])
# (59,1) 0.234429 - 0.0011512 * e([1]) - 9.81897e-06 * e([[1,2]])
# (60,1) 0.232142 - 0.00118872 * e([1]) - 8.0465e-06 * e([[1,2]])
# (61,1) 0.229616 - 0.0012201 * e([1]) - 6.42996e-06 * e([[1,2]])
# (62,1) 0.226855 - 0.00124553 * e([1]) - 4.96694e-06 * e([[1,2]])
# (63,1) 0.223864 - 0.00126517 * e([1]) - 3.65358e-06 * e([[1,2]])
# (64,1) 0.220649 - 0.00127925 * e([1]) - 2.48485e-06 * e([[1,2]])
# (65,1) 0.217214 - 0.00128798 * e([1]) - 1.45463e-06 * e([[1,2]])
# (66,1) 0.213564 - 0.00129161 * e([1]) - 5.5599e-07 * e([[1,2]])
# (67,1) 0.209706 - 0.0012904 * e([1]) + 2.18693e-07 * e([[1,2]])
# (68,1) 0.205644 - 0.0012846 * e([1]) + 8.7751e-07 * e([[1,2]])
# (69,1) 0.201385 - 0.00127447 * e([1]) + 1.42887e-06 * e([[1,2]])
# (70,1) 0.196935 - 0.00126029 * e([1]) + 1.88136e-06 * e([[1,2]])
# (71,1) 0.192298 - 0.00124233 * e([1]) + 2.24357e-06 * e([[1,2]])
# (72,1) 0.187482 - 0.00122084 * e([1]) + 2.524e-06 * e([[1,2]])
# (73,1) 0.182491 - 0.00119609 * e([1]) + 2.73097e-06 * e([[1,2]])
# (74,1) 0.177331 - 0.00116833 * e([1]) + 2.8725e-06 * e([[1,2]])
# (75,1) 0.172009 - 0.00113781 * e([1]) + 2.95627e-06 * e([[1,2]])
# (76,1) 0.166529 - 0.00110478 * e([1]) + 2.98954e-06 * e([[1,2]])
# (77,1) 0.160896 - 0.00106945 * e([1]) + 2.97916e-06 * e([[1,2]])
# (78,1) 0.155118 - 0.00103206 * e([1]) + 2.9315e-06 * e([[1,2]])
# (79,1) 0.149198 - 0.000992805 * e([1]) + 2.85247e-06 * e([[1,2]])
# (80,1) 0.143141 - 0.000951889 * e([1]) + 2.74746e-06 * e([[1,2]])
# (81,1) 0.136953 - 0.0009095 * e([1]) + 2.62144e-06 * e([[1,2]])
# (82,1) 0.130639 - 0.000865815 * e([1]) + 2.47888e-06 * e([[1,2]])
# (83,1) 0.124203 - 0.000820998 * e([1]) + 2.32382e-06 * e([[1,2]])
# (84,1) 0.117649 - 0.000775206 * e([1]) + 2.15985e-06 * e([[1,2]])
# (85,1) 0.110983 - 0.000728581 * e([1]) + 1.99018e-06 * e([[1,2]])
# (86,1) 0.104208 - 0.00068126 * e([1]) + 1.81764e-06 * e([[1,2]])
# (87,1) 0.0973289 - 0.000633366 * e([1]) + 1.64469e-06 * e([[1,2]])
# (88,1) 0.0903489 - 0.000585014 * e([1]) + 1.47349e-06 * e([[1,2]])
# (89,1) 0.0832722 - 0.00053631 * e([1]) + 1.30587e-06 * e([[1,2]])
# (90,1) 0.0761025 - 0.000487352 * e([1]) + 1.14341e-06 * e([[1,2]])
# (91,1) 0.0688432 - 0.000438229 * e([1]) + 9.87439e-07 * e([[1,2]])
# (92,1) 0.0614978 - 0.000389022 * e([1]) + 8.3905e-07 * e([[1,2]])
# (93,1) 0.0540696 - 0.000339807 * e([1]) + 6.99147e-07 * e([[1,2]])
# (94,1) 0.0465616 - 0.00029065 * e([1]) + 5.68449e-07 * e([[1,2]])
# (95,1) 0.0389769 - 0.000241614 * e([1]) + 4.47517e-07 * e([[1,2]])
# (96,1) 0.0313184 - 0.000192754 * e([1]) + 3.3677e-07 * e([[1,2]])
# (97,1) 0.0235889 - 0.00014412 * e([1]) + 2.36504e-07 * e([[1,2]])
# (98,1) 0.0157909 - 9.57566e-05 * e([1]) + 1.46905e-07 * e([[1,2]])
# (99,1) 0.00792716 - 4.77047e-05 * e([1]) + 6.80672e-08 * e([[1,2]])
# (100,1) 0 + 1.73472e-18 * e([1]) - 1.01644e-19 * e([[1,2]])
#  - Column 2
# (0,2) -1
# (1,2) 0.626841 + 0.0183935 * e([1]) + 4.43688e-05 * e([[1,2]])
# (2,2) 0.618979 + 0.0183606 * e([1]) + 4.53949e-05 * e([[1,2]])
# (3,2) 0.611183 + 0.0183249 * e([1]) + 4.65252e-05 * e([[1,2]])
# (4,2) 0.603455 + 0.0182863 * e([1]) + 4.77679e-05 * e([[1,2]])
# (5,2) 0.595798 + 0.0182444 * e([1]) + 4.91318e-05 * e([[1,2]])
# (6,2) 0.588214 + 0.0181992 * e([1]) + 5.06262e-05 * e([[1,2]])
# (7,2) 0.580708 + 0.0181504 * e([1]) + 5.22612e-05 * e([[1,2]])
# (8,2) 0.573281 + 0.0180977 * e([1]) + 5.40471e-05 * e([[1,2]])
# (9,2) 0.565937 + 0.0180411 * e([1]) + 5.59951e-05 * e([[1,2]])
# (10,2) 0.558679 + 0.0179802 * e([1]) + 5.81167e-05 * e([[1,2]])
# (11,2) 0.55151 + 0.0179148 * e([1]) + 6.04242e-05 * e([[1,2]])
# (12,2) 0.544435 + 0.0178447 * e([1]) + 6.29304e-05 * e([[1,2]])
# (13,2) 0.537456 + 0.0177695 * e([1]) + 6.56484e-05 * e([[1,2]])
# (14,2) 0.530578 + 0.0176889 * e([1]) + 6.8592e-05 * e([[1,2]])
# (15,2) 0.523804 + 0.0176027 * e([1]) + 7.17755e-05 * e([[1,2]])
# (16,2) 0.517139 + 0.0175106 * e([1]) + 7.52133e-05 * e([[1,2]])
# (17,2) 0.510587 + 0.0174123 * e([1]) + 7.89201e-05 * e([[1,2]])
# (18,2) 0.504152 + 0.0173073 * e([1]) + 8.29109e-05 * e([[1,2]])
# (19,2) 0.497838 + 0.0171955 * e([1]) + 8.72006e-05 * e([[1,2]])
# (20,2) 0.491651 + 0.0170763 * e([1]) + 9.1804e-05 * e([[1,2]])
# (21,2) 0.485596 + 0.0169496 * e([1]) + 9.67354e-05 * e([[1,2]])
# (22,2) 0.479677 + 0.0168148 * e([1]) + 0.000102009 * e([[1,2]])
# (23,2) 0.473899 + 0.0166718 * e([1]) + 0.000107637 * e([[1,2]])
# (24,2) 0.468268 + 0.01652 * e([1]) + 0.000113632 * e([[1,2]])
# (25,2) 0.462788 + 0.0163591 * e([1]) + 0.000120005 * e([[1,2]])
# (26,2) 0.457466 + 0.0161888 * e([1]) + 0.000126764 * e([[1,2]])
# (27,2) 0.452308 + 0.0160088 * e([1]) + 0.000133917 * e([[1,2]])
# (28,2) -1
# (29,2) 0.447317 + 0.00610864 * e([1]) + 9.63961e-05 * e([[1,2]])
# (30,2) 0.442501 + 0.00625888 * e([1]) + 9.46277e-05 * e([[1,2]])
# (31,2) 0.437866 + 0.00640978 * e([1]) + 9.27209e-05 * e([[1,2]])
# (32,2) 0.433416 + 0.00656111 * e([1]) + 9.06756e-05 * e([[1,2]])
# (33,2) 0.429157 + 0.00671257 * e([1]) + 8.84926e-05 * e([[1,2]])
# (34,2) 0.425096 + 0.00686388 * e([1]) + 8.61744e-05 * e([[1,2]])
# (35,2) 0.421239 + 0.00701472 * e([1]) + 8.37244e-05 * e([[1,2]])
# (36,2) 0.41759 + 0.00716477 * e([1]) + 8.11477e-05 * e([[1,2]])
# (37,2) 0.414155 + 0.00731368 * e([1]) + 7.84507e-05 * e([[1,2]])
# (38,2) 0.41094 + 0.00746109 * e([1]) + 7.56414e-05 * e([[1,2]])
# (39,2) 0.407949 + 0.00760663 * e([1]) + 7.27293e-05 * e([[1,2]])
# (40,2) 0.405189 + 0.00774992 * e([1]) + 6.97253e-05 * e([[1,2]])
# (41,2) 0.402663 + 0.00789058 * e([1]) + 6.66419e-05 * e([[1,2]])
# (42,2) 0.400376 + 0.00802822 * e([1]) + 6.34928e-05 * e([[1,2]])
# (43,2) 0.398332 + 0.00816246 * e([1]) + 6.02929e-05 * e([[1,2]])
# (44,2) 0.396535 + 0.00829292 * e([1]) + 5.70581e-05 * e([[1,2]])
# (45,2) 0.394988 + 0.00841923 * e([1]) + 5.38051e-05 * e([[1,2]])
# (46,2) 0.393694 + 0.00854103 * e([1]) + 5.05512e-05 * e([[1,2]])
# (47,2) 0.392656 + 0.008658 * e([1]) + 4.73141e-05 * e([[1,2]])
# (48,2) 0.391876 + 0.00876981 * e([1]) + 4.41111e-05 * e([[1,2]])
# (49,2) 0.391355 + 0.00887619 * e([1]) + 4.09598e-05 * e([[1,2]])
# (50,2) 0.391094 + 0.00897688 * e([1]) + 3.78767e-05 * e([[1,2]])
# (51,2) 0.391094 + 0.00907164 * e([1]) + 3.48776e-05 * e([[1,2]])
# (52,2) 0.391355 + 0.0091603 * e([1]) + 3.19775e-05 * e([[1,2]])
# (53,2) 0.391876 + 0.0092427 * e([1]) + 2.91895e-05 * e([[1,2]])
# (54,2) 0.392656 + 0.00931872 * e([1]) + 2.65256e-05 * e([[1,2]])
# (55,2) 0.393694 + 0.00938829 * e([1]) + 2.39958e-05 * e([[1,2]])
# (56,2) 0.394988 + 0.00945137 * e([1]) + 2.16084e-05 * e([[1,2]])
# (57,2) 0.396535 + 0.00950796 * e([1]) + 1.93699e-05 * e([[1,2]])
# (58,2) 0.398332 + 0.00955811 * e([1]) + 1.72848e-05 * e([[1,2]])
# (59,2) 0.400376 + 0.00960189 * e([1]) + 1.53556e-05 * e([[1,2]])
# (60,2) 0.402663 + 0.0096394 * e([1]) + 1.35832e-05 * e([[1,2]])
# (61,2) 0.405189 + 0.00967077 * e([1]) + 1.19668e-05 * e([[1,2]])
# (62,2) 0.407949 + 0.00969618 * e([1]) + 1.05039e-05 * e([[1,2]])
# (63,2) 0.41094 + 0.00971581 * e([1]) + 9.19061e-06 * e([[1,2]])
# (64,2) 0.414155 + 0.00972988 * e([1]) + 8.02198e-06 * e([[1,2]])
# (65,2) 0.41759 + 0.0097386 * e([1]) + 6.99186e-06 * e([[1,2]])
# (66,2) 0.421239 + 0.00974222 * e([1]) + 6.09332e-06 * e([[1,2]])
# (67,2) 0.425096 + 0.009741 * e([1]) + 5.31874e-06 * e([[1,2]])
# (68,2) 0.429157 + 0.00973518 * e([1]) + 4.66002e-06 * e([[1,2]])
# (69,2) 0.433416 + 0.00972505 * e([1]) + 4.10876e-06 * e([[1,2]])
# (70,2) 0.437866 + 0.00971085 * e([1]) + 3.65637e-06 * e([[1,2]])
# (71,2) 0.442501 + 0.00969288 * e([1]) + 3.29426e-06 * e([[1,2]])
# (72,2) 0.447317 + 0.00967138 * e([1]) + 3.01393e-06 * e([[1,2]])
# (73,2) 0.452308 + 0.00964661 * e([1]) + 2.80706e-06 * e([[1,2]])
# (74,2) 0.457466 + 0.00961884 * e([1]) + 2.66563e-06 * e([[1,2]])
# (75,2) 0.462788 + 0.00958832 * e([1]) + 2.58197e-06 * e([[1,2]])
# (76,2) 0.468268 + 0.00955527 * e([1]) + 2.5488e-06 * e([[1,2]])
# (77,2) 0.473899 + 0.00951993 * e([1]) + 2.55928e-06 * e([[1,2]])
# (78,2) 0.479677 + 0.00948253 * e([1]) + 2.60703e-06 * e([[1,2]])
# (79,2) 0.485596 + 0.00944326 * e([1]) + 2.68617e-06 * e([[1,2]])
# (80,2) 0.491651 + 0.00940233 * e([1]) + 2.79127e-06 * e([[1,2]])
# (81,2) 0.497838 + 0.00935993 * e([1]) + 2.9174e-06 * e([[1,2]])
# (82,2) 0.504152 + 0.00931623 * e([1]) + 3.06006e-06 * e([[1,2]])
# (83,2) 0.510587 + 0.00927141 * e([1]) + 3.21523e-06 * e([[1,2]])
# (84,2) 0.517139 + 0.0092256 * e([1]) + 3.37929e-06 * e([[1,2]])
# (85,2) 0.523804 + 0.00917897 * e([1]) + 3.54906e-06 * e([[1,2]])
# (86,2) 0.530578 + 0.00913163 * e([1]) + 3.7217e-06 * e([[1,2]])
# (87,2) 0.537456 + 0.00908373 * e([1]) + 3.89475e-06 * e([[1,2]])
# (88,2) 0.544435 + 0.00903536 * e([1]) + 4.06605e-06 * e([[1,2]])
# (89,2) 0.55151 + 0.00898665 * e([1]) + 4.23377e-06 * e([[1,2]])
# (90,2) 0.558679 + 0.00893768 * e([1]) + 4.39633e-06 * e([[1,2]])
# (91,2) 0.565937 + 0.00888854 * e([1]) + 4.55241e-06 * e([[1,2]])
# (92,2) 0.573281 + 0.00883933 * e([1]) + 4.7009e-06 * e([[1,2]])
# (93,2) 0.580708 + 0.0087901 * e([1]) + 4.8409e-06 * e([[1,2]])
# (94,2) 0.588214 + 0.00874093 * e([1]) + 4.9717e-06 * e([[1,2]])
# (95,2) 0.595798 + 0.00869188 * e([1]) + 5.09273e-06 * e([[1,2]])
# (96,2) 0.603455 + 0.00864301 * e([1]) + 5.20358e-06 * e([[1,2]])
# (97,2) 0.611183 + 0.00859436 * e([1]) + 5.30394e-06 * e([[1,2]])
# (98,2) 0.618979 + 0.00854599 * e([1]) + 5.39364e-06 * e([[1,2]])
# (99,2) 0.626841 + 0.00849793 * e([1]) + 5.47258e-06 * e([[1,2]])
# (100,2) -1
# >
