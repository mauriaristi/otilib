# %%
# %reset -f
import sys
# sys.path.append("/home/jose/Documents/Maestria/Codigo/OTI/build/")
# sys.path.append("/Users/maristi7/coding/otilib/build")
# sys.path.append("anterior/")
import Calc_Cable as cab
# import Calc_Cable_20201116 as cab_old
import pyoti.sparse as oti
import numpy as np
# %matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
mpl.rcParams.update(mpl.rcParamsDefault)
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Computer Modern Roman",
    "font.size": 12,
    "font.sans-serif": ["Helvetica"]
})

# %%
order = 2
nbases = 7

plt.figure(figsize=(7,4))
l,h,L0,A0,E,w,cargas = cab.leer_entradas("PlotCase")
cargas = cargas.astype(object)
F = cargas[0][0]
F = F + oti.e(1,order=order)
cargas[0][0] = F
#convertir adimensionales
gamma,delta,beta,Psi,Sigmas = cab.param_adim(l,h,L0,A0,E,w,cargas)
#calcular las incognitas gi fi
gi_0, fi_0 = 0.275, 0.275 #valores iniciales para iterar en newton
gi,fi = cab.calc_gi_fi(order,nbases,gamma,delta,beta,Psi,Sigmas,gi_0,fi_0)

#calcular curva
p = 100 #puntos de la curva
A = cab.curva(nbases,order,gi,fi,beta,Psi,Sigmas,p)

#Convertir a dimensionales    
x = (A[:,0]*L0).get_deriv(0)
y = (A[:,1]*L0).get_deriv(0)
T = (A[:,2]*w*L0).get_deriv(0)

cab.plot_curva(x,y,T,u,np.array([[None]]), [None], [None], [None],color=color )

ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.01))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.01))

ax.set_axisbelow(True)

plt.grid(which='major', color=(0.8,0.8,0.8))
plt.grid(which='minor', color=(0.9,0.9,0.9))

plt.xlabel(r'$x$')
plt.ylabel(r'$y$')

plt.axis('equal')

plt.legend(ncol=3,fontsize=11)

vals = ax.get_ylim()
ax.set_ylim((vals[0]-0.1,vals[1]-0.1))
plt.tight_layout()

plt.savefig("PlotCase.pdf")

plt.show()

# %%
#SOLUCION PARA EL CABLE DEL PAPER IRVINE
order = 10
nbases = 7


forceScale = 0.005

plt.figure(figsize=(7,4))

Xsol = []
Fsol = []
us = [0,1,2]
for u in range(3):
    #Lectura de datos de entrada
    l,h,L0,A0,E,w,cargas = cab.leer_entradas("Irvine_"+str(u))
    cargas = cargas.astype(object)
    F = cargas[0][0]
    Fsol.append(F)
    #Pertubar parametros 
#     e1 = oti.e(1,nbases=nbases, order=order)
#     e2 = oti.e(2,nbases=nbases, order=order)
#     e3 = oti.e(3,nbases=nbases, order=order)
#     e4 = oti.e(4,nbases=nbases, order=order)
#     e5 = oti.e(5,nbases=nbases, order=order)
#     e6 = oti.e(6,nbases=nbases, order=order)
    e7 = oti.e(1,nbases=nbases, order=order)
#     l = l + e1
#     h = h + e2
#     L0 = L0 + e3
#     A0 = A0 + e4
#     E = E + e5
#     w = w + e6
    F = F + e7
    cargas[0][0] = F
#     print(Sigmas)
    #convertir adimensionales
    gamma,delta,beta,Psi,Sigmas = cab.param_adim(l,h,L0,A0,E,w,cargas)

    #calcular las incognitas gi fi
    gi_0, fi_0 = 0.275, 0.275 #valores iniciales para iterar en newton
    gi,fi = cab.calc_gi_fi(order,nbases,gamma,delta,beta,Psi,Sigmas,gi_0,fi_0)
    #print(gi.real*w.real*L0.real,fi.real*w.real*L0.real)
    
    #calcular curva
    p = 100 #puntos de la curva
    A = cab.curva(nbases,order,gi,fi,beta,Psi,Sigmas,p)

    #Convertir a dimensionales    
    x = (A[:,0]*L0).get_deriv(0)
    y = (A[:,1]*L0).get_deriv(0)
    T = (A[:,2]*w*L0).get_deriv(0)

    Xsol.append(A[:,:2]*L0)
    color = None
    
    if u==0:
        color='k'
    elif u==1:
        color='C0'
    elif u==2:
        color='C1'
    # end if
    
    cab.plot_curva(x,y,T,u,np.array([[None]]), [None], [None], [None],color=color )
    
    xi, eta, tau = cab.solu(gi,fi,beta,Psi,Sigmas,Sigmas[1,0],0)
    xf,yf = (xi*L0).get_deriv(0),(eta*L0).get_deriv(0)
#     print(xf,yf)
    
    print(F.real*forceScale)
    plt.arrow(  xf[0,0],yf[0,0]-F.real*forceScale, 
                0, F.real*forceScale,
              width=0.005,
              head_width=0.015,
              head_length=0.03,
              color=color,
              zorder=1000,
              head_starts_at_zero=False,
             length_includes_head=True)
    #Calculo de curvas por modelo de orden reducido
    if u==2:
        x_1 = Xsol[0][:,0]
        y_1 = Xsol[0][:,1]
        # orders = [1,2,5,10]
        orders = [2,10]
        for ordi in orders:
            x_1_t = x_1.truncate_order(ordi)
            y_1_t = y_1.truncate_order(ordi)
            x_0 = x_1_t.rom_eval([1],[Fsol[1]-Fsol[0]]).get_deriv(0)
            y_0 = y_1_t.rom_eval([1],[Fsol[1]-Fsol[0]]).get_deriv(0)
            plt.plot(x_0,y_0, '--', lw=1.2, label="ROM order {0} LC1".format(ordi),zorder=1010)
            
        for ordi in orders:
            x_1_t = x_1.truncate_order(ordi)
            y_1_t = y_1.truncate_order(ordi)
            x_2 = x_1_t.rom_eval([1],[Fsol[2]-Fsol[0]]).get_deriv(0)
            y_2 = y_1_t.rom_eval([1],[Fsol[2]-Fsol[0]]).get_deriv(0)
            plt.plot(x_2,y_2, ':', lw=1.5, label="ROM order {0} LC2".format(ordi),zorder=1010)

    #Graficar cable
#     if u==0 or u==1:
#         cab.plot_curva(x,y,T,u,np.array([[None]]), [None], [None], [None] )
    
#     else:
#         cab.plot_curva(x,y,T,u,x_0,x_2,y_0,y_2)
        
       
        
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.01))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.01))

ax.set_axisbelow(True)

plt.grid(which='major', color=(0.8,0.8,0.8))
plt.grid(which='minor', color=(0.9,0.9,0.9))

plt.xlabel(r'$x$')
plt.ylabel(r'$y$')

plt.axis('equal')

plt.legend(ncol=3,fontsize=11)

vals = ax.get_ylim()
ax.set_ylim((vals[0]-0.1,vals[1]-0.1))
plt.tight_layout()
ord_str_name = str(orders).replace(" ","").replace(",",'_').replace("[","").replace("]","")
plt.savefig("Irvine_ROM_oti_{0}.pdf".format(ord_str_name))

plt.show()
# Out:
# Conf. 0: x = 0.22383389623785754 , y = 0.24128017734375387
# 0.049
# Conf. 1: x = 0.29076897820306424 , y = 0.1362093317460752
# -0.0735
# Conf. 2: x = 0.19994612779783041 , y = 0.26233398976124506
# 0.17149999999999999
# <img src="data:image/png;base64,..." width="700">

# %%
Fsol
# Out:
# [9.8, -14.7, 34.3]

# %%
plt.figure(figsize=(7,4))

# Error
rom = Xsol[0]
exac= Xsol[1]
NRMSEs = [None]*4
print(NRMSEs)
i=0
for ordi in [1,2,5,10]:
    NRMSEs[i]=[]
    rom_eval = rom.truncate_order(ordi)
    
    print("\nOrder: {0}".format(ordi))
    print(rom_eval[3,0])

    p_rom = rom_eval.rom_eval([1],[Fsol[1]-Fsol[0]]).real

    p_exac = exac.real
    
    se = (p_rom-p_exac)**2
    
    mse = np.sum(se)/se.size
    rmse = np.sqrt(mse)
    nrmse = rmse/np.linalg.norm(p_exac.mean(axis=0))#p_exac.mean()
    print(nrmse,np.linalg.norm(p_exac.mean(axis=0)),p_exac.mean())
    NRMSEs[i].append(nrmse)
    
    err = np.linalg.norm(p_rom-p_exac,axis=1)/p_exac.mean()#L0.real

    plt.semilogy((L0.real*np.linspace(0,1,p-1)),err[1:-1],label='ROM order '+str(ordi))
    i+=1

# end for 
print(NRMSEs)
ax = plt.gca()

ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.01))

plt.grid(which='major', color=(0.8,0.8,0.8))
plt.grid(which='minor', color=(0.9,0.9,0.9))

plt.xlabel(r'$s$')
plt.ylabel(r'Relative error')

plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [None, None, None, None]
#
# Order: 1
#  0.0216936 - 9.20971e-05 * e([1])
# 0.04257735498167109 0.5433948593572434 0.342543660906374
#
# Order: 2
#  0.0216936 - 9.20971e-05 * e([1]) + 2.03162e-06 * e([[1,2]])
# 0.0292485631481963 0.5433948593572434 0.342543660906374
#
# Order: 5
#  0.0216936 - 9.20971e-05 * e([1]) + 2.03162e-06 * e([[1,2]]) - 3.80604e-08 * e([[1,3]]) + 7.24528e-10 * e([[1,4]]) - 1.58002e-11 * e([[1,5]])
# 0.00670232247988993 0.5433948593572434 0.342543660906374
#
# Order: 10
#  0.0216936 - 9.20971e-05 * e([1]) + 2.03162e-06 * e([[1,2]]) - 3.80604e-08 * e([[1,3]]) + 7.24528e-10 * e([[1,4]]) - 1.58002e-11 * e([[1,5]]) + 4.00178e-13 * e([[1,6]]) - 1.09329e-14 * e([[1,7]]) + 2.96597e-16 * e([[1,8]]) - 7.48456e-18 * e([[1,9]]) + 1.63076e-19 * e([[1,10]])
# 0.0008987894180046757 0.5433948593572434 0.342543660906374
# [[0.04257735498167109], [0.0292485631481963], [0.00670232247988993], [0.0008987894180046757]]
# <img src="data:image/png;base64,..." width="700">

# %%
plt.figure(figsize=(7,4))

# Error
rom = Xsol[0]
exac= Xsol[2]

i=0
for ordi in [1,2,5,10]:
    
    rom_eval = rom.truncate_order(ordi)
    
    print("\nOrder: {0}".format(ordi))
    print(rom_eval[3,0])

    p_rom = rom_eval.rom_eval([1],[Fsol[2]-Fsol[0]]).real

    p_exac = exac.real
    
    se = (p_rom-p_exac)**2
    
    mse = np.sum(se)/se.size
    rmse = np.sqrt(mse)
    nrmse = rmse/np.linalg.norm(p_exac.mean(axis=0))#p_exac.mean()
    print(nrmse)
    err = np.linalg.norm(p_rom-p_exac,axis=1)/p_exac.mean()#L0.real
    NRMSEs[i].append(nrmse)
    plt.semilogy((L0.real*np.linspace(0,1,p-1)),err[1:-1],label='ROM order '+str(ordi))
    i+=1
# end for 

ax = plt.gca()

ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.01))

plt.grid(which='major', color=(0.8,0.8,0.8))
plt.grid(which='minor', color=(0.9,0.9,0.9))

plt.xlabel(r'$s$')
plt.ylabel(r'Relative error')

plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Order: 1
#  0.0216936 - 9.20971e-05 * e([1])
# 0.013891252380496263
#
# Order: 2
#  0.0216936 - 9.20971e-05 * e([1]) + 2.03162e-06 * e([[1,2]])
# 0.007578084756140336
#
# Order: 5
#  0.0216936 - 9.20971e-05 * e([1]) + 2.03162e-06 * e([[1,2]]) - 3.80604e-08 * e([[1,3]]) + 7.24528e-10 * e([[1,4]]) - 1.58002e-11 * e([[1,5]])
# 0.0024309476478349187
#
# Order: 10
#  0.0216936 - 9.20971e-05 * e([1]) + 2.03162e-06 * e([[1,2]]) - 3.80604e-08 * e([[1,3]]) + 7.24528e-10 * e([[1,4]]) - 1.58002e-11 * e([[1,5]]) + 4.00178e-13 * e([[1,6]]) - 1.09329e-14 * e([[1,7]]) + 2.96597e-16 * e([[1,8]]) - 7.48456e-18 * e([[1,9]]) + 1.63076e-19 * e([[1,10]])
# 0.000147907317079856
# <img src="data:image/png;base64,..." width="700">

# %%
NRMSEs = np.array(NRMSEs)
NRMSEs
# Out:
# array([[0.04257735, 0.01389125],
#        [0.02924856, 0.00757808],
#        [0.00670232, 0.00243095],
#        [0.00089879, 0.00014791]])

# %%
plt.figure(figsize=(7,4))

x = np.arange(NRMSEs.shape[0])
des = .15
plt.bar(x-des,NRMSEs[:,0],width=0.25,bottom=1e-4,label=r"Load case 1")
plt.bar(x+des,NRMSEs[:,1],width=0.25,bottom=1e-4,label=r"Load case 2")

ax = plt.gca()
ax.set_yscale('log')
ax.set_xticks(x)
ax.set_xticklabels([1,2,5,10])

ax.set_axisbelow(True)
ax.set_ylim(None,1e-1)
plt.grid()
plt.grid(which='minor',color=(0.9,0.9,0.9))

plt.legend()
plt.ylabel('NRMSE')
plt.xlabel('ROM order')
plt.tight_layout()
plt.savefig("NRMSE_ROM_Irvine.pdf",dpi=300)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
#SOLUCION PARA EL CABLE DEL PAPER IRVINE
order = 2
nbases = 6

for u in range(3):
    #Lectura de datos de entrada
    l,h,L0,A0,E,w,cargas = cab_old.leer_entradas("Irvine_"+str(u))
    
    #Pertubar parametros (no sirve para perturbar cargas y ubicacion s de las cargas)
    e1 = oti.e(1,nbases=nbases, order=order)
    e2 = oti.e(2,nbases=nbases, order=order)
    e3 = oti.e(3,nbases=nbases, order=order)
    e4 = oti.e(4,nbases=nbases, order=order)
    e5 = oti.e(5,nbases=nbases, order=order)
    e6 = oti.e(6,nbases=nbases, order=order)
    l = l + e1
    h = h + e2
    L0 = L0 + e3
    A0 = A0 + e4
    E = E + e5
    w = w + e6

    #convertir adimensionales
    gamma,delta,beta,Psi,Sigmas = cab_old.param_adim(l,h,L0,A0,E,w,cargas)

    #calcular las incognitas gi fi
    gi_0, fi_0 = 0.275, 0.275 #valores iniciales para iterar en newton
    gi,fi = cab_old.calc_gi_fi(order,nbases,gamma,delta,beta,Psi,Sigmas,gi_0,fi_0)

    #calcular curva
    p = 100 #puntos de la curva
    A = cab_old.curva(nbases,order,gi,fi,beta,Psi,Sigmas,p)

    #Convertir a dimensionales    
    x = (A[:,0]*L0).get_deriv(0)
    y = (A[:,1]*L0).get_deriv(0)
    T = (A[:,2]*w*L0).get_deriv(0)

    #Graficar cable
    cab_old.plot_curva(x,y,T,u)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 5>()
#       3 nbases = 6
#       5 for u in range(3):
#       6     #Lectura de datos de entrada
# ----> 7     l,h,L0,A0,E,w,cargas = cab_old.leer_entradas("Irvine_"+str(u))
#       9     #Pertubar parametros (no sirve para perturbar cargas y ubicacion s de las cargas)
#      10     e1 = oti.e(1,nbases=nbases, order=order)
#
# NameError: name 'cab_old' is not defined
