# %%
from numpy import arange, sin, cos, pi, abs
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
# Function F
def f(t):
    return sin(2*pi*t)
# end function

# %%
# definir t
t  = arange(0,2.0,0.02)

# evaluar (Derivada por el método de diferenciación directa/analitica.)
f_eval       = f(t)
df_analitica = 2*pi*cos(2*pi*t)

# %%
plt.figure()

plt.plot(t,       f_eval,'-C0',linewidth=1.5, label='f-eval')
plt.plot(t, df_analitica,'-C1',linewidth=1.5, label='df-analitic')
plt.xlabel("t")

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Uso de Complex.

h = 1e-10

# Perturbar t.
t_complejo = t + h * 1j

# Evaluar en t perturbado.
f_ceval  = f( t_complejo )

# %%
# Extraer información:
# Extraer Real
cf  = f_ceval.real

# Extraer Derivada
cdf = f_ceval.imag/h

# %%
plt.figure()

plt.plot(t,  cf,'.C2',linewidth=3.5, label='f-complex')
plt.plot(t, cdf,'.C3',linewidth=3.5, label='df-complex')
plt.xlabel("t")

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(figsize=(9,5))

plt.plot(t,           cf,'.C2',linewidth=1.5, label='f-complex')
plt.plot(t,          cdf,'.C3',linewidth=1.5, label='df-complex')
plt.plot(t,       f_eval,'-C0',linewidth=1.5, label='f-eval')
plt.plot(t, df_analitica,'-C1',linewidth=1.5, label='df-analitic')
plt.xlabel("t")

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
plt.figure(figsize=(9,5))

plt.semilogy(t,abs((      f_eval- cf)/      f_eval),'-C2',linewidth=1.5, label='f')
plt.semilogy(t,abs((df_analitica-cdf)/df_analitica),'-C3',linewidth=1.5, label='df')

plt.axis([None,None,1e-16,1e0])

plt.xlabel("t")
plt.ylabel("Relative error")
plt.legend()
plt.grid(which='both')
plt.grid(which='minor')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# //anaconda3/envs/pyoti/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# //anaconda3/envs/pyoti/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   This is separate from the ipykernel package so we can avoid doing imports until
# //anaconda3/envs/pyoti/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   after removing the cwd from sys.path.
