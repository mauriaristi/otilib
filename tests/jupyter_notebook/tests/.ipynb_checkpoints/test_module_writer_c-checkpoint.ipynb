# %%
import sys
import os
path2oti = '../../../build/'
sys.path.append(path2oti) # Add path to OTI library.

import pyoti.core   as coti
from pyoti.cmod_writer import writer

# %%
# w = writer(order = 2, nbases=2, mdual=True)
w = writer(order = 3, nbases=2, mdual=False)
# w.process_static_include_files(base_dir='../../../')
# w.process_headers_static(tab='  ', base_dir = '../../../' )

# %%
w.truncgem_like_function_oo(level = "", f_name = "", a_name= "a", a_ptr=True,
    b_name= "b", b_ptr=True, c_name= "c", c_ptr=True, res_name = "res", separator = " * ", 
    f_open = "(", f_close = ")",  addition = " + ", to=False, tab = '    '  )

# %%
for ord_lhs in range(w.order+1):
    print("//lhs order "+str(ord_lhs))
    for ord_rhs in range(w.order-ord_lhs+1):
        ord_res = ord_lhs + ord_rhs
#         if ord_res > w.order:
#             break
#         # end if 
        print("    //rhs order "+str(ord_rhs))
        print("        //res order "+str(ord_res))
        for k in range(len(w.mult_res_total[ord_res])):
            mults = w.mult_res_total[ord_res][k]
            str_out = '        res.'+ w.name_imdir[ord_res][k]+' = '
            for mult in mults:
                lhs = mult[0]
                rhs = mult[1]
                if lhs[1]==ord_lhs and rhs[1]==ord_rhs:
                    str_out += ' lhs.'+lhs[2]+' * '+'rhs.'+rhs[2] +" +"
                # end if 
            # end for
            print(str_out[:-1])
        # end for 
    # end for 
# end for
# Out:
# //lhs order 0
#     //rhs order 0
#         //res order 0
#         res.r =  lhs.r * rhs.r
#     //rhs order 1
#         //res order 1
#         res.e1 =  lhs.r * rhs.e1
#         res.e2 =  lhs.r * rhs.e2
#     //rhs order 2
#         //res order 2
#         res.e11 =  lhs.r * rhs.e11
#         res.e12 =  lhs.r * rhs.e12
#         res.e22 =  lhs.r * rhs.e22
#     //rhs order 3
#         //res order 3
#         res.e111 =  lhs.r * rhs.e111
#         res.e112 =  lhs.r * rhs.e112
#         res.e122 =  lhs.r * rhs.e122
#         res.e222 =  lhs.r * rhs.e222
#     //rhs order 4
#         //res order 4
#         res.e1111 =  lhs.r * rhs.e1111
#         res.e1112 =  lhs.r * rhs.e1112
#         res.e1122 =  lhs.r * rhs.e1122
#         res.e1222 =  lhs.r * rhs.e1222
#         res.e2222 =  lhs.r * rhs.e2222
#     //rhs order 5
#         //res order 5
#         res.e11111 =  lhs.r * rhs.e11111
#         res.e11112 =  lhs.r * rhs.e11112
#         res.e11122 =  lhs.r * rhs.e11122
#         res.e11222 =  lhs.r * rhs.e11222
#         res.e12222 =  lhs.r * rhs.e12222
#         res.e22222 =  lhs.r * rhs.e22222
#     //rhs order 6
#         //res order 6
#         res.e111111 =  lhs.r * rhs.e111111
#         res.e111112 =  lhs.r * rhs.e111112
#         res.e111122 =  lhs.r * rhs.e111122
#         res.e111222 =  lhs.r * rhs.e111222
#         res.e112222 =  lhs.r * rhs.e112222
#         res.e122222 =  lhs.r * rhs.e122222
#         res.e222222 =  lhs.r * rhs.e222222
#     //rhs order 7
#         //res order 7
#         res.e1111111 =  lhs.r * rhs.e1111111
#         res.e1111112 =  lhs.r * rhs.e1111112
#         res.e1111122 =  lhs.r * rhs.e1111122
#         res.e1111222 =  lhs.r * rhs.e1111222
#         res.e1112222 =  lhs.r * rhs.e1112222
#         res.e1122222 =  lhs.r * rhs.e1122222
#         res.e1222222 =  lhs.r * rhs.e1222222
#         res.e2222222 =  lhs.r * rhs.e2222222
#     //rhs order 8
#         //res order 8
#         res.e11111111 =  lhs.r * rhs.e11111111
#         res.e11111112 =  lhs.r * rhs.e11111112
#         res.e11111122 =  lhs.r * rhs.e11111122
#         res.e11111222 =  lhs.r * rhs.e11111222
#         res.e11112222 =  lhs.r * rhs.e11112222
#         res.e11122222 =  lhs.r * rhs.e11122222
#         res.e11222222 =  lhs.r * rhs.e11222222
#         res.e12222222 =  lhs.r * rhs.e12222222
#         res.e22222222 =  lhs.r * rhs.e22222222
#     //rhs order 9
#         //res order 9
#         res.e111111111 =  lhs.r * rhs.e111111111
#         res.e111111112 =  lhs.r * rhs.e111111112
#         res.e111111122 =  lhs.r * rhs.e111111122
#         res.e111111222 =  lhs.r * rhs.e111111222
#         res.e111112222 =  lhs.r * rhs.e111112222
#         res.e111122222 =  lhs.r * rhs.e111122222
#         res.e111222222 =  lhs.r * rhs.e111222222
#         res.e112222222 =  lhs.r * rhs.e112222222
#         res.e122222222 =  lhs.r * rhs.e122222222
#         res.e222222222 =  lhs.r * rhs.e222222222
#     //rhs order 10
#         //res order 10
#         res.e1111111111 =  lhs.r * rhs.e1111111111
#         res.e1111111112 =  lhs.r * rhs.e1111111112
#         res.e1111111122 =  lhs.r * rhs.e1111111122
#         res.e1111111222 =  lhs.r * rhs.e1111111222
#         res.e1111112222 =  lhs.r * rhs.e1111112222
#         res.e1111122222 =  lhs.r * rhs.e1111122222
#         res.e1111222222 =  lhs.r * rhs.e1111222222
#         res.e1112222222 =  lhs.r * rhs.e1112222222
#         res.e1122222222 =  lhs.r * rhs.e1122222222
#         res.e1222222222 =  lhs.r * rhs.e1222222222
#         res.e2222222222 =  lhs.r * rhs.e2222222222
# //lhs order 1
#     //rhs order 0
#         //res order 1
#         res.e1 =  lhs.e1 * rhs.r
#         res.e2 =  lhs.e2 * rhs.r
#     //rhs order 1
#         //res order 2
#         res.e11 =  lhs.e1 * rhs.e1
#         res.e12 =  lhs.e1 * rhs.e2 + lhs.e2 * rhs.e1
#         res.e22 =  lhs.e2 * rhs.e2
#     //rhs order 2
#         //res order 3
#         res.e111 =  lhs.e1 * rhs.e11
#         res.e112 =  lhs.e1 * rhs.e12 + lhs.e2 * rhs.e11
#         res.e122 =  lhs.e1 * rhs.e22 + lhs.e2 * rhs.e12
#         res.e222 =  lhs.e2 * rhs.e22
#     //rhs order 3
#         //res order 4
#         res.e1111 =  lhs.e1 * rhs.e111
#         res.e1112 =  lhs.e1 * rhs.e112 + lhs.e2 * rhs.e111
#         res.e1122 =  lhs.e1 * rhs.e122 + lhs.e2 * rhs.e112
#         res.e1222 =  lhs.e1 * rhs.e222 + lhs.e2 * rhs.e122
#         res.e2222 =  lhs.e2 * rhs.e222
#     //rhs order 4
#         //res order 5
#         res.e11111 =  lhs.e1 * rhs.e1111
#         res.e11112 =  lhs.e1 * rhs.e1112 + lhs.e2 * rhs.e1111
#         res.e11122 =  lhs.e1 * rhs.e1122 + lhs.e2 * rhs.e1112
#         res.e11222 =  lhs.e1 * rhs.e1222 + lhs.e2 * rhs.e1122
#         res.e12222 =  lhs.e1 * rhs.e2222 + lhs.e2 * rhs.e1222
#         res.e22222 =  lhs.e2 * rhs.e2222
#     //rhs order 5
#         //res order 6
#         res.e111111 =  lhs.e1 * rhs.e11111
#         res.e111112 =  lhs.e1 * rhs.e11112 + lhs.e2 * rhs.e11111
#         res.e111122 =  lhs.e1 * rhs.e11122 + lhs.e2 * rhs.e11112
#         res.e111222 =  lhs.e1 * rhs.e11222 + lhs.e2 * rhs.e11122
#         res.e112222 =  lhs.e1 * rhs.e12222 + lhs.e2 * rhs.e11222
#         res.e122222 =  lhs.e1 * rhs.e22222 + lhs.e2 * rhs.e12222
#         res.e222222 =  lhs.e2 * rhs.e22222
#     //rhs order 6
#         //res order 7
#         res.e1111111 =  lhs.e1 * rhs.e111111
#         res.e1111112 =  lhs.e1 * rhs.e111112 + lhs.e2 * rhs.e111111
#         res.e1111122 =  lhs.e1 * rhs.e111122 + lhs.e2 * rhs.e111112
#         res.e1111222 =  lhs.e1 * rhs.e111222 + lhs.e2 * rhs.e111122
#         res.e1112222 =  lhs.e1 * rhs.e112222 + lhs.e2 * rhs.e111222
#         res.e1122222 =  lhs.e1 * rhs.e122222 + lhs.e2 * rhs.e112222
#         res.e1222222 =  lhs.e1 * rhs.e222222 + lhs.e2 * rhs.e122222
#         res.e2222222 =  lhs.e2 * rhs.e222222
#     //rhs order 7
#         //res order 8
#         res.e11111111 =  lhs.e1 * rhs.e1111111
#         res.e11111112 =  lhs.e1 * rhs.e1111112 + lhs.e2 * rhs.e1111111
#         res.e11111122 =  lhs.e1 * rhs.e1111122 + lhs.e2 * rhs.e1111112
#         res.e11111222 =  lhs.e1 * rhs.e1111222 + lhs.e2 * rhs.e1111122
#         res.e11112222 =  lhs.e1 * rhs.e1112222 + lhs.e2 * rhs.e1111222
#         res.e11122222 =  lhs.e1 * rhs.e1122222 + lhs.e2 * rhs.e1112222
#         res.e11222222 =  lhs.e1 * rhs.e1222222 + lhs.e2 * rhs.e1122222
#         res.e12222222 =  lhs.e1 * rhs.e2222222 + lhs.e2 * rhs.e1222222
#         res.e22222222 =  lhs.e2 * rhs.e2222222
#     //rhs order 8
#         //res order 9
#         res.e111111111 =  lhs.e1 * rhs.e11111111
#         res.e111111112 =  lhs.e1 * rhs.e11111112 + lhs.e2 * rhs.e11111111
#         res.e111111122 =  lhs.e1 * rhs.e11111122 + lhs.e2 * rhs.e11111112
#         res.e111111222 =  lhs.e1 * rhs.e11111222 + lhs.e2 * rhs.e11111122
#         res.e111112222 =  lhs.e1 * rhs.e11112222 + lhs.e2 * rhs.e11111222
#         res.e111122222 =  lhs.e1 * rhs.e11122222 + lhs.e2 * rhs.e11112222
#         res.e111222222 =  lhs.e1 * rhs.e11222222 + lhs.e2 * rhs.e11122222
#         res.e112222222 =  lhs.e1 * rhs.e12222222 + lhs.e2 * rhs.e11222222
#         res.e122222222 =  lhs.e1 * rhs.e22222222 + lhs.e2 * rhs.e12222222
#         res.e222222222 =  lhs.e2 * rhs.e22222222
#     //rhs order 9
#         //res order 10
#         res.e1111111111 =  lhs.e1 * rhs.e111111111
#         res.e1111111112 =  lhs.e1 * rhs.e111111112 + lhs.e2 * rhs.e111111111
#         res.e1111111122 =  lhs.e1 * rhs.e111111122 + lhs.e2 * rhs.e111111112
#         res.e1111111222 =  lhs.e1 * rhs.e111111222 + lhs.e2 * rhs.e111111122
#         res.e1111112222 =  lhs.e1 * rhs.e111112222 + lhs.e2 * rhs.e111111222
#         res.e1111122222 =  lhs.e1 * rhs.e111122222 + lhs.e2 * rhs.e111112222
#         res.e1111222222 =  lhs.e1 * rhs.e111222222 + lhs.e2 * rhs.e111122222
#         res.e1112222222 =  lhs.e1 * rhs.e112222222 + lhs.e2 * rhs.e111222222
#         res.e1122222222 =  lhs.e1 * rhs.e122222222 + lhs.e2 * rhs.e112222222
#         res.e1222222222 =  lhs.e1 * rhs.e222222222 + lhs.e2 * rhs.e122222222
#         res.e2222222222 =  lhs.e2 * rhs.e222222222
# //lhs order 2
#     //rhs order 0
#         //res order 2
#         res.e11 =  lhs.e11 * rhs.r
#         res.e12 =  lhs.e12 * rhs.r
#         res.e22 =  lhs.e22 * rhs.r
#     //rhs order 1
#         //res order 3
#         res.e111 =  lhs.e11 * rhs.e1
#         res.e112 =  lhs.e12 * rhs.e1 + lhs.e11 * rhs.e2
#         res.e122 =  lhs.e22 * rhs.e1 + lhs.e12 * rhs.e2
#         res.e222 =  lhs.e22 * rhs.e2
#     //rhs order 2
#         //res order 4
#         res.e1111 =  lhs.e11 * rhs.e11
#         res.e1112 =  lhs.e11 * rhs.e12 + lhs.e12 * rhs.e11
#         res.e1122 =  lhs.e11 * rhs.e22 + lhs.e12 * rhs.e12 + lhs.e22 * rhs.e11
#         res.e1222 =  lhs.e12 * rhs.e22 + lhs.e22 * rhs.e12
#         res.e2222 =  lhs.e22 * rhs.e22
#     //rhs order 3
#         //res order 5
#         res.e11111 =  lhs.e11 * rhs.e111
#         res.e11112 =  lhs.e11 * rhs.e112 + lhs.e12 * rhs.e111
#         res.e11122 =  lhs.e11 * rhs.e122 + lhs.e12 * rhs.e112 + lhs.e22 * rhs.e111
#         res.e11222 =  lhs.e11 * rhs.e222 + lhs.e12 * rhs.e122 + lhs.e22 * rhs.e112
#         res.e12222 =  lhs.e12 * rhs.e222 + lhs.e22 * rhs.e122
#         res.e22222 =  lhs.e22 * rhs.e222
#     //rhs order 4
#         //res order 6
#         res.e111111 =  lhs.e11 * rhs.e1111
#         res.e111112 =  lhs.e11 * rhs.e1112 + lhs.e12 * rhs.e1111
#         res.e111122 =  lhs.e11 * rhs.e1122 + lhs.e12 * rhs.e1112 + lhs.e22 * rhs.e1111
#         res.e111222 =  lhs.e11 * rhs.e1222 + lhs.e12 * rhs.e1122 + lhs.e22 * rhs.e1112
#         res.e112222 =  lhs.e11 * rhs.e2222 + lhs.e12 * rhs.e1222 + lhs.e22 * rhs.e1122
#         res.e122222 =  lhs.e12 * rhs.e2222 + lhs.e22 * rhs.e1222
#         res.e222222 =  lhs.e22 * rhs.e2222
#     //rhs order 5
#         //res order 7
#         res.e1111111 =  lhs.e11 * rhs.e11111
#         res.e1111112 =  lhs.e11 * rhs.e11112 + lhs.e12 * rhs.e11111
#         res.e1111122 =  lhs.e11 * rhs.e11122 + lhs.e12 * rhs.e11112 + lhs.e22 * rhs.e11111
#         res.e1111222 =  lhs.e11 * rhs.e11222 + lhs.e12 * rhs.e11122 + lhs.e22 * rhs.e11112
#         res.e1112222 =  lhs.e11 * rhs.e12222 + lhs.e12 * rhs.e11222 + lhs.e22 * rhs.e11122
#         res.e1122222 =  lhs.e11 * rhs.e22222 + lhs.e12 * rhs.e12222 + lhs.e22 * rhs.e11222
#         res.e1222222 =  lhs.e12 * rhs.e22222 + lhs.e22 * rhs.e12222
#         res.e2222222 =  lhs.e22 * rhs.e22222
#     //rhs order 6
#         //res order 8
#         res.e11111111 =  lhs.e11 * rhs.e111111
#         res.e11111112 =  lhs.e11 * rhs.e111112 + lhs.e12 * rhs.e111111
#         res.e11111122 =  lhs.e11 * rhs.e111122 + lhs.e12 * rhs.e111112 + lhs.e22 * rhs.e111111
#         res.e11111222 =  lhs.e11 * rhs.e111222 + lhs.e12 * rhs.e111122 + lhs.e22 * rhs.e111112
#         res.e11112222 =  lhs.e11 * rhs.e112222 + lhs.e12 * rhs.e111222 + lhs.e22 * rhs.e111122
#         res.e11122222 =  lhs.e11 * rhs.e122222 + lhs.e12 * rhs.e112222 + lhs.e22 * rhs.e111222
#         res.e11222222 =  lhs.e11 * rhs.e222222 + lhs.e12 * rhs.e122222 + lhs.e22 * rhs.e112222
#         res.e12222222 =  lhs.e12 * rhs.e222222 + lhs.e22 * rhs.e122222
#         res.e22222222 =  lhs.e22 * rhs.e222222
#     //rhs order 7
#         //res order 9
#         res.e111111111 =  lhs.e11 * rhs.e1111111
#         res.e111111112 =  lhs.e11 * rhs.e1111112 + lhs.e12 * rhs.e1111111
#         res.e111111122 =  lhs.e11 * rhs.e1111122 + lhs.e12 * rhs.e1111112 + lhs.e22 * rhs.e1111111
#         res.e111111222 =  lhs.e11 * rhs.e1111222 + lhs.e12 * rhs.e1111122 + lhs.e22 * rhs.e1111112
#         res.e111112222 =  lhs.e11 * rhs.e1112222 + lhs.e12 * rhs.e1111222 + lhs.e22 * rhs.e1111122
#         res.e111122222 =  lhs.e11 * rhs.e1122222 + lhs.e12 * rhs.e1112222 + lhs.e22 * rhs.e1111222
#         res.e111222222 =  lhs.e11 * rhs.e1222222 + lhs.e12 * rhs.e1122222 + lhs.e22 * rhs.e1112222
#         res.e112222222 =  lhs.e11 * rhs.e2222222 + lhs.e12 * rhs.e1222222 + lhs.e22 * rhs.e1122222
#         res.e122222222 =  lhs.e12 * rhs.e2222222 + lhs.e22 * rhs.e1222222
#         res.e222222222 =  lhs.e22 * rhs.e2222222
#     //rhs order 8
#         //res order 10
#         res.e1111111111 =  lhs.e11 * rhs.e11111111
#         res.e1111111112 =  lhs.e11 * rhs.e11111112 + lhs.e12 * rhs.e11111111
#         res.e1111111122 =  lhs.e11 * rhs.e11111122 + lhs.e12 * rhs.e11111112 + lhs.e22 * rhs.e11111111
#         res.e1111111222 =  lhs.e11 * rhs.e11111222 + lhs.e12 * rhs.e11111122 + lhs.e22 * rhs.e11111112
#         res.e1111112222 =  lhs.e11 * rhs.e11112222 + lhs.e12 * rhs.e11111222 + lhs.e22 * rhs.e11111122
#         res.e1111122222 =  lhs.e11 * rhs.e11122222 + lhs.e12 * rhs.e11112222 + lhs.e22 * rhs.e11111222
#         res.e1111222222 =  lhs.e11 * rhs.e11222222 + lhs.e12 * rhs.e11122222 + lhs.e22 * rhs.e11112222
#         res.e1112222222 =  lhs.e11 * rhs.e12222222 + lhs.e12 * rhs.e11222222 + lhs.e22 * rhs.e11122222
#         res.e1122222222 =  lhs.e11 * rhs.e22222222 + lhs.e12 * rhs.e12222222 + lhs.e22 * rhs.e11222222
#         res.e1222222222 =  lhs.e12 * rhs.e22222222 + lhs.e22 * rhs.e12222222
#         res.e2222222222 =  lhs.e22 * rhs.e22222222
# //lhs order 3
#     //rhs order 0
#         //res order 3
#         res.e111 =  lhs.e111 * rhs.r
#         res.e112 =  lhs.e112 * rhs.r
#         res.e122 =  lhs.e122 * rhs.r
#         res.e222 =  lhs.e222 * rhs.r
#     //rhs order 1
#         //res order 4
#         res.e1111 =  lhs.e111 * rhs.e1
#         res.e1112 =  lhs.e112 * rhs.e1 + lhs.e111 * rhs.e2
#         res.e1122 =  lhs.e122 * rhs.e1 + lhs.e112 * rhs.e2
#         res.e1222 =  lhs.e222 * rhs.e1 + lhs.e122 * rhs.e2
#         res.e2222 =  lhs.e222 * rhs.e2
#     //rhs order 2
#         //res order 5
#         res.e11111 =  lhs.e111 * rhs.e11
#         res.e11112 =  lhs.e112 * rhs.e11 + lhs.e111 * rhs.e12
#         res.e11122 =  lhs.e122 * rhs.e11 + lhs.e112 * rhs.e12 + lhs.e111 * rhs.e22
#         res.e11222 =  lhs.e222 * rhs.e11 + lhs.e122 * rhs.e12 + lhs.e112 * rhs.e22
#         res.e12222 =  lhs.e222 * rhs.e12 + lhs.e122 * rhs.e22
#         res.e22222 =  lhs.e222 * rhs.e22
#     //rhs order 3
#         //res order 6
#         res.e111111 =  lhs.e111 * rhs.e111
#         res.e111112 =  lhs.e111 * rhs.e112 + lhs.e112 * rhs.e111
#         res.e111122 =  lhs.e111 * rhs.e122 + lhs.e112 * rhs.e112 + lhs.e122 * rhs.e111
#         res.e111222 =  lhs.e111 * rhs.e222 + lhs.e112 * rhs.e122 + lhs.e122 * rhs.e112 + lhs.e222 * rhs.e111
#         res.e112222 =  lhs.e112 * rhs.e222 + lhs.e122 * rhs.e122 + lhs.e222 * rhs.e112
#         res.e122222 =  lhs.e122 * rhs.e222 + lhs.e222 * rhs.e122
#         res.e222222 =  lhs.e222 * rhs.e222
#     //rhs order 4
#         //res order 7
#         res.e1111111 =  lhs.e111 * rhs.e1111
#         res.e1111112 =  lhs.e111 * rhs.e1112 + lhs.e112 * rhs.e1111
#         res.e1111122 =  lhs.e111 * rhs.e1122 + lhs.e112 * rhs.e1112 + lhs.e122 * rhs.e1111
#         res.e1111222 =  lhs.e111 * rhs.e1222 + lhs.e112 * rhs.e1122 + lhs.e122 * rhs.e1112 + lhs.e222 * rhs.e1111
#         res.e1112222 =  lhs.e111 * rhs.e2222 + lhs.e112 * rhs.e1222 + lhs.e122 * rhs.e1122 + lhs.e222 * rhs.e1112
#         res.e1122222 =  lhs.e112 * rhs.e2222 + lhs.e122 * rhs.e1222 + lhs.e222 * rhs.e1122
#         res.e1222222 =  lhs.e122 * rhs.e2222 + lhs.e222 * rhs.e1222
#         res.e2222222 =  lhs.e222 * rhs.e2222
#     //rhs order 5
#         //res order 8
#         res.e11111111 =  lhs.e111 * rhs.e11111
#         res.e11111112 =  lhs.e111 * rhs.e11112 + lhs.e112 * rhs.e11111
#         res.e11111122 =  lhs.e111 * rhs.e11122 + lhs.e112 * rhs.e11112 + lhs.e122 * rhs.e11111
#         res.e11111222 =  lhs.e111 * rhs.e11222 + lhs.e112 * rhs.e11122 + lhs.e122 * rhs.e11112 + lhs.e222 * rhs.e11111
#         res.e11112222 =  lhs.e111 * rhs.e12222 + lhs.e112 * rhs.e11222 + lhs.e122 * rhs.e11122 + lhs.e222 * rhs.e11112
#         res.e11122222 =  lhs.e111 * rhs.e22222 + lhs.e112 * rhs.e12222 + lhs.e122 * rhs.e11222 + lhs.e222 * rhs.e11122
#         res.e11222222 =  lhs.e112 * rhs.e22222 + lhs.e122 * rhs.e12222 + lhs.e222 * rhs.e11222
#         res.e12222222 =  lhs.e122 * rhs.e22222 + lhs.e222 * rhs.e12222
#         res.e22222222 =  lhs.e222 * rhs.e22222
#     //rhs order 6
#         //res order 9
#         res.e111111111 =  lhs.e111 * rhs.e111111
#         res.e111111112 =  lhs.e111 * rhs.e111112 + lhs.e112 * rhs.e111111
#         res.e111111122 =  lhs.e111 * rhs.e111122 + lhs.e112 * rhs.e111112 + lhs.e122 * rhs.e111111
#         res.e111111222 =  lhs.e111 * rhs.e111222 + lhs.e112 * rhs.e111122 + lhs.e122 * rhs.e111112 + lhs.e222 * rhs.e111111
#         res.e111112222 =  lhs.e111 * rhs.e112222 + lhs.e112 * rhs.e111222 + lhs.e122 * rhs.e111122 + lhs.e222 * rhs.e111112
#         res.e111122222 =  lhs.e111 * rhs.e122222 + lhs.e112 * rhs.e112222 + lhs.e122 * rhs.e111222 + lhs.e222 * rhs.e111122
#         res.e111222222 =  lhs.e111 * rhs.e222222 + lhs.e112 * rhs.e122222 + lhs.e122 * rhs.e112222 + lhs.e222 * rhs.e111222
#         res.e112222222 =  lhs.e112 * rhs.e222222 + lhs.e122 * rhs.e122222 + lhs.e222 * rhs.e112222
#         res.e122222222 =  lhs.e122 * rhs.e222222 + lhs.e222 * rhs.e122222
#         res.e222222222 =  lhs.e222 * rhs.e222222
#     //rhs order 7
#         //res order 10
#         res.e1111111111 =  lhs.e111 * rhs.e1111111
#         res.e1111111112 =  lhs.e111 * rhs.e1111112 + lhs.e112 * rhs.e1111111
#         res.e1111111122 =  lhs.e111 * rhs.e1111122 + lhs.e112 * rhs.e1111112 + lhs.e122 * rhs.e1111111
#         res.e1111111222 =  lhs.e111 * rhs.e1111222 + lhs.e112 * rhs.e1111122 + lhs.e122 * rhs.e1111112 + lhs.e222 * rhs.e1111111
#         res.e1111112222 =  lhs.e111 * rhs.e1112222 + lhs.e112 * rhs.e1111222 + lhs.e122 * rhs.e1111122 + lhs.e222 * rhs.e1111112
#         res.e1111122222 =  lhs.e111 * rhs.e1122222 + lhs.e112 * rhs.e1112222 + lhs.e122 * rhs.e1111222 + lhs.e222 * rhs.e1111122
#         res.e1111222222 =  lhs.e111 * rhs.e1222222 + lhs.e112 * rhs.e1122222 + lhs.e122 * rhs.e1112222 + lhs.e222 * rhs.e1111222
#         res.e1112222222 =  lhs.e111 * rhs.e2222222 + lhs.e112 * rhs.e1222222 + lhs.e122 * rhs.e1122222 + lhs.e222 * rhs.e1112222
#         res.e1122222222 =  lhs.e112 * rhs.e2222222 + lhs.e122 * rhs.e1222222 + lhs.e222 * rhs.e1122222
#         res.e1222222222 =  lhs.e122 * rhs.e2222222 + lhs.e222 * rhs.e1222222
#         res.e2222222222 =  lhs.e222 * rhs.e2222222
# //lhs order 4
#     //rhs order 0
#         //res order 4
#         res.e1111 =  lhs.e1111 * rhs.r
#         res.e1112 =  lhs.e1112 * rhs.r
#         res.e1122 =  lhs.e1122 * rhs.r
#         res.e1222 =  lhs.e1222 * rhs.r
#         res.e2222 =  lhs.e2222 * rhs.r
#     //rhs order 1
#         //res order 5
#         res.e11111 =  lhs.e1111 * rhs.e1
#         res.e11112 =  lhs.e1112 * rhs.e1 + lhs.e1111 * rhs.e2
#         res.e11122 =  lhs.e1122 * rhs.e1 + lhs.e1112 * rhs.e2
#         res.e11222 =  lhs.e1222 * rhs.e1 + lhs.e1122 * rhs.e2
#         res.e12222 =  lhs.e2222 * rhs.e1 + lhs.e1222 * rhs.e2
#         res.e22222 =  lhs.e2222 * rhs.e2
#     //rhs order 2
#         //res order 6
#         res.e111111 =  lhs.e1111 * rhs.e11
#         res.e111112 =  lhs.e1112 * rhs.e11 + lhs.e1111 * rhs.e12
#         res.e111122 =  lhs.e1122 * rhs.e11 + lhs.e1112 * rhs.e12 + lhs.e1111 * rhs.e22
#         res.e111222 =  lhs.e1222 * rhs.e11 + lhs.e1122 * rhs.e12 + lhs.e1112 * rhs.e22
#         res.e112222 =  lhs.e2222 * rhs.e11 + lhs.e1222 * rhs.e12 + lhs.e1122 * rhs.e22
#         res.e122222 =  lhs.e2222 * rhs.e12 + lhs.e1222 * rhs.e22
#         res.e222222 =  lhs.e2222 * rhs.e22
#     //rhs order 3
#         //res order 7
#         res.e1111111 =  lhs.e1111 * rhs.e111
#         res.e1111112 =  lhs.e1112 * rhs.e111 + lhs.e1111 * rhs.e112
#         res.e1111122 =  lhs.e1122 * rhs.e111 + lhs.e1112 * rhs.e112 + lhs.e1111 * rhs.e122
#         res.e1111222 =  lhs.e1222 * rhs.e111 + lhs.e1122 * rhs.e112 + lhs.e1112 * rhs.e122 + lhs.e1111 * rhs.e222
#         res.e1112222 =  lhs.e2222 * rhs.e111 + lhs.e1222 * rhs.e112 + lhs.e1122 * rhs.e122 + lhs.e1112 * rhs.e222
#         res.e1122222 =  lhs.e2222 * rhs.e112 + lhs.e1222 * rhs.e122 + lhs.e1122 * rhs.e222
#         res.e1222222 =  lhs.e2222 * rhs.e122 + lhs.e1222 * rhs.e222
#         res.e2222222 =  lhs.e2222 * rhs.e222
#     //rhs order 4
#         //res order 8
#         res.e11111111 =  lhs.e1111 * rhs.e1111
#         res.e11111112 =  lhs.e1111 * rhs.e1112 + lhs.e1112 * rhs.e1111
#         res.e11111122 =  lhs.e1111 * rhs.e1122 + lhs.e1112 * rhs.e1112 + lhs.e1122 * rhs.e1111
#         res.e11111222 =  lhs.e1111 * rhs.e1222 + lhs.e1112 * rhs.e1122 + lhs.e1122 * rhs.e1112 + lhs.e1222 * rhs.e1111
#         res.e11112222 =  lhs.e1111 * rhs.e2222 + lhs.e1112 * rhs.e1222 + lhs.e1122 * rhs.e1122 + lhs.e1222 * rhs.e1112 + lhs.e2222 * rhs.e1111
#         res.e11122222 =  lhs.e1112 * rhs.e2222 + lhs.e1122 * rhs.e1222 + lhs.e1222 * rhs.e1122 + lhs.e2222 * rhs.e1112
#         res.e11222222 =  lhs.e1122 * rhs.e2222 + lhs.e1222 * rhs.e1222 + lhs.e2222 * rhs.e1122
#         res.e12222222 =  lhs.e1222 * rhs.e2222 + lhs.e2222 * rhs.e1222
#         res.e22222222 =  lhs.e2222 * rhs.e2222
#     //rhs order 5
#         //res order 9
#         res.e111111111 =  lhs.e1111 * rhs.e11111
#         res.e111111112 =  lhs.e1111 * rhs.e11112 + lhs.e1112 * rhs.e11111
#         res.e111111122 =  lhs.e1111 * rhs.e11122 + lhs.e1112 * rhs.e11112 + lhs.e1122 * rhs.e11111
#         res.e111111222 =  lhs.e1111 * rhs.e11222 + lhs.e1112 * rhs.e11122 + lhs.e1122 * rhs.e11112 + lhs.e1222 * rhs.e11111
#         res.e111112222 =  lhs.e1111 * rhs.e12222 + lhs.e1112 * rhs.e11222 + lhs.e1122 * rhs.e11122 + lhs.e1222 * rhs.e11112 + lhs.e2222 * rhs.e11111
#         res.e111122222 =  lhs.e1111 * rhs.e22222 + lhs.e1112 * rhs.e12222 + lhs.e1122 * rhs.e11222 + lhs.e1222 * rhs.e11122 + lhs.e2222 * rhs.e11112
#         res.e111222222 =  lhs.e1112 * rhs.e22222 + lhs.e1122 * rhs.e12222 + lhs.e1222 * rhs.e11222 + lhs.e2222 * rhs.e11122
#         res.e112222222 =  lhs.e1122 * rhs.e22222 + lhs.e1222 * rhs.e12222 + lhs.e2222 * rhs.e11222
#         res.e122222222 =  lhs.e1222 * rhs.e22222 + lhs.e2222 * rhs.e12222
#         res.e222222222 =  lhs.e2222 * rhs.e22222
#     //rhs order 6
#         //res order 10
#         res.e1111111111 =  lhs.e1111 * rhs.e111111
#         res.e1111111112 =  lhs.e1111 * rhs.e111112 + lhs.e1112 * rhs.e111111
#         res.e1111111122 =  lhs.e1111 * rhs.e111122 + lhs.e1112 * rhs.e111112 + lhs.e1122 * rhs.e111111
#         res.e1111111222 =  lhs.e1111 * rhs.e111222 + lhs.e1112 * rhs.e111122 + lhs.e1122 * rhs.e111112 + lhs.e1222 * rhs.e111111
#         res.e1111112222 =  lhs.e1111 * rhs.e112222 + lhs.e1112 * rhs.e111222 + lhs.e1122 * rhs.e111122 + lhs.e1222 * rhs.e111112 + lhs.e2222 * rhs.e111111
#         res.e1111122222 =  lhs.e1111 * rhs.e122222 + lhs.e1112 * rhs.e112222 + lhs.e1122 * rhs.e111222 + lhs.e1222 * rhs.e111122 + lhs.e2222 * rhs.e111112
#         res.e1111222222 =  lhs.e1111 * rhs.e222222 + lhs.e1112 * rhs.e122222 + lhs.e1122 * rhs.e112222 + lhs.e1222 * rhs.e111222 + lhs.e2222 * rhs.e111122
#         res.e1112222222 =  lhs.e1112 * rhs.e222222 + lhs.e1122 * rhs.e122222 + lhs.e1222 * rhs.e112222 + lhs.e2222 * rhs.e111222
#         res.e1122222222 =  lhs.e1122 * rhs.e222222 + lhs.e1222 * rhs.e122222 + lhs.e2222 * rhs.e112222
#         res.e1222222222 =  lhs.e1222 * rhs.e222222 + lhs.e2222 * rhs.e122222
#         res.e2222222222 =  lhs.e2222 * rhs.e222222
# //lhs order 5
#     //rhs order 0
#         //res order 5
#         res.e11111 =  lhs.e11111 * rhs.r
#         res.e11112 =  lhs.e11112 * rhs.r
#         res.e11122 =  lhs.e11122 * rhs.r
#         res.e11222 =  lhs.e11222 * rhs.r
#         res.e12222 =  lhs.e12222 * rhs.r
#         res.e22222 =  lhs.e22222 * rhs.r
#     //rhs order 1
#         //res order 6
#         res.e111111 =  lhs.e11111 * rhs.e1
#         res.e111112 =  lhs.e11112 * rhs.e1 + lhs.e11111 * rhs.e2
#         res.e111122 =  lhs.e11122 * rhs.e1 + lhs.e11112 * rhs.e2
#         res.e111222 =  lhs.e11222 * rhs.e1 + lhs.e11122 * rhs.e2
#         res.e112222 =  lhs.e12222 * rhs.e1 + lhs.e11222 * rhs.e2
#         res.e122222 =  lhs.e22222 * rhs.e1 + lhs.e12222 * rhs.e2
#         res.e222222 =  lhs.e22222 * rhs.e2
#     //rhs order 2
#         //res order 7
#         res.e1111111 =  lhs.e11111 * rhs.e11
#         res.e1111112 =  lhs.e11112 * rhs.e11 + lhs.e11111 * rhs.e12
#         res.e1111122 =  lhs.e11122 * rhs.e11 + lhs.e11112 * rhs.e12 + lhs.e11111 * rhs.e22
#         res.e1111222 =  lhs.e11222 * rhs.e11 + lhs.e11122 * rhs.e12 + lhs.e11112 * rhs.e22
#         res.e1112222 =  lhs.e12222 * rhs.e11 + lhs.e11222 * rhs.e12 + lhs.e11122 * rhs.e22
#         res.e1122222 =  lhs.e22222 * rhs.e11 + lhs.e12222 * rhs.e12 + lhs.e11222 * rhs.e22
#         res.e1222222 =  lhs.e22222 * rhs.e12 + lhs.e12222 * rhs.e22
#         res.e2222222 =  lhs.e22222 * rhs.e22
#     //rhs order 3
#         //res order 8
#         res.e11111111 =  lhs.e11111 * rhs.e111
#         res.e11111112 =  lhs.e11112 * rhs.e111 + lhs.e11111 * rhs.e112
#         res.e11111122 =  lhs.e11122 * rhs.e111 + lhs.e11112 * rhs.e112 + lhs.e11111 * rhs.e122
#         res.e11111222 =  lhs.e11222 * rhs.e111 + lhs.e11122 * rhs.e112 + lhs.e11112 * rhs.e122 + lhs.e11111 * rhs.e222
#         res.e11112222 =  lhs.e12222 * rhs.e111 + lhs.e11222 * rhs.e112 + lhs.e11122 * rhs.e122 + lhs.e11112 * rhs.e222
#         res.e11122222 =  lhs.e22222 * rhs.e111 + lhs.e12222 * rhs.e112 + lhs.e11222 * rhs.e122 + lhs.e11122 * rhs.e222
#         res.e11222222 =  lhs.e22222 * rhs.e112 + lhs.e12222 * rhs.e122 + lhs.e11222 * rhs.e222
#         res.e12222222 =  lhs.e22222 * rhs.e122 + lhs.e12222 * rhs.e222
#         res.e22222222 =  lhs.e22222 * rhs.e222
#     //rhs order 4
#         //res order 9
#         res.e111111111 =  lhs.e11111 * rhs.e1111
#         res.e111111112 =  lhs.e11112 * rhs.e1111 + lhs.e11111 * rhs.e1112
#         res.e111111122 =  lhs.e11122 * rhs.e1111 + lhs.e11112 * rhs.e1112 + lhs.e11111 * rhs.e1122
#         res.e111111222 =  lhs.e11222 * rhs.e1111 + lhs.e11122 * rhs.e1112 + lhs.e11112 * rhs.e1122 + lhs.e11111 * rhs.e1222
#         res.e111112222 =  lhs.e12222 * rhs.e1111 + lhs.e11222 * rhs.e1112 + lhs.e11122 * rhs.e1122 + lhs.e11112 * rhs.e1222 + lhs.e11111 * rhs.e2222
#         res.e111122222 =  lhs.e22222 * rhs.e1111 + lhs.e12222 * rhs.e1112 + lhs.e11222 * rhs.e1122 + lhs.e11122 * rhs.e1222 + lhs.e11112 * rhs.e2222
#         res.e111222222 =  lhs.e22222 * rhs.e1112 + lhs.e12222 * rhs.e1122 + lhs.e11222 * rhs.e1222 + lhs.e11122 * rhs.e2222
#         res.e112222222 =  lhs.e22222 * rhs.e1122 + lhs.e12222 * rhs.e1222 + lhs.e11222 * rhs.e2222
#         res.e122222222 =  lhs.e22222 * rhs.e1222 + lhs.e12222 * rhs.e2222
#         res.e222222222 =  lhs.e22222 * rhs.e2222
#     //rhs order 5
#         //res order 10
#         res.e1111111111 =  lhs.e11111 * rhs.e11111
#         res.e1111111112 =  lhs.e11111 * rhs.e11112 + lhs.e11112 * rhs.e11111
#         res.e1111111122 =  lhs.e11111 * rhs.e11122 + lhs.e11112 * rhs.e11112 + lhs.e11122 * rhs.e11111
#         res.e1111111222 =  lhs.e11111 * rhs.e11222 + lhs.e11112 * rhs.e11122 + lhs.e11122 * rhs.e11112 + lhs.e11222 * rhs.e11111
#         res.e1111112222 =  lhs.e11111 * rhs.e12222 + lhs.e11112 * rhs.e11222 + lhs.e11122 * rhs.e11122 + lhs.e11222 * rhs.e11112 + lhs.e12222 * rhs.e11111
#         res.e1111122222 =  lhs.e11111 * rhs.e22222 + lhs.e11112 * rhs.e12222 + lhs.e11122 * rhs.e11222 + lhs.e11222 * rhs.e11122 + lhs.e12222 * rhs.e11112 + lhs.e22222 * rhs.e11111
#         res.e1111222222 =  lhs.e11112 * rhs.e22222 + lhs.e11122 * rhs.e12222 + lhs.e11222 * rhs.e11222 + lhs.e12222 * rhs.e11122 + lhs.e22222 * rhs.e11112
#         res.e1112222222 =  lhs.e11122 * rhs.e22222 + lhs.e11222 * rhs.e12222 + lhs.e12222 * rhs.e11222 + lhs.e22222 * rhs.e11122
#         res.e1122222222 =  lhs.e11222 * rhs.e22222 + lhs.e12222 * rhs.e12222 + lhs.e22222 * rhs.e11222
#         res.e1222222222 =  lhs.e12222 * rhs.e22222 + lhs.e22222 * rhs.e12222
#         res.e2222222222 =  lhs.e22222 * rhs.e22222
# //lhs order 6
#     //rhs order 0
#         //res order 6
#         res.e111111 =  lhs.e111111 * rhs.r
#         res.e111112 =  lhs.e111112 * rhs.r
#         res.e111122 =  lhs.e111122 * rhs.r
#         res.e111222 =  lhs.e111222 * rhs.r
#         res.e112222 =  lhs.e112222 * rhs.r
#         res.e122222 =  lhs.e122222 * rhs.r
#         res.e222222 =  lhs.e222222 * rhs.r
#     //rhs order 1
#         //res order 7
#         res.e1111111 =  lhs.e111111 * rhs.e1
#         res.e1111112 =  lhs.e111112 * rhs.e1 + lhs.e111111 * rhs.e2
#         res.e1111122 =  lhs.e111122 * rhs.e1 + lhs.e111112 * rhs.e2
#         res.e1111222 =  lhs.e111222 * rhs.e1 + lhs.e111122 * rhs.e2
#         res.e1112222 =  lhs.e112222 * rhs.e1 + lhs.e111222 * rhs.e2
#         res.e1122222 =  lhs.e122222 * rhs.e1 + lhs.e112222 * rhs.e2
#         res.e1222222 =  lhs.e222222 * rhs.e1 + lhs.e122222 * rhs.e2
#         res.e2222222 =  lhs.e222222 * rhs.e2
#     //rhs order 2
#         //res order 8
#         res.e11111111 =  lhs.e111111 * rhs.e11
#         res.e11111112 =  lhs.e111112 * rhs.e11 + lhs.e111111 * rhs.e12
#         res.e11111122 =  lhs.e111122 * rhs.e11 + lhs.e111112 * rhs.e12 + lhs.e111111 * rhs.e22
#         res.e11111222 =  lhs.e111222 * rhs.e11 + lhs.e111122 * rhs.e12 + lhs.e111112 * rhs.e22
#         res.e11112222 =  lhs.e112222 * rhs.e11 + lhs.e111222 * rhs.e12 + lhs.e111122 * rhs.e22
#         res.e11122222 =  lhs.e122222 * rhs.e11 + lhs.e112222 * rhs.e12 + lhs.e111222 * rhs.e22
#         res.e11222222 =  lhs.e222222 * rhs.e11 + lhs.e122222 * rhs.e12 + lhs.e112222 * rhs.e22
#         res.e12222222 =  lhs.e222222 * rhs.e12 + lhs.e122222 * rhs.e22
#         res.e22222222 =  lhs.e222222 * rhs.e22
#     //rhs order 3
#         //res order 9
#         res.e111111111 =  lhs.e111111 * rhs.e111
#         res.e111111112 =  lhs.e111112 * rhs.e111 + lhs.e111111 * rhs.e112
#         res.e111111122 =  lhs.e111122 * rhs.e111 + lhs.e111112 * rhs.e112 + lhs.e111111 * rhs.e122
#         res.e111111222 =  lhs.e111222 * rhs.e111 + lhs.e111122 * rhs.e112 + lhs.e111112 * rhs.e122 + lhs.e111111 * rhs.e222
#         res.e111112222 =  lhs.e112222 * rhs.e111 + lhs.e111222 * rhs.e112 + lhs.e111122 * rhs.e122 + lhs.e111112 * rhs.e222
#         res.e111122222 =  lhs.e122222 * rhs.e111 + lhs.e112222 * rhs.e112 + lhs.e111222 * rhs.e122 + lhs.e111122 * rhs.e222
#         res.e111222222 =  lhs.e222222 * rhs.e111 + lhs.e122222 * rhs.e112 + lhs.e112222 * rhs.e122 + lhs.e111222 * rhs.e222
#         res.e112222222 =  lhs.e222222 * rhs.e112 + lhs.e122222 * rhs.e122 + lhs.e112222 * rhs.e222
#         res.e122222222 =  lhs.e222222 * rhs.e122 + lhs.e122222 * rhs.e222
#         res.e222222222 =  lhs.e222222 * rhs.e222
#     //rhs order 4
#         //res order 10
#         res.e1111111111 =  lhs.e111111 * rhs.e1111
#         res.e1111111112 =  lhs.e111112 * rhs.e1111 + lhs.e111111 * rhs.e1112
#         res.e1111111122 =  lhs.e111122 * rhs.e1111 + lhs.e111112 * rhs.e1112 + lhs.e111111 * rhs.e1122
#         res.e1111111222 =  lhs.e111222 * rhs.e1111 + lhs.e111122 * rhs.e1112 + lhs.e111112 * rhs.e1122 + lhs.e111111 * rhs.e1222
#         res.e1111112222 =  lhs.e112222 * rhs.e1111 + lhs.e111222 * rhs.e1112 + lhs.e111122 * rhs.e1122 + lhs.e111112 * rhs.e1222 + lhs.e111111 * rhs.e2222
#         res.e1111122222 =  lhs.e122222 * rhs.e1111 + lhs.e112222 * rhs.e1112 + lhs.e111222 * rhs.e1122 + lhs.e111122 * rhs.e1222 + lhs.e111112 * rhs.e2222
#         res.e1111222222 =  lhs.e222222 * rhs.e1111 + lhs.e122222 * rhs.e1112 + lhs.e112222 * rhs.e1122 + lhs.e111222 * rhs.e1222 + lhs.e111122 * rhs.e2222
#         res.e1112222222 =  lhs.e222222 * rhs.e1112 + lhs.e122222 * rhs.e1122 + lhs.e112222 * rhs.e1222 + lhs.e111222 * rhs.e2222
#         res.e1122222222 =  lhs.e222222 * rhs.e1122 + lhs.e122222 * rhs.e1222 + lhs.e112222 * rhs.e2222
#         res.e1222222222 =  lhs.e222222 * rhs.e1222 + lhs.e122222 * rhs.e2222
#         res.e2222222222 =  lhs.e222222 * rhs.e2222
# //lhs order 7
#     //rhs order 0
#         //res order 7
#         res.e1111111 =  lhs.e1111111 * rhs.r
#         res.e1111112 =  lhs.e1111112 * rhs.r
#         res.e1111122 =  lhs.e1111122 * rhs.r
#         res.e1111222 =  lhs.e1111222 * rhs.r
#         res.e1112222 =  lhs.e1112222 * rhs.r
#         res.e1122222 =  lhs.e1122222 * rhs.r
#         res.e1222222 =  lhs.e1222222 * rhs.r
#         res.e2222222 =  lhs.e2222222 * rhs.r
#     //rhs order 1
#         //res order 8
#         res.e11111111 =  lhs.e1111111 * rhs.e1
#         res.e11111112 =  lhs.e1111112 * rhs.e1 + lhs.e1111111 * rhs.e2
#         res.e11111122 =  lhs.e1111122 * rhs.e1 + lhs.e1111112 * rhs.e2
#         res.e11111222 =  lhs.e1111222 * rhs.e1 + lhs.e1111122 * rhs.e2
#         res.e11112222 =  lhs.e1112222 * rhs.e1 + lhs.e1111222 * rhs.e2
#         res.e11122222 =  lhs.e1122222 * rhs.e1 + lhs.e1112222 * rhs.e2
#         res.e11222222 =  lhs.e1222222 * rhs.e1 + lhs.e1122222 * rhs.e2
#         res.e12222222 =  lhs.e2222222 * rhs.e1 + lhs.e1222222 * rhs.e2
#         res.e22222222 =  lhs.e2222222 * rhs.e2
#     //rhs order 2
#         //res order 9
#         res.e111111111 =  lhs.e1111111 * rhs.e11
#         res.e111111112 =  lhs.e1111112 * rhs.e11 + lhs.e1111111 * rhs.e12
#         res.e111111122 =  lhs.e1111122 * rhs.e11 + lhs.e1111112 * rhs.e12 + lhs.e1111111 * rhs.e22
#         res.e111111222 =  lhs.e1111222 * rhs.e11 + lhs.e1111122 * rhs.e12 + lhs.e1111112 * rhs.e22
#         res.e111112222 =  lhs.e1112222 * rhs.e11 + lhs.e1111222 * rhs.e12 + lhs.e1111122 * rhs.e22
#         res.e111122222 =  lhs.e1122222 * rhs.e11 + lhs.e1112222 * rhs.e12 + lhs.e1111222 * rhs.e22
#         res.e111222222 =  lhs.e1222222 * rhs.e11 + lhs.e1122222 * rhs.e12 + lhs.e1112222 * rhs.e22
#         res.e112222222 =  lhs.e2222222 * rhs.e11 + lhs.e1222222 * rhs.e12 + lhs.e1122222 * rhs.e22
#         res.e122222222 =  lhs.e2222222 * rhs.e12 + lhs.e1222222 * rhs.e22
#         res.e222222222 =  lhs.e2222222 * rhs.e22
#     //rhs order 3
#         //res order 10
#         res.e1111111111 =  lhs.e1111111 * rhs.e111
#         res.e1111111112 =  lhs.e1111112 * rhs.e111 + lhs.e1111111 * rhs.e112
#         res.e1111111122 =  lhs.e1111122 * rhs.e111 + lhs.e1111112 * rhs.e112 + lhs.e1111111 * rhs.e122
#         res.e1111111222 =  lhs.e1111222 * rhs.e111 + lhs.e1111122 * rhs.e112 + lhs.e1111112 * rhs.e122 + lhs.e1111111 * rhs.e222
#         res.e1111112222 =  lhs.e1112222 * rhs.e111 + lhs.e1111222 * rhs.e112 + lhs.e1111122 * rhs.e122 + lhs.e1111112 * rhs.e222
#         res.e1111122222 =  lhs.e1122222 * rhs.e111 + lhs.e1112222 * rhs.e112 + lhs.e1111222 * rhs.e122 + lhs.e1111122 * rhs.e222
#         res.e1111222222 =  lhs.e1222222 * rhs.e111 + lhs.e1122222 * rhs.e112 + lhs.e1112222 * rhs.e122 + lhs.e1111222 * rhs.e222
#         res.e1112222222 =  lhs.e2222222 * rhs.e111 + lhs.e1222222 * rhs.e112 + lhs.e1122222 * rhs.e122 + lhs.e1112222 * rhs.e222
#         res.e1122222222 =  lhs.e2222222 * rhs.e112 + lhs.e1222222 * rhs.e122 + lhs.e1122222 * rhs.e222
#         res.e1222222222 =  lhs.e2222222 * rhs.e122 + lhs.e1222222 * rhs.e222
#         res.e2222222222 =  lhs.e2222222 * rhs.e222
# //lhs order 8
#     //rhs order 0
#         //res order 8
#         res.e11111111 =  lhs.e11111111 * rhs.r
#         res.e11111112 =  lhs.e11111112 * rhs.r
#         res.e11111122 =  lhs.e11111122 * rhs.r
#         res.e11111222 =  lhs.e11111222 * rhs.r
#         res.e11112222 =  lhs.e11112222 * rhs.r
#         res.e11122222 =  lhs.e11122222 * rhs.r
#         res.e11222222 =  lhs.e11222222 * rhs.r
#         res.e12222222 =  lhs.e12222222 * rhs.r
#         res.e22222222 =  lhs.e22222222 * rhs.r
#     //rhs order 1
#         //res order 9
#         res.e111111111 =  lhs.e11111111 * rhs.e1
#         res.e111111112 =  lhs.e11111112 * rhs.e1 + lhs.e11111111 * rhs.e2
#         res.e111111122 =  lhs.e11111122 * rhs.e1 + lhs.e11111112 * rhs.e2
#         res.e111111222 =  lhs.e11111222 * rhs.e1 + lhs.e11111122 * rhs.e2
#         res.e111112222 =  lhs.e11112222 * rhs.e1 + lhs.e11111222 * rhs.e2
#         res.e111122222 =  lhs.e11122222 * rhs.e1 + lhs.e11112222 * rhs.e2
#         res.e111222222 =  lhs.e11222222 * rhs.e1 + lhs.e11122222 * rhs.e2
#         res.e112222222 =  lhs.e12222222 * rhs.e1 + lhs.e11222222 * rhs.e2
#         res.e122222222 =  lhs.e22222222 * rhs.e1 + lhs.e12222222 * rhs.e2
#         res.e222222222 =  lhs.e22222222 * rhs.e2
#     //rhs order 2
#         //res order 10
#         res.e1111111111 =  lhs.e11111111 * rhs.e11
#         res.e1111111112 =  lhs.e11111112 * rhs.e11 + lhs.e11111111 * rhs.e12
#         res.e1111111122 =  lhs.e11111122 * rhs.e11 + lhs.e11111112 * rhs.e12 + lhs.e11111111 * rhs.e22
#         res.e1111111222 =  lhs.e11111222 * rhs.e11 + lhs.e11111122 * rhs.e12 + lhs.e11111112 * rhs.e22
#         res.e1111112222 =  lhs.e11112222 * rhs.e11 + lhs.e11111222 * rhs.e12 + lhs.e11111122 * rhs.e22
#         res.e1111122222 =  lhs.e11122222 * rhs.e11 + lhs.e11112222 * rhs.e12 + lhs.e11111222 * rhs.e22
#         res.e1111222222 =  lhs.e11222222 * rhs.e11 + lhs.e11122222 * rhs.e12 + lhs.e11112222 * rhs.e22
#         res.e1112222222 =  lhs.e12222222 * rhs.e11 + lhs.e11222222 * rhs.e12 + lhs.e11122222 * rhs.e22
#         res.e1122222222 =  lhs.e22222222 * rhs.e11 + lhs.e12222222 * rhs.e12 + lhs.e11222222 * rhs.e22
#         res.e1222222222 =  lhs.e22222222 * rhs.e12 + lhs.e12222222 * rhs.e22
#         res.e2222222222 =  lhs.e22222222 * rhs.e22
# //lhs order 9
#     //rhs order 0
#         //res order 9
#         res.e111111111 =  lhs.e111111111 * rhs.r
#         res.e111111112 =  lhs.e111111112 * rhs.r
#         res.e111111122 =  lhs.e111111122 * rhs.r
#         res.e111111222 =  lhs.e111111222 * rhs.r
#         res.e111112222 =  lhs.e111112222 * rhs.r
#         res.e111122222 =  lhs.e111122222 * rhs.r
#         res.e111222222 =  lhs.e111222222 * rhs.r
#         res.e112222222 =  lhs.e112222222 * rhs.r
#         res.e122222222 =  lhs.e122222222 * rhs.r
#         res.e222222222 =  lhs.e222222222 * rhs.r
#     //rhs order 1
#         //res order 10
#         res.e1111111111 =  lhs.e111111111 * rhs.e1
#         res.e1111111112 =  lhs.e111111112 * rhs.e1 + lhs.e111111111 * rhs.e2
#         res.e1111111122 =  lhs.e111111122 * rhs.e1 + lhs.e111111112 * rhs.e2
#         res.e1111111222 =  lhs.e111111222 * rhs.e1 + lhs.e111111122 * rhs.e2
#         res.e1111112222 =  lhs.e111112222 * rhs.e1 + lhs.e111111222 * rhs.e2
#         res.e1111122222 =  lhs.e111122222 * rhs.e1 + lhs.e111112222 * rhs.e2
#         res.e1111222222 =  lhs.e111222222 * rhs.e1 + lhs.e111122222 * rhs.e2
#         res.e1112222222 =  lhs.e112222222 * rhs.e1 + lhs.e111222222 * rhs.e2
#         res.e1122222222 =  lhs.e122222222 * rhs.e1 + lhs.e112222222 * rhs.e2
#         res.e1222222222 =  lhs.e222222222 * rhs.e1 + lhs.e122222222 * rhs.e2
#         res.e2222222222 =  lhs.e222222222 * rhs.e2
# //lhs order 10
#     //rhs order 0
#         //res order 10
#         res.e1111111111 =  lhs.e1111111111 * rhs.r
#         res.e1111111112 =  lhs.e1111111112 * rhs.r
#         res.e1111111122 =  lhs.e1111111122 * rhs.r
#         res.e1111111222 =  lhs.e1111111222 * rhs.r
#         res.e1111112222 =  lhs.e1111112222 * rhs.r
#         res.e1111122222 =  lhs.e1111122222 * rhs.r
#         res.e1111222222 =  lhs.e1111222222 * rhs.r
#         res.e1112222222 =  lhs.e1112222222 * rhs.r
#         res.e1122222222 =  lhs.e1122222222 * rhs.r
#         res.e1222222222 =  lhs.e1222222222 * rhs.r
#         res.e2222222222 =  lhs.e2222222222 * rhs.r

# %%
# Write MultiDual.
w = writer(order = 2, nbases=2, mdual=True)
w.write_files(base_dir='../../../')

# w = writer(order = 3, nbases=3, mdual=True)
# w.write_files(base_dir='../../../')

# w = writer(order = 4, nbases=4, mdual=True)
# w.write_files(base_dir='../../../')

# w = writer(order = 5, nbases=5, mdual=True)
# w.write_files(base_dir='../../../')

# OTI
w = writer(order = 1, nbases=1, mdual=False)
w.write_files(base_dir='../../../')

w = writer(order = 2, nbases=1, mdual=False)
w.write_files(base_dir='../../../')

# w = writer(order = 3, nbases=1, mdual=False)
# w.write_files(base_dir='../../../')

# w = writer(order = 5, nbases=1, mdual=False)
# w.write_files(base_dir='../../../')

w = writer(order = 10, nbases=1, mdual=False)
w.write_files(base_dir='../../../')

# w = writer(order = 2, nbases=2, mdual=False)
# w.write_files(base_dir='../../../')

# w = writer(order = 3, nbases=3, mdual=False)
# w.write_files(base_dir='../../../')

# w = writer(order = 2, nbases=3, mdual=False)
# w.write_files(base_dir='../../../')

# w = writer(order = 5, nbases=2, mdual=False)
# w.write_files(base_dir='../../../')

# w = writer(order = 1, nbases=10, mdual=False)
# w.write_files(base_dir='../../../')
# Out:
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c
# Processing:  include/pyoti/static/number.pxd
# Processing:  include/pyoti/static/number/utils.pxd
# Processing:  include/pyoti/static/number/dependencies.pxd
# Processing:  include/pyoti/static/number/gauss.pxd
# Processing:  include/pyoti/static/number/scalar.pxd
# Processing:  include/pyoti/static/number/fem.pxd
# Processing:  include/pyoti/static/number/math.pxd
# Processing:  include/pyoti/static/number/array.pxd
# Processing:  include/pyoti/static/number/algebra.pxd
# Processing:  include/pyoti/static/number/sparse_array.pxd
# Processing:  include/pyoti/static/number/gauss/scalar.pxd
# Processing:  include/pyoti/static/number/gauss/array.pxd
# Processing:  include/oti/static/number.h
# Processing:  include/oti/static/number/array/utils.h
# Processing:  include/oti/static/number/array/algebra_elementwise.h
# Processing:  include/oti/static/number/array/algebra_matops.h
# Processing:  include/oti/static/number/array/gauss.h
# Processing:  include/oti/static/number/array/functions.h
# Processing:  include/oti/static/number/array/structures.h
# Processing:  include/oti/static/number/array/base.h
# Processing:  include/oti/static/number/array/gauss/utils.h
# Processing:  include/oti/static/number/array/gauss/algebra.h
# Processing:  include/oti/static/number/array/gauss/functions.h
# Processing:  include/oti/static/number/array/gauss/structures.h
# Processing:  include/oti/static/number/array/gauss/base.h
# Processing:  include/oti/static/number/scalar/utils.h
# Processing:  include/oti/static/number/scalar/algebra.h
# Processing:  include/oti/static/number/scalar/gauss.h
# Processing:  include/oti/static/number/scalar/functions.h
# Processing:  include/oti/static/number/scalar/structures.h
# Processing:  include/oti/static/number/scalar/base.h
# Processing:  include/oti/static/number/scalar/gauss/utils.h
# Processing:  include/oti/static/number/scalar/gauss/algebra.h
# Processing:  include/oti/static/number/scalar/gauss/functions.h
# Processing:  include/oti/static/number/scalar/gauss/structures.h
# Processing:  include/oti/static/number/scalar/gauss/base.h
# Processing:  src/python/pyoti/cython/static/number.pyx
# Processing:  src/python/pyoti/cython/static/number/algebra.pxi
# Processing:  src/python/pyoti/cython/static/number/creators.pxi
# Processing:  src/python/pyoti/cython/static/number/include.pxi
# Processing:  src/python/pyoti/cython/static/number/linalg.pxi
# Processing:  src/python/pyoti/cython/static/number/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/math.pxi
# Processing:  src/python/pyoti/cython/static/number/fem/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math_to.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/array/math.pxi
# Processing:  src/python/pyoti/cython/static/number/array/base.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/array/gauss/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csr/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/csc/base.pxi
# Processing:  src/python/pyoti/cython/static/number/sprarray/lil/base.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/solve.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/div.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/cross_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/sub.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/add_old.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/dot_product.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/mul.pxi
# Processing:  src/python/pyoti/cython/static/number/algebra_utils/inv.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/math.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/base.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/utils.pxi
# Processing:  src/python/pyoti/cython/static/number/scalar/gauss/base.pxi
# Processing:  src/c/static/number.c
# Processing:  src/c/static/number/array/algebra_elementwise.c
# Processing:  src/c/static/number/array/functions.c
# Processing:  src/c/static/number/array/gauss.c
# Processing:  src/c/static/number/array/functions_to.c
# Processing:  src/c/static/number/array/algebra_matops.c
# Processing:  src/c/static/number/array/base.c
# Processing:  src/c/static/number/array/utils.c
# Processing:  src/c/static/number/array/algebra_matops_to.c
# Processing:  src/c/static/number/array/algebra_elementwise_to.c
# Processing:  src/c/static/number/array/gauss/algebra_elementwise.c
# Processing:  src/c/static/number/array/gauss/functions.c
# Processing:  src/c/static/number/array/gauss/algebra_matops.c
# Processing:  src/c/static/number/array/gauss/base.c
# Processing:  src/c/static/number/array/gauss/utils.c
# Processing:  src/c/static/number/scalar/algebra.c
# Processing:  src/c/static/number/scalar/functions.c
# Processing:  src/c/static/number/scalar/gauss.c
# Processing:  src/c/static/number/scalar/functions_to.c
# Processing:  src/c/static/number/scalar/base.c
# Processing:  src/c/static/number/scalar/utils.c
# Processing:  src/c/static/number/scalar/algebra_to.c
# Processing:  src/c/static/number/scalar/gauss/algebra.c
# Processing:  src/c/static/number/scalar/gauss/functions.c
# Processing:  src/c/static/number/scalar/gauss/base.c
# Processing:  src/c/static/number/scalar/gauss/utils.c

# %%
src_path = coti.whereotilib.getpath()+"../../src/python/pyoti/python/source/"

folders={}
folders['include']=[]
folders['src']=[]


supp_ext = ['h','pxd','pxi','c','pyx']

# r=>root, d=>directories, f=>files
for key, files_in_dir in folders.items():
    location = src_path+ key
    for r, d, f in os.walk(location):
        for item in f:
            ext = item.split('.')[-1]
            if ext in supp_ext:
                files_in_dir.append(os.path.join(r.replace(location,""), item))
            #
        #
    #
#
    
for i in range(len(folders['include'])):
    print(folders['include'][i])
    print()
# Out:
# /pyoti/static/number.pxd
#
# /pyoti/static/number/utils.pxd
#
# /pyoti/static/number/dependencies.pxd
#
# /pyoti/static/number/gauss.pxd
#
# /pyoti/static/number/scalar.pxd
#
# /pyoti/static/number/fem.pxd
#
# /pyoti/static/number/math.pxd
#
# /pyoti/static/number/array.pxd
#
# /pyoti/static/number/algebra.pxd
#
# /pyoti/static/number/sparse_array.pxd
#
# /pyoti/static/number/gauss/scalar.pxd
#
# /pyoti/static/number/gauss/array.pxd
#
# /oti/static/number.h
#
# /oti/static/number/array/utils.h
#
# /oti/static/number/array/algebra_elementwise.h
#
# /oti/static/number/array/algebra_matops.h
#
# /oti/static/number/array/gauss.h
#
# /oti/static/number/array/functions.h
#
# /oti/static/number/array/structures.h
#
# /oti/static/number/array/base.h
#
# /oti/static/number/array/gauss/utils.h
#
# /oti/static/number/array/gauss/algebra.h
#
# /oti/static/number/array/gauss/functions.h
#
# /oti/static/number/array/gauss/structures.h
#
# /oti/static/number/array/gauss/base.h
#
# /oti/static/number/scalar/utils.h
#
# /oti/static/number/scalar/algebra.h
#
# /oti/static/number/scalar/gauss.h
#
# /oti/static/number/scalar/functions.h
#
# /oti/static/number/scalar/structures.h
#
# /oti/static/number/scalar/base.h
#
# /oti/static/number/scalar/gauss/utils.h
#
# /oti/static/number/scalar/gauss/algebra.h
#
# /oti/static/number/scalar/gauss/functions.h
#
# /oti/static/number/scalar/gauss/structures.h
#
# /oti/static/number/scalar/gauss/base.h

# %%
# f = open(coti.whereotilib.getpath()+"/source/src/cython/number/algebra_utils/div.pxi",'r')

src_path = coti.whereotilib.getpath()+"../../src/python/pyoti/python/source/"

# file_path = "/src/cython/number/algebra_utils/div.pxi"

# file_path = "/include/pyoti/number/algebra.pxd"
file_path = "/src"+"/c/number/scalar/functions.c"


dest_path = src_path+"../source_conv/"

for key, files_in_dir in folders.items():
    for file_path in files_in_dir:
        dest_path = src_path+"../source_conv/"+key
        
        f = open(src_path +key+ file_path,'r')
        f_str = f.read()
        f.close()

        f_str = f_str.replace("{","{{")
        f_str = f_str.replace("}","}}")
        
        f_str = f_str.replace("<<<","{")
        f_str = f_str.replace(">>>","}")

        f_str = f_str.replace("global dhl","")
        
        for i in range(30):
            string = " "*i
            f_str = f_str.replace(","+string+"dhl","")
            f_str = f_str.replace(",\n"+string+"dhl","")
            f_str = f_str.replace(", \n"+string+"dhl","")
            f_str = f_str.replace(",  \n"+string+"dhl","")
            f_str = f_str.replace(","+string+"dhelpl_t dhl","")
            f_str = f_str.replace(",\n"+string+"dhelpl_t dhl","")
            f_str = f_str.replace(", \n"+string+"dhelpl_t dhl","")
            f_str = f_str.replace(",  \n"+string+"dhelpl_t dhl","")
        #end for 
        
        
        f_str = f_str.replace("sotinum_t","{num_type}")
        f_str = f_str.replace("fesoti_t","{fenum_type}")
        f_str = f_str.replace("fearrso_t","{fearr_type}")
        f_str = f_str.replace("arrso_t","{arr_type}")
        
        f_str = f_str.replace("_SPARSE_","_{module_name_upper}_")
        f_str = f_str.replace(", bases_t nbases, ord_t order","")
        f_str = f_str.replace(", nbases, order","")
        
        f_str = f_str.replace("type}an","func}_tan")
        f_str = f_str.replace("type}aylor","func}_taylor")
        f_str = f_str.replace("type}runc","func}_trunc")

        f_str = f_str.replace("sotinum","{num_pytype}")
        f_str = f_str.replace("sotife","{fenum_pytype}")
        f_str = f_str.replace("matsofe","{fearr_pytype}")
        f_str = f_str.replace("matso","{arr_pytype}")


        f_str = f_str.replace("fesoti","{fenum_func}")
        f_str = f_str.replace("fearrso","{fearr_func}")
        f_str = f_str.replace("arrso","{arr_func}")
        f_str = f_str.replace("soti","{num_func}")
        
        f_str = f_str.replace("active_bases","active_base")
        f_str = f_str.replace("_bases","")
        f_str = f_str.replace("active_base","active_bases")
        f_str = f_str.replace("_predef","")
        f_str = f_str.replace(", 0, 0","")
        
        for i in range(10):
            f_str = f_str.replace("\n\n\n","\n\n")
        #end for 

        conv_file = dest_path+file_path
        os.makedirs(os.path.dirname(conv_file), exist_ok=True)

        f = open(conv_file,'w')
        f.write(f_str)
        f.close()

# %%
print( w.write_util_function_getidx() )

# %%
# Write static OTI.
w = writer(order = 1, nbases=20, mdual=False)
w.write_files(base_dir='export_tests/')

# %%
import re

# %%
s = """
#ifndef OTI_ONUMM1N2_SCALAR_STRUCTURES_H
#define OTI_ONUMM1N2_SCALAR_STRUCTURES_H

// ----------------------------------------------------------------------------------------------------
// --------------------------------------      STRUCTURES        --------------------------------------
// ----------------------------------------------------------------------------------------------------

// Scalar
typedef struct {
  // Real
  coeff_t r;
  // Order 1
  coeff_t e1;
  // Order 2
  coeff_t e11;
} onumm1n2_t;




// ----------------------------------------------------------------------------------------------------
// -------------------------------------    END STRUCTURES      ---------------------------------------
// ----------------------------------------------------------------------------------------------------

#endif
"""
pattern = "}(.*?);"

substring = re.search(pattern, s).group(1)

# %%
substring
# Out:
# ' onumm1n2_t'
