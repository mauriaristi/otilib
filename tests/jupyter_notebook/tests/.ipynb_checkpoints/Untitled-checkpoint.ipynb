# %%
import sympy as sym
import sys
path2oti = '../../../build_master/'
sys.path.append(path2oti) # Add path to OTI library.

import pyoti.sparse as oti
e  = oti.e
np = oti.np

# %%
x = 3.5+e(1,order=150)
y = 4.5+e(2,order=150)

# %%
# %timeit x*y
# Out:
# 230 µs ± 1.33 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit oti.sin(x)
# Out:
# 12.2 ms ± 8.53 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
12200/544
# Out:
# 22.426470588235293

# %%
230/2.25
# Out:
# 102.22222222222223

# %%
xx = (x*y)*0.0001
oti.mul(x,y,out=xx)

# %%
# %timeit oti.mul(x,y,out=xx)
# Out:
# 230 µs ± 899 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
f1 = oti.sin(x*y)
f2 = oti.sin(2*x*y)

# %%
# %timeit f1*f2
# Out:
# 62.6 ms ± 140 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
f1
# Out:
# -0.0420 - 4.4960 * e([1]) - 3.4969 * e([2]) + 0.4255 * e([[1,2]]) - 0.3372 * e([1,2]) + 0.2574 * e([[2,2]])

# %%
xs = sym.symbols('x')

# %%
# %timeit x*y

# %%
f1.extract_deriv([[1,2]])
# Out:
# 0.8510 + 91.0445 * e([1]) + 71.1906 * e([2]) - 8.6163 * e([[1,2]]) + 47.2932 * e([1,2]) + 26.3019 * e([[2,2]]) - 307.2752 * e([[1,3]]) - 724.6344 * e([[1,2],2]) - 553.0949 * e([1,[2,2]]) - 143.3950 * e([[2,3]]) + 14.5400 * e([[1,4]]) - 296.1813 * e([[1,3],2]) - 587.0896 * e([[1,2],[2,2]]) - 345.3868 * e([1,[2,3]]) - 59.1922 * e([[2,4]]) + 311.1161 * e([[1,5]]) + 1229.2827 * e([[1,4],2]) + 1780.5815 * e([[1,3],[2,2]]) + 1297.9204 * e([[1,2],[2,3]]) + 504.7468 * e([1,[2,4]]) + 83.7777 * e([[2,5]]) - 9.8145 * e([[1,6]]) + 438.1574 * e([[1,5],2]) + 1534.9075 * e([[1,4],[2,2]]) + 1987.4407 * e([[1,3],[2,3]]) + 1231.4471 * e([[1,2],[2,4]]) + 360.6837 * e([1,[2,5]]) + 37.4467 * e([[2,6]]) - 150.0024 * e([[1,7]]) - 834.1278 * e([[1,6],2]) - 1654.1934 * e([[1,5],[2,2]]) - 1689.5374 * e([[1,4],[2,3]]) - 1093.2579 * e([[1,3],[2,4]]) - 510.1870 * e([[1,2],[2,5]]) - 158.9880 * e([1,[2,6]]) - 22.4205 * e([[2,7]]) + 3.5490 * e([[1,8]]) - 277.9222 * e([[1,7],2]) - 1405.3320 * e([[1,6],[2,2]]) - 2798.7363 * e([[1,5],[2,3]]) - 3002.5832 * e([[1,4],[2,4]]) - 1916.8632 * e([[1,3],[2,5]]) - 726.5510 * e([[1,2],[2,6]]) - 146.3141 * e([1,[2,7]]) - 11.1110 * e([[2,8]]) + 42.1882 * e([[1,9]]) + 303.2039 * e([[1,8],2]) + 696.2591 * e([[1,7],[2,2]]) + 638.9894 * e([[1,6],[2,3]]) + 123.5462 * e([[1,5],[2,4]]) - 170.8048 * e([[1,4],[2,5]]) - 88.5654 * e([[1,3],[2,6]]) + 16.6084 * e([[1,2],[2,7]]) + 19.4865 * e([1,[2,8]]) + 3.3301 * e([[2,9]]) - 0.7985 * e([[1,10]]) + 96.9159 * e([[1,9],2]) + 642.4096 * e([[1,8],[2,2]]) + 1693.4284 * e([[1,7],[2,3]]) + 2482.4413 * e([[1,6],[2,4]]) + 2333.4180 * e([[1,5],[2,5]]) + 1506.0745 * e([[1,4],[2,6]]) + 672.1780 * e([[1,3],[2,7]]) + 194.6679 * e([[1,2],[2,8]]) + 31.2406 * e([1,[2,9]]) + 1.9118 * e([[2,10]]) - 7.7665 * e([[1,11]]) - 68.5758 * e([[1,10],2]) - 158.9992 * e([[1,9],[2,2]]) + 9.6890 * e([[1,8],[2,3]]) + 579.5478 * e([[1,7],[2,4]]) + 1072.3861 * e([[1,6],[2,5]]) + 1006.9239 * e([[1,5],[2,6]]) + 559.4021 * e([[1,4],[2,7]]) + 180.2021 * e([[1,3],[2,8]]) + 27.4926 * e([[1,2],[2,9]]) + 0.1112 * e([1,[2,10]]) - 0.3011 * e([[2,11]]) + 0.1225 * e([[1,12]]) - 21.2931 * e([[1,11],2]) - 174.9020 * e([[1,10],[2,2]]) - 559.4491 * e([[1,9],[2,3]]) - 975.2680 * e([[1,8],[2,4]]) - 1084.8784 * e([[1,7],[2,5]]) - 865.2727 * e([[1,6],[2,6]]) - 544.8826 * e([[1,5],[2,7]]) - 280.4125 * e([[1,4],[2,8]]) - 110.2810 * e([[1,3],[2,9]]) - 28.7870 * e([[1,2],[2,10]]) - 4.0866 * e([1,[2,11]]) - 0.2147 * e([[2,12]]) + 1.0081 * e([[1,13]]) + 10.5746 * e([[1,12],2]) + 20.9573 * e([[1,11],[2,2]]) - 69.7899 * e([[1,10],[2,3]]) - 384.3466 * e([[1,9],[2,4]]) - 798.1568 * e([[1,8],[2,5]]) - 988.4409 * e([[1,7],[2,6]]) - 823.7253 * e([[1,6],[2,7]]) - 480.5064 * e([[1,5],[2,8]]) - 193.7787 * e([[1,4],[2,9]]) - 50.4840 * e([[1,3],[2,10]]) - 7.2194 * e([[1,2],[2,11]]) - 0.3304 * e([1,[2,12]]) + 0.0169 * e([[2,13]]) - 0.0136 * e([[1,14]]) + 3.2121 * e([[1,13],2]) + 31.5132 * e([[1,12],[2,2]]) + 115.1175 * e([[1,11],[2,3]]) + 211.3285 * e([[1,10],[2,4]]) + 209.1587 * e([[1,9],[2,5]]) + 96.2117 * e([[1,8],[2,6]]) - 8.6157 * e([[1,7],[2,7]]) - 28.7447 * e([[1,6],[2,8]]) - 3.0403 * e([[1,5],[2,9]]) + 11.7362 * e([[1,4],[2,10]]) + 8.4187 * e([[1,3],[2,11]]) + 2.5728 * e([[1,2],[2,12]]) + 0.3587 * e([1,[2,13]]) + 0.0170 * e([[2,14]]) - 0.0972 * e([[1,15]]) - 1.1826 * e([[1,14],2]) - 1.4422 * e([[1,13],[2,2]]) + 23.1511 * e([[1,12],[2,3]]) + 117.9733 * e([[1,11],[2,4]]) + 277.0044 * e([[1,10],[2,5]]) + 405.5595 * e([[1,9],[2,6]]) + 417.7769 * e([[1,8],[2,7]]) + 324.4589 * e([[1,7],[2,8]]) + 196.2776 * e([[1,6],[2,9]]) + 91.7313 * e([[1,5],[2,10]]) + 31.4819 * e([[1,4],[2,11]]) + 7.2266 * e([[1,3],[2,12]]) + 0.9452 * e([[1,2],[2,13]]) + 0.0481 * e([1,[2,14]]) - 0.0005 * e([[2,15]]) + 0.0012 * e([[1,16]]) - 0.3529 * e([[1,15],2]) - 4.0299 * e([[1,14],[2,2]]) - 16.0157 * e([[1,13],[2,3]]) - 26.3363 * e([[1,12],[2,4]]) - 1.9718 * e([[1,11],[2,5]]) + 69.0044 * e([[1,10],[2,6]]) + 141.0460 * e([[1,9],[2,7]]) + 158.2300 * e([[1,8],[2,8]]) + 117.4049 * e([[1,7 ...

# %%
fs = sym.asinh(xs)

# %%
fs.diff(xs,10).subs(xs,2).evalf()
# Out:
# 40.3050701977187

# %%
oti.asinh(2+oti.e(1,order=10)).get_deriv([[1,10]])
# Out:
# 40.30507019771766
